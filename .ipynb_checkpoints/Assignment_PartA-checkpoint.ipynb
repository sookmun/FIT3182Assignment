# %% [markdown]
# Name : Tan Sook Mun
#
# ID   : 30695759
#
# Email: stan0111@student.monash.edu

# %% [markdown]
# # Part A

# %% [markdown]
# # TASK 1
#
# **<ins> hotspot_historic Example </ins>**
# ```
# {
#     'station':0,
#     'date':"",
#     'air_temperature_celcius':0,
#     'relative_humidity':0,
#     'windspeed_knots':0,
#     'max_wind_speed':0,
#     'precipitation':0,
#     "precip_flag",
#     'GHI_w/m2':0,
#     'hotspot':[]
# }
# ```
#
# **<ins>Justification</ins>**
#
# I used the embeded data model. This is because for each climate data there can be 0 or more hotspot. So for each climate data i have a key "hotspot", which contains a list of hotspot on that day. To get this, I first read the hotspot data from the csv file and add it into a temperory list. Then when adding the climate data I will add all hotspot day that have the same climate day. With this structure, I will not need to perform mergeing of collection. All the data I need is in a single record. In general it reduce the ammount of query needed. I also added a new key called  precip_flag. This contains the alpabet flag for the precipitation. The key precipitation will contain the numerical value.This is so is easy to query Task 2.j. There will be no need of text parsing or manipulating a string of numerical and alphabet values.

# %% [markdown]
# # TASK 2

# %% [markdown]
# ## TASK 2.1

# %%
import pymongo
from pymongo import MongoClient
import csv
import json
import datetime
#NEED TO MAKE IT INTO A APPLICATION???
# Method 1: connect on the default host and port
client = MongoClient () # method 1: connect on the default host and port
db = client.fit3182_assignment_db
collection = db.Climate

# %%
#reading the data of hotspot and storing into a variable 
with open('hotspot_historic.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    records=[]
    for row in csv_reader:
        if line_count!=0:
            temp={'latitude':0, 'longitude':0, 'datetime':"", 'confidence':0, 'date':"",
                      'surface_temperature_celcius':0 }
            temp["latitude"]=float(row[0])
            temp["longitude"]=float(row[1])
            temp["datetime"]=row[2] 
            temp["confidence"]=int(row[3])
            temp["date"]=row[4]
            temp["surface_temperature_celcius"]=int(row[5])
            records.append(temp)
        line_count+=1

# %%
#reading the data of climate and finding matching hotspot then add into the database
from pprint import pprint
with open('climate_historic.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    hotspot_pointer=-1 #pointer for searching
    for row in csv_reader:
        if line_count!=0: #when is not the header
            temp={'station':0, 'date':"", 'air_temperature_celcius':0, 'relative_humidity':0, 'windspeed_knots':0,
                      'max_wind_speed':0, 'precipitation':0,'GHI_w/m2':0, 'hotspot':[]}
            temp["station"]=int(row[0])
            temp["date"]=row[1]
            temp["air_temperature_celcius"]=int(row[2])
            temp["relative_humidity"]=float(row[3])
            temp["windspeed_knots"]=float(row[4])
            temp["max_wind_speed"]=float(row[5])
            temp["precipitation"]=float(row[6][:-1])
            if row[6][-1] in ["A","B","C","D","E","F","G","H","I"]:  #possible flag
                temp["precip_flag"]=row[6][-1]
            else:
                temp["precip_flag"]="Z" #Z=no flag
            temp["GHI_w/m2"]=int(row[7])
            #finding matching hotspot
            #looking at the csv file hotspot is added in decending order
            flag=True
            lst=[]
            while flag:
                if hotspot_pointer <-(len(records)): #when reach the end of list
                    break
                if records[hotspot_pointer]['date']==temp["date"]: #when there is a match 
                    lst.append(records[hotspot_pointer])#append into the array of hotspots
                    hotspot_pointer-=1 #move pointer
                else: #no longer matches so break the loop
                    flag=False
            temp["hotspot"]=lst
            collection.insert_one(temp) #insert into database
                
        line_count+=1

# %% [markdown]
# ## TASK 2.2

# %%
#a
"""
Find climate data on 12th December 2018
"""
from pprint import pprint
collection = db.Climate
cursor = collection.find({'date':'12/12/2018'})
for document in cursor: 
    pprint(document)
# Out:
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60a958a49343696505cf481d'),
#  'air_temperature_celcius': 19,
#  'date': '12/12/2018',
#  'hotspot': [{'confidence': 53,
#               'date': '12/12/2018',
#               'datetime': '2018-12-12T00:45:38',
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44}],
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %%
#b
"""
Find the latitude, longitude, surface temperature (°C), and confidence when
the surface temperature (°C) was between 65 °C and 100 °C.
"""
from pprint import pprint
collection = db.Climate
pipeline = [
    {"$unwind": "$hotspot"},
    {"$match": {"hotspot.surface_temperature_celcius":{"$gte":65,"$lte":100}}},
    {"$project": {"hotspot.latitude":1,"hotspot.longitude":1,"hotspot.confidence":1,"hotspot.date":1}},
    
]

cursor = collection.aggregate(pipeline)
for x in cursor:
    pprint(x)
# Out:
# {'_id': ObjectId('60a958a49343696505cf4708'),
#  'hotspot': {'confidence': 97,
#              'date': '10/3/2018',
#              'latitude': -37.6572,
#              'longitude': 142.0703}}
# {'_id': ObjectId('60a958a49343696505cf4708'),
#  'hotspot': {'confidence': 94,
#              'date': '10/3/2018',
#              'latitude': -37.2284,
#              'longitude': 147.9187}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'hotspot': {'confidence': 85,
#              'date': '12/3/2018',
#              'latitude': -37.4128,
#              'longitude': 147.0242}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'hotspot': {'confidence': 80,
#              'date': '12/3/2018',
#              'latitude': -37.0055,
#              'longitude': 148.1582}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'hotspot': {'confidence': 100,
#              'date': '12/3/2018',
#              'latitude': -37.4229,
#              'longitude': 147.027}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'hotspot': {'confidence': 84,
#              'date': '12/3/2018',
#              'latitude': -37.0193,
#              'longitude': 148.1459}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'hotspot': {'confidence': 94,
#              'date': '14/3/2018',
#              'latitude': -34.3555,
#              'longitude': 141.5495}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'hotspot': {'confidence': 96,
#              'date': '14/3/2018',
#              'latitude': -34.3554,
#              'longitude': 141.5413}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'hotspot': {'confidence': 89,
#              'date': '14/3/2018',
#              'latitude': -34.3654,
#              'longitude': 141.543}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'hotspot': {'confidence': 95,
#              'date': '14/3/2018',
#              'latitude': -36.9959,
#              'longitude': 148.2118}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'hotspot': {'confidence': 90,
#              'date': '14/3/2018',
#              'latitude': -36.9939,
#              'longitude': 148.2244}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'hotspot': {'confidence': 93,
#              'date': '14/3/2018',
#              'latitude': -34.3539,
#              'longitude': 141.5547}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'hotspot': {'confidence': 90,
#              'date': '14/3/2018',
#              'latitude': -34.357,
#              'longitude': 141.5361}}
# {'_id': ObjectId('60a958a49343696505cf470f'),
#  'hotspot': {'confidence': 94,
#              'date': '17/3/2018',
#              'latitude': -36.7152,
#              'longitude': 141.3853}}
# {'_id': ObjectId('60a958a49343696505cf4710'),
#  'hotspot': {'confidence': 97,
#              'date': '18/3/2018',
#              'latitude': -37.0155,
#              'longitude': 148.1432}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'hotspot': {'confidence': 92,
#              'date': '19/3/2018',
#              'latitude': -37.6625,
#              'longitude': 144.287}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'hotspot': {'confidence': 100,
#              'date': '19/3/2018',
#              'latitude': -37.3949,
#              'longitude': 147.0175}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'hotspot': {'confidence': 98,
#              'date': '19/3/2018',
#              'latitude': -37.4261,
#              'longitude': 147.0323}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'hotspot': {'confidence': 90,
#              'date': '19/3/2018',
#              'latitude': -37.4523,
#              'longitude': 147.0175}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'hotspot': {'confidence': 96,
#              'date': '19/3/2018',
#              'latitude': -37.6622,
#              'longitude': 142.1001}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'hotspot': {'confidence': 100,
#              'date': '25/3/2018',
#              'latitude': -37.8881,
#              'longitude': 145.8229}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'hotspot': {'confidence': 95,
#              'date': '25/3/2018',
#              'latitude': -37.8774,
#              'longitude': 145.8213}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'hotspot': {'confidence': 95,
#              'date': '25/3/2018',
#              'latitude': -37.7805,
#              'longitude': 143.5003}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'hotspot': {'confidence': 82,
#              'date': '25/3/2018',
#              'latitude': -37.8973,
#              'longitude': 143.4754}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'hotspot': {'confidence': 100,
#              'date': '26/3/2018',
#              'latitude': -38.0693,
#              'longitude': 142.9722}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'hotspot': {'confidence': 92,
#              'date': '26/3/2018',
#              'latitude': -38.0715,
#              'longitude': 142.9591}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'hotspot': {'confidence': 91,
#              'date': '26/3/2018',
#              'latitude': -38.0674,
#              'longitude': 142.965}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'hotspot': {'confidence': 71,
#              'date': '26/3/2018',
#              'latitude': -37.522,
#              'longitude': 143.3874}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 97,
#              'date': '28/3/2018',
#              'latitude': -35.0805,
#              'longitude': 142.4642}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 97,
#              'date': '28/3/2018',
#              'latitude': -37.9247,
#              'longitude': 142.8999}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 100,
#              'date': '28/3/2018',
#              'latitude': -37.5012,
#              'longitude': 142.5853}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 99,
#              'date': '28/3/2018',
#              'latitude': -34.351,
#              'longitude': 141.6567}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 97,
#              'date': '28/3/2018',
#              'latitude': -37.9452,
#              'longitude': 143.5834}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 97,
#              'date': '28/3/2018',
#              'latitude': -37.0924,
#              'longitude': 141.897}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 98,
#              'date': '28/3/2018',
#              'latitude': -34.3526,
#              'longitude': 141.6458}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 94,
#              'date': '28/3/2018',
#              'latitude': -36.7806,
#              'longitude': 141.5597}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 93,
#              'date': '28/3/2018',
#              'latitude': -36.8099,
#              'longitude': 142.728}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 95,
#              'date': '28/3/2018',
#              'latitude': -36.8009,
#              'longitude': 142.7259}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'hotspot': {'confidence': 92,
#              'date': '28/3/2018',
#              'latitude': -36.4557,
#              'longitude': 142.2434}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 89,
#              'date': '3/4/2018',
#              'latitude': -35.7647,
#              'longitude': 142.0858}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 89,
#              'date': '3/4/2018',
#              'latitude': -36.1556,
#              'longitude': 141.5904}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 95,
#              'date': '3/4/2018',
#              'latitude': -36.4312,
#              'longitude': 141.2064}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 93,
#              'date': '3/4/2018',
#              'latitude': -37.3046,
#              'longitude': 143.5448}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 99,
#              'date': '3/4/2018',
#              'latitude': -37.7236,
#              'longitude': 143.3995}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 90,
#              'date': '3/4/2018',
#              'latitude': -35.7657,
#              'longitude': 142.0906}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 87,
#              'date': '3/4/2018',
#              'latitude': -37.7974,
#              'longitude': 145.9535}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 98,
#              'date': '3/4/2018',
#              'latitude': -37.7509,
#              'longitude': 143.4023}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 89,
#              'date': '3/4/2018',
#              'latitude': -37.7446,
#              'longitude': 143.4085}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 100,
#              'date': '3/4/2018',
#              'latitude': -37.383,
#              'longitude': 145.9089}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 100,
#              'date': '3/4/2018',
#              'latitude': -37.3025,
#              'longitude': 143.5714}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 100,
#              'date': '3/4/2018',
#              'latitude': -37.2988,
#              'longitude': 143.5487}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 100,
#              'date': '3/4/2018',
#              'latitude': -37.297,
#              'longitude': 143.5753}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 96,
#              'date': '3/4/2018',
#              'latitude': -37.3704,
#              'longitude': 145.8942}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 95,
#              'date': '3/4/2018',
#              'latitude': -37.8072,
#              'longitude': 145.9738}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 93,
#              'date': '3/4/2018',
#              'latitude': -37.7465,
#              'longitude': 143.3806}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'hotspot': {'confidence': 87,
#              'date': '3/4/2018',
#              'latitude': -37.3735,
#              'longitude': 145.886}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 100,
#              'date': '4/4/2018',
#              'latitude': -36.1819,
#              'longitude': 145.9269}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 87,
#              'date': '4/4/2018',
#              'latitude': -36.0973,
#              'longitude': 143.4279}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 79,
#              'date': '4/4/2018',
#              'latitude': -36.883,
#              'longitude': 142.1637}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 93,
#              'date': '4/4/2018',
#              'latitude': -37.0769,
#              'longitude': 141.042}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 96,
#              'date': '4/4/2018',
#              'latitude': -36.6006,
#              'longitude': 141.9657}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 98,
#              'date': '4/4/2018',
#              'latitude': -36.095,
#              'longitude': 141.7699}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 97,
#              'date': '4/4/2018',
#              'latitude': -36.1925,
#              'longitude': 145.93}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 66,
#              'date': '4/4/2018',
#              'latitude': -36.6299,
#              'longitude': 142.4234}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 92,
#              'date': '4/4/2018',
#              'latitude': -36.5989,
#              'longitude': 141.9771}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 85,
#              'date': '4/4/2018',
#              'latitude': -35.4533,
#              'longitude': 143.2029}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 96,
#              'date': '4/4/2018',
#              'latitude': -36.1955,
#              'longitude': 145.914}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 89,
#              'date': '4/4/2018',
#              'latitude': -35.4255,
#              'longitude': 143.6306}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 100,
#              'date': '4/4/2018',
#              'latitude': -37.3735,
#              'longitude': 145.8384}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 90,
#              'date': '4/4/2018',
#              'latitude': -36.1122,
#              'longitude': 142.1491}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 90,
#              'date': '4/4/2018',
#              'latitude': -36.1615,
#              'longitude': 141.8728}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 85,
#              'date': '4/4/2018',
#              'latitude': -36.111,
#              'longitude': 145.124}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 64,
#              'date': '4/4/2018',
#              'latitude': -36.6281,
#              'longitude': 142.4349}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'hotspot': {'confidence': 90,
#              'date': '4/4/2018',
#              'latitude': -35.4033,
#              'longitude': 143.267}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 100,
#              'date': '5/4/2018',
#              'latitude': -37.4343,
#              'longitude': 147.6327}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 95,
#              'date': '5/4/2018',
#              'latitude': -37.4323,
#              'longitude': 147.6583}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 89,
#              'date': '5/4/2018',
#              'latitude': -37.4449,
#              'longitude': 147.6594}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 90,
#              'date': '5/4/2018',
#              'latitude': -37.7835,
#              'longitude': 148.4138}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 89,
#              'date': '5/4/2018',
#              'latitude': -37.4471,
#              'longitude': 147.6331}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 95,
#              'date': '5/4/2018',
#              'latitude': -37.3158,
#              'longitude': 147.4986}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 93,
#              'date': '5/4/2018',
#              'latitude': -37.3165,
#              'longitude': 147.4932}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 93,
#              'date': '5/4/2018',
#              'latitude': -37.6439,
#              'longitude': 142.913}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'hotspot': {'confidence': 87,
#              'date': '5/4/2018',
#              'latitude': -37.6387,
#              'longitude': 142.9032}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 94,
#              'date': '6/4/2018',
#              'latitude': -38.0052,
#              'longitude': 142.6179}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 86,
#              'date': '6/4/2018',
#              'latitude': -36.6986,
#              'longitude': 142.7259}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 100,
#              'date': '6/4/2018',
#              'latitude': -36.9018,
#              'longitude': 141.0146}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 94,
#              'date': '6/4/2018',
#              'latitude': -36.6349,
#              'longitude': 142.2125}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 90,
#              'date': '6/4/2018',
#              'latitude': -36.0387,
#              'longitude': 145.6787}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 92,
#              'date': '6/4/2018',
#              'latitude': -37.8161,
#              'longitude': 142.9286}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 97,
#              'date': '6/4/2018',
#              'latitude': -37.7617,
#              'longitude': 143.081}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 91,
#              'date': '6/4/2018',
#              'latitude': -37.3803,
#              'longitude': 145.611}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 96,
#              'date': '6/4/2018',
#              'latitude': -37.7542,
#              'longitude': 142.9949}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 83,
#              'date': '6/4/2018',
#              'latitude': -37.803,
#              'longitude': 142.3151}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 88,
#              'date': '6/4/2018',
#              'latitude': -37.7746,
#              'longitude': 148.3673}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 100,
#              'date': '6/4/2018',
#              'latitude': -36.9034,
#              'longitude': 141.0013}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 94,
#              'date': '6/4/2018',
#              'latitude': -35.811,
#              'longitude': 142.1403}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 90,
#              'date': '6/4/2018',
#              'latitude': -36.6384,
#              'longitude': 142.4075}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 90,
#              'date': '6/4/2018',
#              'latitude': -37.5788,
#              'longitude': 148.592}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 86,
#              'date': '6/4/2018',
#              'latitude': -37.5814,
#              'longitude': 148.5777}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 91,
#              'date': '6/4/2018',
#              'latitude': -36.031,
#              'longitude': 145.6824}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 81,
#              'date': '6/4/2018',
#              'latitude': -36.0844,
#              'longitude': 141.4934}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 89,
#              'date': '6/4/2018',
#              'latitude': -34.3943,
#              'longitude': 141.7567}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 93,
#              'date': '6/4/2018',
#              'latitude': -37.5888,
#              'longitude': 148.5949}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 99,
#              'date': '6/4/2018',
#              'latitude': -37.777,
#              'longitude': 148.4128}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 92,
#              'date': '6/4/2018',
#              'latitude': -36.0157,
#              'longitude': 145.9414}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 89,
#              'date': '6/4/2018',
#              'latitude': -37.745,
#              'longitude': 142.993}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 89,
#              'date': '6/4/2018',
#              'latitude': -36.9902,
#              'longitude': 141.879}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 100,
#              'date': '6/4/2018',
#              'latitude': -37.782,
#              'longitude': 148.3844}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 90,
#              'date': '6/4/2018',
#              'latitude': -36.1104,
#              'longitude': 145.9829}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 100,
#              'date': '6/4/2018',
#              'latitude': -36.9918,
#              'longitude': 141.8667}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 77,
#              'date': '6/4/2018',
#              'latitude': -37.8062,
#              'longitude': 143.3598}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 100,
#              'date': '6/4/2018',
#              'latitude': -37.8429,
#              'longitude': 143.8366}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 100,
#              'date': '6/4/2018',
#              'latitude': -35.805,
#              'longitude': 142.1326}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 76,
#              'date': '6/4/2018',
#              'latitude': -37.7966,
#              'longitude': 142.3196}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 92,
#              'date': '6/4/2018',
#              'latitude': -36.6334,
#              'longitude': 142.2244}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'hotspot': {'confidence': 84,
#              'date': '6/4/2018',
#              'latitude': -37.5816,
#              'longitude': 148.5862}}
# {'_id': ObjectId('60a958a49343696505cf4724'),
#  'hotspot': {'confidence': 95,
#              'date': '7/4/2018',
#              'latitude': -37.224,
#              'longitude': 147.4347}}
# {'_id': ObjectId('60a958a49343696505cf4724'),
#  'hotspot': {'confidence': 92,
#              'date': '7/4/2018',
#              'latitude': -37.2082,
#              'longitude': 147.4368}}
# {'_id': ObjectId('60a958a49343696505cf4724'),
#  'hotspot': {'confidence': 92,
#              'date': '7/4/2018',
#              'latitude': -37.2063,
#              'longitude': 147.4713}}
# {'_id': ObjectId('60a958a49343696505cf4724'),
#  'hotspot': {'confidence': 96,
#              'date': '7/4/2018',
#              'latitude': -37.222,
#              'longitude': 147.4689}}
# {'_id': ObjectId('60a958a49343696505cf4724'),
#  'hotspot': {'confidence': 100,
#              'date': '7/4/2018',
#              'latitude': -37.2168,
#              'longitude': 147.4748}}
# {'_id': ObjectId('60a958a49343696505cf4725'),
#  'hotspot': {'confidence': 90,
#              'date': '8/4/2018',
#              'latitude': -36.7165,
#              'longitude': 142.6155}}
# {'_id': ObjectId('60a958a49343696505cf4725'),
#  'hotspot': {'confidence': 66,
#              'date': '8/4/2018',
#              'latitude': -37.3493,
#              'longitude': 149.3691}}
# {'_id': ObjectId('60a958a49343696505cf4725'),
#  'hotspot': {'confidence': 98,
#              'date': '8/4/2018',
#              'latitude': -35.2381,
#              'longitude': 142.994}}
# {'_id': ObjectId('60a958a49343696505cf4725'),
#  'hotspot': {'confidence': 100,
#              'date': '8/4/2018',
#              'latitude': -35.2378,
#              'longitude': 142.9864}}
# {'_id': ObjectId('60a958a49343696505cf4725'),
#  'hotspot': {'confidence': 91,
#              'date': '8/4/2018',
#              'latitude': -35.2363,
#              'longitude': 143.0004}}
# {'_id': ObjectId('60a958a49343696505cf4725'),
#  'hotspot': {'confidence': 99,
#              'date': '8/4/2018',
#              'latitude': -36.7287,
#              'longitude': 142.6017}}
# {'_id': ObjectId('60a958a49343696505cf4725'),
#  'hotspot': {'confidence': 67,
#              'date': '8/4/2018',
#              'latitude': -37.34,
#              'longitude': 149.3668}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 93,
#              'date': '12/4/2018',
#              'latitude': -36.4489,
#              'longitude': 144.7685}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 93,
#              'date': '12/4/2018',
#              'latitude': -36.6823,
#              'longitude': 142.5024}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 100,
#              'date': '12/4/2018',
#              'latitude': -37.8249,
#              'longitude': 143.6174}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 92,
#              'date': '12/4/2018',
#              'latitude': -37.4033,
#              'longitude': 143.6884}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 95,
#              'date': '12/4/2018',
#              'latitude': -37.4028,
#              'longitude': 143.6932}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 95,
#              'date': '12/4/2018',
#              'latitude': -37.8247,
#              'longitude': 143.6243}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 100,
#              'date': '12/4/2018',
#              'latitude': -37.5949,
#              'longitude': 142.6857}}
# {'_id': ObjectId('60a958a49343696505cf4729'),
#  'hotspot': {'confidence': 94,
#              'date': '12/4/2018',
#              'latitude': -37.5812,
#              'longitude': 142.7374}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 95,
#              'date': '13/4/2018',
#              'latitude': -36.1418,
#              'longitude': 144.0261}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 96,
#              'date': '13/4/2018',
#              'latitude': -36.1518,
#              'longitude': 144.0233}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 92,
#              'date': '13/4/2018',
#              'latitude': -36.1367,
#              'longitude': 145.2071}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.5532,
#              'longitude': 142.5349}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.3972,
#              'longitude': 141.6041}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 91,
#              'date': '13/4/2018',
#              'latitude': -36.4449,
#              'longitude': 140.9836}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 92,
#              'date': '13/4/2018',
#              'latitude': -36.0749,
#              'longitude': 143.4058}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.2857,
#              'longitude': 141.3467}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 94,
#              'date': '13/4/2018',
#              'latitude': -36.3313,
#              'longitude': 141.0017}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -37.9246,
#              'longitude': 146.2464}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -35.8182,
#              'longitude': 143.8739}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 95,
#              'date': '13/4/2018',
#              'latitude': -37.8906,
#              'longitude': 146.2035}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 95,
#              'date': '13/4/2018',
#              'latitude': -37.9152,
#              'longitude': 145.8808}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -37.9174,
#              'longitude': 145.8678}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.4409,
#              'longitude': 141.6948}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 91,
#              'date': '13/4/2018',
#              'latitude': -35.6453,
#              'longitude': 142.387}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -35.6469,
#              'longitude': 142.376}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -35.1857,
#              'longitude': 141.0604}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -38.0795,
#              'longitude': 143.2449}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 95,
#              'date': '13/4/2018',
#              'latitude': -35.0706,
#              'longitude': 141.4435}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 99,
#              'date': '13/4/2018',
#              'latitude': -37.8885,
#              'longitude': 143.9157}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 89,
#              'date': '13/4/2018',
#              'latitude': -37.88,
#              'longitude': 143.7233}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -38.0254,
#              'longitude': 142.3959}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 91,
#              'date': '13/4/2018',
#              'latitude': -37.4611,
#              'longitude': 144.9371}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 84,
#              'date': '13/4/2018',
#              'latitude': -37.7587,
#              'longitude': 142.8521}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 91,
#              'date': '13/4/2018',
#              'latitude': -37.6171,
#              'longitude': 142.9426}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -37.1999,
#              'longitude': 143.8231}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 95,
#              'date': '13/4/2018',
#              'latitude': -36.8681,
#              'longitude': 143.5186}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 97,
#              'date': '13/4/2018',
#              'latitude': -36.601,
#              'longitude': 144.6378}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.7089,
#              'longitude': 143.3518}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 91,
#              'date': '13/4/2018',
#              'latitude': -36.4612,
#              'longitude': 144.7775}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 97,
#              'date': '13/4/2018',
#              'latitude': -36.4538,
#              'longitude': 144.763}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.5568,
#              'longitude': 144.0538}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 92,
#              'date': '13/4/2018',
#              'latitude': -36.5586,
#              'longitude': 144.0423}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.782,
#              'longitude': 141.8851}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.0837,
#              'longitude': 144.2448}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 94,
#              'date': '13/4/2018',
#              'latitude': -36.4816,
#              'longitude': 141.6635}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 89,
#              'date': '13/4/2018',
#              'latitude': -36.1441,
#              'longitude': 145.2221}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 97,
#              'date': '13/4/2018',
#              'latitude': -36.1067,
#              'longitude': 143.7948}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.7903,
#              'longitude': 141.618}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.4518,
#              'longitude': 144.7752}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 97,
#              'date': '13/4/2018',
#              'latitude': -36.8158,
#              'longitude': 142.6229}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.5399,
#              'longitude': 144.678}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 91,
#              'date': '13/4/2018',
#              'latitude': -36.3487,
#              'longitude': 145.5315}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -37.4591,
#              'longitude': 144.9492}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 94,
#              'date': '13/4/2018',
#              'latitude': -36.2933,
#              'longitude': 141.36}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 92,
#              'date': '13/4/2018',
#              'latitude': -36.0714,
#              'longitude': 145.7665}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 97,
#              'date': '13/4/2018',
#              'latitude': -37.0669,
#              'longitude': 141.0556}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.4125,
#              'longitude': 143.1189}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.8835,
#              'longitude': 142.2098}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -35.6374,
#              'longitude': 142.3787}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -37.3847,
#              'longitude': 142.8935}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 92,
#              'date': '13/4/2018',
#              'latitude': -36.9364,
#              'longitude': 143.4996}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.8867,
#              'longitude': 142.1873}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 98,
#              'date': '13/4/2018',
#              'latitude': -37.618,
#              'longitude': 143.0013}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 93,
#              'date': '13/4/2018',
#              'latitude': -36.5243,
#              'longitude': 142.0839}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.1462,
#              'longitude': 145.2096}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 95,
#              'date': '13/4/2018',
#              'latitude': -36.3823,
#              'longitude': 141.3146}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -37.0899,
#              'longitude': 141.0238}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 92,
#              'date': '13/4/2018',
#              'latitude': -36.1346,
#              'longitude': 145.2196}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -36.429,
#              'longitude': 141.5759}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 89,
#              'date': '13/4/2018',
#              'latitude': -35.7642,
#              'longitude': 143.3321}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -38.027,
#              'longitude': 142.3844}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.1771,
#              'longitude': 145.7451}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -37.8185,
#              'longitude': 142.5609}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 89,
#              'date': '13/4/2018',
#              'latitude': -38.1561,
#              'longitude': 143.7846}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 98,
#              'date': '13/4/2018',
#              'latitude': -36.2948,
#              'longitude': 141.3486}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 97,
#              'date': '13/4/2018',
#              'latitude': -36.7787,
#              'longitude': 141.4449}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 89,
#              'date': '13/4/2018',
#              'latitude': -35.8071,
#              'longitude': 142.7318}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.91,
#              'longitude': 141.2705}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 90,
#              'date': '13/4/2018',
#              'latitude': -35.1949,
#              'longitude': 141.0622}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 99,
#              'date': '13/4/2018',
#              'latitude': -36.0691,
#              'longitude': 145.7797}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 91,
#              'date': '13/4/2018',
#              'latitude': -36.1748,
#              'longitude': 145.7582}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.3999,
#              'longitude': 144.737}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 93,
#              'date': '13/4/2018',
#              'latitude': -35.0616,
#              'longitude': 141.4417}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -37.0761,
#              'longitude': 141.0574}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 89,
#              'date': '13/4/2018',
#              'latitude': -36.0295,
#              'longitude': 143.6409}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 92,
#              'date': '13/4/2018',
#              'latitude': -36.1924,
#              'longitude': 143.1716}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'latitude': -36.4142,
#              'longitude': 143.1077}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 93,
#              'date': '13/4/2018',
#              'latitude': -36.1941,
#              'longitude': 143.1604}}
# {'_id': ObjectId('60a958a49343696505cf472a'),
#  'hotspot': {'confidence': 96,
#              'date': '13/4/2018',
#              'latitude': -36.9498,
#              'longitude': 142.2012}}
# {'_id': ObjectId('60a958a49343696505cf472b'),
#  'hotspot': {'confidence': 100,
#              'date': '14/4/2018',
#              'latitude': -36.7957,
#              'longitude': 143.9652}}
# {'_id': ObjectId('60a958a49343696505cf472b'),
#  'hotspot': {'confidence': 99,
#              'date': '14/4/2018',
#              'latitude': -36.7943,
#              'longitude': 143.9571}}
# {'_id': ObjectId('60a958a49343696505cf472b'),
#  'hotspot': {'confidence': 84,
#              'date': '14/4/2018',
#              'latitude': -36.7531,
#              'longitude': 141.3253}}
# {'_id': ObjectId('60a958a49343696505cf472b'),
#  'hotspot': {'confidence': 84,
#              'date': '14/4/2018',
#              'latitude': -36.7432,
#              'longitude': 141.3296}}
# {'_id': ObjectId('60a958a49343696505cf472b'),
#  'hotspot': {'confidence': 75,
#              'date': '14/4/2018',
#              'latitude': -36.7499,
#              'longitude': 141.3006}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 100,
#              'date': '15/4/2018',
#              'latitude': -36.1988,
#              'longitude': 145.0941}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 93,
#              'date': '15/4/2018',
#              'latitude': -36.8238,
#              'longitude': 143.5724}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 100,
#              'date': '15/4/2018',
#              'latitude': -36.6615,
#              'longitude': 144.6014}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 96,
#              'date': '15/4/2018',
#              'latitude': -36.8298,
#              'longitude': 143.4483}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 96,
#              'date': '15/4/2018',
#              'latitude': -36.1898,
#              'longitude': 145.0922}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 97,
#              'date': '15/4/2018',
#              'latitude': -36.6527,
#              'longitude': 142.7392}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 100,
#              'date': '15/4/2018',
#              'latitude': -36.8283,
#              'longitude': 143.4605}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 89,
#              'date': '15/4/2018',
#              'latitude': -36.73,
#              'longitude': 143.935}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 91,
#              'date': '15/4/2018',
#              'latitude': -36.6892,
#              'longitude': 145.2775}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 78,
#              'date': '15/4/2018',
#              'latitude': -35.9326,
#              'longitude': 141.958}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 99,
#              'date': '15/4/2018',
#              'latitude': -35.8276,
#              'longitude': 143.7549}}
# {'_id': ObjectId('60a958a49343696505cf472c'),
#  'hotspot': {'confidence': 98,
#              'date': '15/4/2018',
#              'latitude': -36.9329,
#              'longitude': 143.7796}}
# {'_id': ObjectId('60a958a49343696505cf472d'),
#  'hotspot': {'confidence': 91,
#              'date': '16/4/2018',
#              'latitude': -36.7651,
#              'longitude': 143.5801}}
# {'_id': ObjectId('60a958a49343696505cf472e'),
#  'hotspot': {'confidence': 90,
#              'date': '17/4/2018',
#              'latitude': -37.1349,
#              'longitude': 141.9491}}
# {'_id': ObjectId('60a958a49343696505cf472e'),
#  'hotspot': {'confidence': 94,
#              'date': '17/4/2018',
#              'latitude': -36.3966,
#              'longitude': 141.406}}
# {'_id': ObjectId('60a958a49343696505cf472e'),
#  'hotspot': {'confidence': 91,
#              'date': '17/4/2018',
#              'latitude': -37.0782,
#              'longitude': 145.3625}}
# {'_id': ObjectId('60a958a49343696505cf472e'),
#  'hotspot': {'confidence': 95,
#              'date': '17/4/2018',
#              'latitude': -36.5199,
#              'longitude': 144.7311}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 95,
#              'date': '18/4/2018',
#              'latitude': -36.738,
#              'longitude': 142.1177}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 92,
#              'date': '18/4/2018',
#              'latitude': -36.2652,
#              'longitude': 145.3769}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 93,
#              'date': '18/4/2018',
#              'latitude': -36.91,
#              'longitude': 141.0704}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 89,
#              'date': '18/4/2018',
#              'latitude': -37.2609,
#              'longitude': 141.7999}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 91,
#              'date': '18/4/2018',
#              'latitude': -36.2637,
#              'longitude': 145.3649}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 89,
#              'date': '18/4/2018',
#              'latitude': -34.9023,
#              'longitude': 142.0557}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 94,
#              'date': '18/4/2018',
#              'latitude': -36.092,
#              'longitude': 141.7306}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 93,
#              'date': '18/4/2018',
#              'latitude': -36.663,
#              'longitude': 141.3038}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 93,
#              'date': '18/4/2018',
#              'latitude': -36.4899,
#              'longitude': 142.2805}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 100,
#              'date': '18/4/2018',
#              'latitude': -35.8768,
#              'longitude': 145.4627}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 93,
#              'date': '18/4/2018',
#              'latitude': -36.8879,
#              'longitude': 141.6647}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 95,
#              'date': '18/4/2018',
#              'latitude': -36.6995,
#              'longitude': 142.978}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 98,
#              'date': '18/4/2018',
#              'latitude': -36.5262,
#              'longitude': 144.5737}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 96,
#              'date': '18/4/2018',
#              'latitude': -36.5987,
#              'longitude': 144.4995}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 92,
#              'date': '18/4/2018',
#              'latitude': -36.5828,
#              'longitude': 144.5775}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 100,
#              'date': '18/4/2018',
#              'latitude': -37.4352,
#              'longitude': 143.1444}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 100,
#              'date': '18/4/2018',
#              'latitude': -37.5728,
#              'longitude': 142.6348}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 92,
#              'date': '18/4/2018',
#              'latitude': -37.6498,
#              'longitude': 142.5997}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 100,
#              'date': '18/4/2018',
#              'latitude': -37.7002,
#              'longitude': 142.9562}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 94,
#              'date': '18/4/2018',
#              'latitude': -37.7236,
#              'longitude': 142.947}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 91,
#              'date': '18/4/2018',
#              'latitude': -37.7171,
#              'longitude': 142.9505}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 90,
#              'date': '18/4/2018',
#              'latitude': -37.7756,
#              'longitude': 143.1388}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 96,
#              'date': '18/4/2018',
#              'latitude': -37.7935,
#              'longitude': 143.1606}}
# {'_id': ObjectId('60a958a49343696505cf472f'),
#  'hotspot': {'confidence': 93,
#              'date': '18/4/2018',
#              'latitude': -37.9157,
# ...
#  'hotspot': {'confidence': 90,
#              'date': '11/5/2018',
#              'latitude': -36.2911,
#              'longitude': 141.1664}}
# {'_id': ObjectId('60a958a49343696505cf4747'),
#  'hotspot': {'confidence': 93,
#              'date': '12/5/2018',
#              'latitude': -37.4671,
#              'longitude': 145.9962}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 100,
#              'date': '13/5/2018',
#              'latitude': -36.1506,
#              'longitude': 143.5671}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 90,
#              'date': '13/5/2018',
#              'latitude': -35.6871,
#              'longitude': 143.5235}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 91,
#              'date': '13/5/2018',
#              'latitude': -35.6819,
#              'longitude': 143.5275}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 91,
#              'date': '13/5/2018',
#              'latitude': -36.5541,
#              'longitude': 144.1321}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 94,
#              'date': '13/5/2018',
#              'latitude': -36.0828,
#              'longitude': 145.873}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 100,
#              'date': '13/5/2018',
#              'latitude': -36.0077,
#              'longitude': 141.7747}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 100,
#              'date': '13/5/2018',
#              'latitude': -36.1532,
#              'longitude': 143.5527}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 100,
#              'date': '13/5/2018',
#              'latitude': -36.0816,
#              'longitude': 145.859}}
# {'_id': ObjectId('60a958a49343696505cf4748'),
#  'hotspot': {'confidence': 95,
#              'date': '13/5/2018',
#              'latitude': -36.3254,
#              'longitude': 144.3638}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 100,
#              'date': '15/5/2018',
#              'latitude': -38.0361,
#              'longitude': 146.0567}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 94,
#              'date': '15/5/2018',
#              'latitude': -36.2775,
#              'longitude': 146.1026}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 95,
#              'date': '15/5/2018',
#              'latitude': -36.0396,
#              'longitude': 141.7183}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 89,
#              'date': '15/5/2018',
#              'latitude': -35.4666,
#              'longitude': 142.0749}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 94,
#              'date': '15/5/2018',
#              'latitude': -38.049,
#              'longitude': 146.0513}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 90,
#              'date': '15/5/2018',
#              'latitude': -38.0372,
#              'longitude': 146.0616}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 90,
#              'date': '15/5/2018',
#              'latitude': -36.8616,
#              'longitude': 142.8025}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 85,
#              'date': '15/5/2018',
#              'latitude': -36.5023,
#              'longitude': 143.6038}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 89,
#              'date': '15/5/2018',
#              'latitude': -36.5661,
#              'longitude': 142.2956}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 96,
#              'date': '15/5/2018',
#              'latitude': -36.3402,
#              'longitude': 141.7429}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 90,
#              'date': '15/5/2018',
#              'latitude': -36.7032,
#              'longitude': 144.0992}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 100,
#              'date': '15/5/2018',
#              'latitude': -36.345,
#              'longitude': 143.4256}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 100,
#              'date': '15/5/2018',
#              'latitude': -36.3433,
#              'longitude': 143.4369}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 96,
#              'date': '15/5/2018',
#              'latitude': -36.3387,
#              'longitude': 141.7542}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 92,
#              'date': '15/5/2018',
#              'latitude': -36.9396,
#              'longitude': 143.1462}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 96,
#              'date': '15/5/2018',
#              'latitude': -37.253,
#              'longitude': 144.3681}}
# {'_id': ObjectId('60a958a49343696505cf474a'),
#  'hotspot': {'confidence': 93,
#              'date': '15/5/2018',
#              'latitude': -37.4984,
#              'longitude': 142.9739}}
# {'_id': ObjectId('60a958a49343696505cf4751'),
#  'hotspot': {'confidence': 100,
#              'date': '22/5/2018',
#              'latitude': -37.9047,
#              'longitude': 141.0945}}
# {'_id': ObjectId('60a958a49343696505cf4751'),
#  'hotspot': {'confidence': 89,
#              'date': '22/5/2018',
#              'latitude': -38.4792,
#              'longitude': 146.3081}}
# {'_id': ObjectId('60a958a49343696505cf4751'),
#  'hotspot': {'confidence': 100,
#              'date': '22/5/2018',
#              'latitude': -38.4349,
#              'longitude': 146.3122}}
# {'_id': ObjectId('60a958a49343696505cf4751'),
#  'hotspot': {'confidence': 98,
#              'date': '22/5/2018',
#              'latitude': -37.9085,
#              'longitude': 141.1038}}
# {'_id': ObjectId('60a958a49343696505cf4751'),
#  'hotspot': {'confidence': 96,
#              'date': '22/5/2018',
#              'latitude': -36.8359,
#              'longitude': 146.6448}}
# {'_id': ObjectId('60a958a49343696505cf4751'),
#  'hotspot': {'confidence': 91,
#              'date': '22/5/2018',
#              'latitude': -36.7746,
#              'longitude': 146.6642}}
# {'_id': ObjectId('60a958a49343696505cf475e'),
#  'hotspot': {'confidence': 91,
#              'date': '4/6/2018',
#              'latitude': -36.7801,
#              'longitude': 142.7151}}
# {'_id': ObjectId('60a958a49343696505cf475e'),
#  'hotspot': {'confidence': 91,
#              'date': '4/6/2018',
#              'latitude': -36.7685,
#              'longitude': 142.7134}}
# {'_id': ObjectId('60a958a49343696505cf4761'),
#  'hotspot': {'confidence': 90,
#              'date': '7/6/2018',
#              'latitude': -36.4325,
#              'longitude': 144.3142}}
# {'_id': ObjectId('60a958a49343696505cf4761'),
#  'hotspot': {'confidence': 96,
#              'date': '7/6/2018',
#              'latitude': -36.1002,
#              'longitude': 142.3405}}
# {'_id': ObjectId('60a958a49343696505cf4768'),
#  'hotspot': {'confidence': 94,
#              'date': '14/6/2018',
#              'latitude': -36.2693,
#              'longitude': 143.1768}}
# {'_id': ObjectId('60a958a49343696505cf476e'),
#  'hotspot': {'confidence': 100,
#              'date': '20/6/2018',
#              'latitude': -36.3799,
#              'longitude': 143.7149}}
# {'_id': ObjectId('60a958a49343696505cf476e'),
#  'hotspot': {'confidence': 97,
#              'date': '20/6/2018',
#              'latitude': -36.369,
#              'longitude': 143.7132}}
# {'_id': ObjectId('60a958a49343696505cf476e'),
#  'hotspot': {'confidence': 100,
#              'date': '20/6/2018',
#              'latitude': -36.3756,
#              'longitude': 143.7243}}
# {'_id': ObjectId('60a958a49343696505cf476e'),
#  'hotspot': {'confidence': 91,
#              'date': '20/6/2018',
#              'latitude': -36.3774,
#              'longitude': 143.7079}}
# {'_id': ObjectId('60a958a49343696505cf477e'),
#  'hotspot': {'confidence': 91,
#              'date': '6/7/2018',
#              'latitude': -37.8644,
#              'longitude': 143.4263}}
# {'_id': ObjectId('60a958a49343696505cf4798'),
#  'hotspot': {'confidence': 89,
#              'date': '1/8/2018',
#              'latitude': -38.3998,
#              'longitude': 147.064}}
# {'_id': ObjectId('60a958a49343696505cf4799'),
#  'hotspot': {'confidence': 94,
#              'date': '2/8/2018',
#              'latitude': -37.4796,
#              'longitude': 141.9403}}
# {'_id': ObjectId('60a958a49343696505cf47cd'),
#  'hotspot': {'confidence': 100,
#              'date': '23/9/2018',
#              'latitude': -37.401,
#              'longitude': 148.067}}
# {'_id': ObjectId('60a958a49343696505cf47cd'),
#  'hotspot': {'confidence': 100,
#              'date': '23/9/2018',
#              'latitude': -37.399,
#              'longitude': 148.081}}
# {'_id': ObjectId('60a958a49343696505cf47cd'),
#  'hotspot': {'confidence': 100,
#              'date': '23/9/2018',
#              'latitude': -37.396,
#              'longitude': 148.086}}
# {'_id': ObjectId('60a958a49343696505cf47cd'),
#  'hotspot': {'confidence': 62,
#              'date': '23/9/2018',
#              'latitude': -37.379,
#              'longitude': 148.132}}
# {'_id': ObjectId('60a958a49343696505cf47cd'),
#  'hotspot': {'confidence': 58,
#              'date': '23/9/2018',
#              'latitude': -37.379,
#              'longitude': 148.126}}
# {'_id': ObjectId('60a958a49343696505cf47ce'),
#  'hotspot': {'confidence': 61,
#              'date': '24/9/2018',
#              'latitude': -37.562,
#              'longitude': 148.05}}
# {'_id': ObjectId('60a958a49343696505cf47ce'),
#  'hotspot': {'confidence': 73,
#              'date': '24/9/2018',
#              'latitude': -37.444,
#              'longitude': 148.101}}
# {'_id': ObjectId('60a958a49343696505cf47ce'),
#  'hotspot': {'confidence': 86,
#              'date': '24/9/2018',
#              'latitude': -37.436,
#              'longitude': 148.088}}
# {'_id': ObjectId('60a958a49343696505cf47ce'),
#  'hotspot': {'confidence': 64,
#              'date': '24/9/2018',
#              'latitude': -37.45,
#              'longitude': 148.126}}
# {'_id': ObjectId('60a958a49343696505cf47ce'),
#  'hotspot': {'confidence': 68,
#              'date': '24/9/2018',
#              'latitude': -37.452,
#              'longitude': 148.115}}
# {'_id': ObjectId('60a958a49343696505cf47ce'),
#  'hotspot': {'confidence': 100,
#              'date': '24/9/2018',
#              'latitude': -37.406,
#              'longitude': 148.123}}
# {'_id': ObjectId('60a958a49343696505cf47ce'),
#  'hotspot': {'confidence': 100,
#              'date': '24/9/2018',
#              'latitude': -37.446,
#              'longitude': 148.102}}
# {'_id': ObjectId('60a958a49343696505cf47d7'),
#  'hotspot': {'confidence': 88,
#              'date': '3/10/2018',
#              'latitude': -37.46,
#              'longitude': 148.102}}
# {'_id': ObjectId('60a958a49343696505cf47d7'),
#  'hotspot': {'confidence': 100,
#              'date': '3/10/2018',
#              'latitude': -37.462,
#              'longitude': 148.089}}
# {'_id': ObjectId('60a958a49343696505cf47de'),
#  'hotspot': {'confidence': 96,
#              'date': '10/10/2018',
#              'latitude': -38.127,
#              'longitude': 143.82}}
# {'_id': ObjectId('60a958a49343696505cf47e3'),
#  'hotspot': {'confidence': 99,
#              'date': '15/10/2018',
#              'latitude': -37.293,
#              'longitude': 141.245}}
# {'_id': ObjectId('60a958a49343696505cf47e3'),
#  'hotspot': {'confidence': 100,
#              'date': '15/10/2018',
#              'latitude': -37.294,
#              'longitude': 141.232}}
# {'_id': ObjectId('60a958a49343696505cf47e5'),
#  'hotspot': {'confidence': 91,
#              'date': '17/10/2018',
#              'latitude': -37.247,
#              'longitude': 141.278}}
# {'_id': ObjectId('60a958a49343696505cf47e9'),
#  'hotspot': {'confidence': 92,
#              'date': '21/10/2018',
#              'latitude': -36.098,
#              'longitude': 143.74}}
# {'_id': ObjectId('60a958a49343696505cf47f8'),
#  'hotspot': {'confidence': 90,
#              'date': '5/11/2018',
#              'latitude': -37.331,
#              'longitude': 143.122}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'hotspot': {'confidence': 97,
#              'date': '9/11/2018',
#              'latitude': -37.69,
#              'longitude': 143.605}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'hotspot': {'confidence': 96,
#              'date': '9/11/2018',
#              'latitude': -37.475,
#              'longitude': 143.365}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'hotspot': {'confidence': 100,
#              'date': '9/11/2018',
#              'latitude': -37.477,
#              'longitude': 143.352}}
# {'_id': ObjectId('60a958a49343696505cf47ff'),
#  'hotspot': {'confidence': 89,
#              'date': '12/11/2018',
#              'latitude': -36.94,
#              'longitude': 143.281}}
# {'_id': ObjectId('60a958a49343696505cf4801'),
#  'hotspot': {'confidence': 87,
#              'date': '14/11/2018',
#              'latitude': -37.862,
#              'longitude': 144.175}}
# {'_id': ObjectId('60a958a49343696505cf480a'),
#  'hotspot': {'confidence': 93,
#              'date': '23/11/2018',
#              'latitude': -37.945,
#              'longitude': 144.354}}
# {'_id': ObjectId('60a958a49343696505cf4810'),
#  'hotspot': {'confidence': 99,
#              'date': '29/11/2018',
#              'latitude': -37.609,
#              'longitude': 149.32}}
# {'_id': ObjectId('60a958a49343696505cf4810'),
#  'hotspot': {'confidence': 97,
#              'date': '29/11/2018',
#              'latitude': -37.61,
#              'longitude': 149.307}}
# {'_id': ObjectId('60a958a49343696505cf4810'),
#  'hotspot': {'confidence': 100,
#              'date': '29/11/2018',
#              'latitude': -37.606,
#              'longitude': 149.312}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'hotspot': {'confidence': 95,
#              'date': '30/11/2018',
#              'latitude': -37.618,
#              'longitude': 149.281}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'hotspot': {'confidence': 99,
#              'date': '30/11/2018',
#              'latitude': -37.6,
#              'longitude': 149.325}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'hotspot': {'confidence': 98,
#              'date': '30/11/2018',
#              'latitude': -37.605,
#              'longitude': 149.302}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'hotspot': {'confidence': 100,
#              'date': '30/11/2018',
#              'latitude': -37.634,
#              'longitude': 149.237}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'hotspot': {'confidence': 100,
#              'date': '30/11/2018',
#              'latitude': -37.642,
#              'longitude': 149.263}}
# {'_id': ObjectId('60a958a49343696505cf4819'),
#  'hotspot': {'confidence': 100,
#              'date': '8/12/2018',
#              'latitude': -36.282,
#              'longitude': 146.157}}
# {'_id': ObjectId('60a958a49343696505cf481f'),
#  'hotspot': {'confidence': 92,
#              'date': '14/12/2018',
#              'latitude': -37.95,
#              'longitude': 142.366}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'hotspot': {'confidence': 93,
#              'date': '16/12/2018',
#              'latitude': -38.057,
#              'longitude': 144.211}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'hotspot': {'confidence': 90,
#              'date': '16/12/2018',
#              'latitude': -37.624,
#              'longitude': 149.314}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'hotspot': {'confidence': 95,
#              'date': '16/12/2018',
#              'latitude': -37.613,
#              'longitude': 149.305}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'hotspot': {'confidence': 93,
#              'date': '16/12/2018',
#              'latitude': -37.875,
#              'longitude': 142.51}}
# {'_id': ObjectId('60a958a49343696505cf482c'),
#  'hotspot': {'confidence': 86,
#              'date': '27/12/2018',
#              'latitude': -35.543,
#              'longitude': 143.316}}
# {'_id': ObjectId('60a958a49343696505cf482c'),
#  'hotspot': {'confidence': 78,
#              'date': '27/12/2018',
#              'latitude': -37.966,
#              'longitude': 145.051}}

# %%
#c
"""
Find date, surface temperature (°C), air temperature (°C), relative humidity
and max wind speed on 15th and 16th of December 2018.
"""
cursor = collection.find({"$or":[{'date':'15/12/2018'},{'date':'16/12/2018'}]},
                         {"hotspot.surface_temperature_celcius":1,"air_temperature_celcius":1,
                          "max_wind_speed":1,"relative_humidity":1,"date":1})
for document in cursor: 
    pprint(document)
# Out:
# {'_id': ObjectId('60a958a49343696505cf4820'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2018',
#  'hotspot': [{'surface_temperature_celcius': 40},
#              {'surface_temperature_celcius': 38},
#              {'surface_temperature_celcius': 36},
#              {'surface_temperature_celcius': 42}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'hotspot': [{'surface_temperature_celcius': 57},
#              {'surface_temperature_celcius': 64},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 48},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 60},
#              {'surface_temperature_celcius': 56},
#              {'surface_temperature_celcius': 66},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 75},
#              {'surface_temperature_celcius': 55},
#              {'surface_temperature_celcius': 73},
#              {'surface_temperature_celcius': 54},
#              {'surface_temperature_celcius': 33},
#              {'surface_temperature_celcius': 43}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %%
#d
"""
Find datetime, air temperature (°C), surface temperature (°C) and
confidence when the confidence is between 80 and 100. 
"""
pipeline = [
    {"$unwind": "$hotspot"},
    {"$match": {"hotspot.confidence":{"$gte":80,"$lte":100}}},
    {"$project": {"hotspot.surface_temperature_celcius":1,"air_temperature_celcius":1,
                          "hotspot.datetime":1,"hotspot.confidence":1}},
    
]

cursor = collection.aggregate(pipeline)
for document in cursor: 
    pprint(document)
# Out:
# {'_id': ObjectId('60a958a49343696505cf4704'),
#  'air_temperature_celcius': 20,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-03-06T05:06:20',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4704'),
#  'air_temperature_celcius': 20,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-03-06T05:06:30',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4705'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-03-07T04:16:10',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4707'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-03-09T13:23:40',
#              'surface_temperature_celcius': 41}}
# {'_id': ObjectId('60a958a49343696505cf4708'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-10T04:43:50',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4708'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-03-10T04:45:30',
#              'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60a958a49343696505cf4708'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-03-10T04:45:30',
#              'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60a958a49343696505cf4708'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-10T04:46:20',
#              'surface_temperature_celcius': 109}}
# {'_id': ObjectId('60a958a49343696505cf4708'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-10T04:48:40',
#              'surface_temperature_celcius': 105}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-03-12T04:27:20',
#              'surface_temperature_celcius': 98}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-03-12T04:28:00',
#              'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-12T04:28:20',
#              'surface_temperature_celcius': 99}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-03-12T04:29:50',
#              'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60a958a49343696505cf470a'),
#  'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-03-12T04:33:50',
#              'surface_temperature_celcius': 105}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-03-14T04:14:30',
#              'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-03-14T04:14:30',
#              'surface_temperature_celcius': 79}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-14T04:14:40',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-03-14T04:16:20',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-03-14T04:16:30',
#              'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-03-14T04:20:50',
#              'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-03-14T04:22:20',
#              'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60a958a49343696505cf470c'),
#  'air_temperature_celcius': 25,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-03-14T04:24:40',
#              'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60a958a49343696505cf470f'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-03-17T04:45:00',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf470f'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-03-17T04:45:10',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf470f'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-03-17T04:48:20',
#              'surface_temperature_celcius': 74}}
# {'_id': ObjectId('60a958a49343696505cf4710'),
#  'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-03-18T03:50:40',
#              'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60a958a49343696505cf4710'),
#  'air_temperature_celcius': 21,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-18T03:50:50',
#              'surface_temperature_celcius': 121}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-19T04:32:40',
#              'surface_temperature_celcius': 106}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-03-19T04:32:40',
#              'surface_temperature_celcius': 70}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-19T04:32:40',
#              'surface_temperature_celcius': 113}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-03-19T04:32:50',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-19T04:32:50',
#              'surface_temperature_celcius': 91}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 98,
#              'datetime': '2018-03-19T04:33:00',
#              'surface_temperature_celcius': 83}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-03-19T04:36:00',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-03-19T04:39:20',
#              'surface_temperature_celcius': 79}}
# {'_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-03-19T04:39:50',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-25T03:56:40',
#              'surface_temperature_celcius': 99}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-03-25T03:57:10',
#              'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-25T03:57:10',
#              'surface_temperature_celcius': 111}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-03-25T03:57:10',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-03-25T03:58:10',
#              'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-03-25T03:58:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-03-25T03:59:50',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-03-26T04:39:10',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-03-26T04:39:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-03-26T04:39:10',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-26T04:39:10',
#              'surface_temperature_celcius': 89}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-03-26T04:39:10',
#              'surface_temperature_celcius': 70}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 91,
#              'datetime': '2018-03-26T04:39:10',
#              'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-26T04:39:50',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-03-26T04:40:50',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-26T04:43:20',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 81}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 81}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 90}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-28T04:26:50',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 99,
#              'datetime': '2018-03-28T04:27:00',
#              'surface_temperature_celcius': 86}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-03-28T04:27:00',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-28T04:27:10',
#              'surface_temperature_celcius': 108}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-03-28T04:27:20',
#              'surface_temperature_celcius': 107}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-03-28T04:27:40',
#              'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-03-28T04:28:30',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-03-28T04:28:30',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-28T04:28:30',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-03-28T04:30:10',
#              'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-28T04:30:10',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 98,
#              'datetime': '2018-03-28T04:30:10',
#              'surface_temperature_celcius': 82}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-03-28T04:30:10',
#              'surface_temperature_celcius': 74}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-03-28T04:30:20',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-03-28T04:30:50',
#              'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-03-28T04:32:20',
#              'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-03-28T04:33:30',
#              'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-03-28T04:33:30',
#              'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-03-28T04:33:40',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-03-28T04:38:00',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-03-31T00:36:30',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-03-31T04:57:10',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-03-31T04:58:00',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-03-31T04:58:30',
#              'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-03-31T05:01:20',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-03-31T05:07:10',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-03T01:07:20',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 99,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 86}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-03T03:50:40',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-03T03:50:50',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-03T03:50:50',
#              'surface_temperature_celcius': 97}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-03T03:51:00',
#              'surface_temperature_celcius': 103}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-04-03T03:51:00',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 98,
#              'datetime': '2018-04-03T03:51:00',
#              'surface_temperature_celcius': 82}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-03T03:51:00',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-03T03:51:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-04-03T03:51:30',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-04-03T03:51:30',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-03T03:52:10',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-03T03:52:10',
#              'surface_temperature_celcius': 89}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-03T03:52:10',
#              'surface_temperature_celcius': 98}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-04-03T03:52:10',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-03T03:52:20',
#              'surface_temperature_celcius': 115}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-03T03:52:30',
#              'surface_temperature_celcius': 90}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-04-03T03:52:30',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-03T03:53:30',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-03T03:53:50',
#              'surface_temperature_celcius': 93}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-04-03T03:54:00',
#              'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-04-03T03:55:10',
#              'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-03T03:55:10',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-03T03:56:20',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-04-03T03:57:50',
#              'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-03T03:59:10',
#              'surface_temperature_celcius': 96}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-04-03T13:15:10',
#              'surface_temperature_celcius': 45}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-03T13:15:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-04-03T13:15:30',
#              'surface_temperature_celcius': 40}}
# {'_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 91,
#              'datetime': '2018-04-03T13:17:00',
#              'surface_temperature_celcius': 43}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-04-04T00:12:50',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 98}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 101}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 92}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 120}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-04-04T04:32:40',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:32:50',
#              'surface_temperature_celcius': 118}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-04T04:32:50',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:32:50',
#              'surface_temperature_celcius': 123}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-04T04:32:50',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-04-04T04:32:50',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-04T04:32:50',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 98,
#              'datetime': '2018-04-04T04:32:50',
#              'surface_temperature_celcius': 82}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-04-04T04:33:00',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-04-04T04:33:00',
#              'surface_temperature_celcius': 79}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-04T04:33:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-04T04:33:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-04T04:33:30',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-04-04T04:33:30',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:33:30',
#              'surface_temperature_celcius': 113}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-04T04:33:40',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-04-04T04:33:50',
#              'surface_temperature_celcius': 81}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-04-04T04:34:00',
#              'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-04T04:34:20',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-04-04T04:34:20',
#              'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-04-04T04:34:20',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-04-04T04:34:50',
#              'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:35:00',
#              'surface_temperature_celcius': 95}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-04T04:36:00',
#              'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-04T04:36:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-04T04:36:10',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-04T04:37:10',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:39:20',
#              'surface_temperature_celcius': 107}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-04T04:39:40',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-04T04:39:40',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-04T04:39:50',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-04T04:39:50',
#              'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T04:40:00',
#              'surface_temperature_celcius': 120}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-04-04T04:41:00',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-04T04:41:00',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-04T04:41:10',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-04T04:41:50',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-04T15:30:40',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-04-04T15:31:00',
#              'surface_temperature_celcius': 44}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-04-05T03:39:10',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-05T03:39:10',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-05T03:39:10',
#              'surface_temperature_celcius': 92}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-04-05T03:39:10',
#              'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-04-05T03:39:10',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-04-05T03:39:10',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-04-05T03:39:20',
#              'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-05T03:39:20',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-05T03:39:30',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-04-05T03:39:30',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-05T03:40:20',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-04-05T03:40:30',
#              'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-04-05T03:40:50',
#              'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-04-05T05:15:30',
#              'surface_temperature_celcius': 83}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-05T05:16:50',
#              'surface_temperature_celcius': 88}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-04-05T13:02:40',
#              'surface_temperature_celcius': 39}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-05T13:02:40',
#              'surface_temperature_celcius': 42}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-05T13:03:00',
#              'surface_temperature_celcius': 39}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-05T13:03:00',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 98,
#              'datetime': '2018-04-05T13:03:00',
#              'surface_temperature_celcius': 45}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-05T13:03:20',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-05T13:04:20',
#              'surface_temperature_celcius': 49}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-05T13:07:00',
#              'surface_temperature_celcius': 40}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-05T13:08:40',
#              'surface_temperature_celcius': 47}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-04-05T13:08:40',
#              'surface_temperature_celcius': 44}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-05T13:09:00',
#              'surface_temperature_celcius': 39}}
# {'_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-05T13:09:00',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 89}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 100}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 86}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 104}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 81}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 91,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-04-06T04:20:40',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-04-06T04:20:50',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-04-06T04:20:50',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-06T04:20:50',
#              'surface_temperature_celcius': 95}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-04-06T04:21:00',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-04-06T04:21:00',
#              'surface_temperature_celcius': 115}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-04-06T04:21:10',
#              'surface_temperature_celcius': 96}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-06T04:21:30',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-04-06T04:22:10',
#              'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-04-06T04:22:10',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-04-06T04:22:10',
#              'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'hotspot': {'confidence': 91,
# ...
#              'datetime': '2018-10-15T04:23:01',
#              'surface_temperature_celcius': 85}}
# {'_id': ObjectId('60a958a49343696505cf47e3'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-10-15T04:23:01',
#              'surface_temperature_celcius': 87}}
# {'_id': ObjectId('60a958a49343696505cf47e5'),
#  'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-10-17T04:10:32',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf47e5'),
#  'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 91,
#              'datetime': '2018-10-17T04:10:45',
#              'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60a958a49343696505cf47e5'),
#  'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-10-17T13:36:12',
#              'surface_temperature_celcius': 43}}
# {'_id': ObjectId('60a958a49343696505cf47e6'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-10-18T00:39:02',
#              'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60a958a49343696505cf47e6'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-10-18T00:39:02',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf47e8'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-10-20T04:41:19',
#              'surface_temperature_celcius': 50}}
# {'_id': ObjectId('60a958a49343696505cf47e8'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-10-20T04:41:19',
#              'surface_temperature_celcius': 46}}
# {'_id': ObjectId('60a958a49343696505cf47e9'),
#  'air_temperature_celcius': 12,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-10-21T01:09:54',
#              'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60a958a49343696505cf47e9'),
#  'air_temperature_celcius': 12,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-10-21T01:09:55',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf47ee'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-10-26T13:30:31',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf47ee'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-10-26T13:30:31',
#              'surface_temperature_celcius': 48}}
# {'_id': ObjectId('60a958a49343696505cf47ef'),
#  'air_temperature_celcius': 22,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-10-27T04:47:31',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf47f0'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-10-28T03:52:17',
#              'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60a958a49343696505cf47f8'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-11-05T04:41:19',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf47f8'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-11-05T04:41:19',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf47f8'),
#  'air_temperature_celcius': 13,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-11-05T04:41:34',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-11-09T04:16:44',
#              'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-11-09T04:16:44',
#              'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 96,
#              'datetime': '2018-11-09T04:16:48',
#              'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-09T04:16:48',
#              'surface_temperature_celcius': 93}}
# {'_id': ObjectId('60a958a49343696505cf47fc'),
#  'air_temperature_celcius': 14,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-11-09T04:16:48',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf47fe'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-11-11T04:04:25',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf47fe'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-11T13:30:08',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf47fe'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-11-11T13:30:08',
#              'surface_temperature_celcius': 37}}
# {'_id': ObjectId('60a958a49343696505cf47ff'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 89,
#              'datetime': '2018-11-12T00:33:15',
#              'surface_temperature_celcius': 69}}
# {'_id': ObjectId('60a958a49343696505cf4800'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-11-13T03:52:14',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf4800'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-11-13T03:52:15',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4801'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-11-14T04:35:04',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4808'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 85,
#              'datetime': '2018-11-21T00:27:21',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4809'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 88,
#              'datetime': '2018-11-22T03:46:00',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4809'),
#  'air_temperature_celcius': 23,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-11-22T03:46:00',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf480a'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-11-23T04:28:59',
#              'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60a958a49343696505cf480a'),
#  'air_temperature_celcius': 24,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-11-23T04:28:59',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 99,
#              'datetime': '2018-11-29T03:52:10',
#              'surface_temperature_celcius': 84}}
# {'_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 97,
#              'datetime': '2018-11-29T03:52:10',
#              'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-29T03:52:10',
#              'surface_temperature_celcius': 87}}
# {'_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-29T13:17:24',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-11-30T00:20:53',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-11-30T00:20:53',
#              'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-11-30T00:20:53',
#              'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-11-30T00:20:53',
#              'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-11-30T00:20:53',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 99,
#              'datetime': '2018-11-30T04:34:57',
#              'surface_temperature_celcius': 86}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-11-30T04:34:57',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-11-30T04:34:57',
#              'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 98,
#              'datetime': '2018-11-30T04:34:57',
#              'surface_temperature_celcius': 83}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-11-30T04:35:00',
#              'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-30T12:22:14',
#              'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-30T12:22:15',
#              'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-30T12:22:15',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-11-30T12:22:15',
#              'surface_temperature_celcius': 42}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-11-30T12:22:15',
#              'surface_temperature_celcius': 38}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-30T15:38:35',
#              'surface_temperature_celcius': 49}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-30T15:38:35',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-11-30T15:38:36',
#              'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60a958a49343696505cf4819'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-12-08T13:11:43',
#              'surface_temperature_celcius': 52}}
# {'_id': ObjectId('60a958a49343696505cf4819'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-12-08T13:11:44',
#              'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60a958a49343696505cf4819'),
#  'air_temperature_celcius': 15,
#  'hotspot': {'confidence': 100,
#              'datetime': '2018-12-08T13:11:44',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf481a'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-12-09T00:14:33',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf481a'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-12-09T00:14:33',
#              'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60a958a49343696505cf481a'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 81,
#              'datetime': '2018-12-09T00:14:34',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf481a'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 87,
#              'datetime': '2018-12-09T00:14:34',
#              'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60a958a49343696505cf481e'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 83,
#              'datetime': '2018-12-13T04:04:19',
#              'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60a958a49343696505cf481f'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-12-14T04:47:25',
#              'surface_temperature_celcius': 70}}
# {'_id': ObjectId('60a958a49343696505cf4820'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 92,
#              'datetime': '2018-12-15T13:17:17',
#              'surface_temperature_celcius': 42}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-12-16T00:20:53',
#              'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-12-16T00:21:11',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-12-16T00:21:12',
#              'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 90,
#              'datetime': '2018-12-16T04:34:57',
#              'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 95,
#              'datetime': '2018-12-16T04:34:58',
#              'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 84,
#              'datetime': '2018-12-16T04:34:58',
#              'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 93,
#              'datetime': '2018-12-16T04:35:13',
#              'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'hotspot': {'confidence': 94,
#              'datetime': '2018-12-16T15:38:39',
#              'surface_temperature_celcius': 43}}
# {'_id': ObjectId('60a958a49343696505cf482a'),
#  'air_temperature_celcius': 17,
#  'hotspot': {'confidence': 80,
#              'datetime': '2018-12-25T04:29:08',
#              'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60a958a49343696505cf482c'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 86,
#              'datetime': '2018-12-27T00:02:14',
#              'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60a958a49343696505cf482c'),
#  'air_temperature_celcius': 28,
#  'hotspot': {'confidence': 82,
#              'datetime': '2018-12-27T00:02:15',
#              'surface_temperature_celcius': 63}}

# %%
#e
"""
Find the top 10 records with the highest surface temperature (°C)
"""
pipeline = [
    {"$unwind": "$hotspot"},
    {"$sort": {"hotspot.surface_temperature_celcius": -1}},
    {"$limit":10}

]

cursor = collection.aggregate(pipeline)
for document in cursor: 
    pprint(document)
# Out:
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60a958a49343696505cf472f'),
#  'air_temperature_celcius': 15,
#  'date': '18/4/2018',
#  'hotspot': {'confidence': 100,
#              'date': '18/4/2018',
#              'datetime': '2018-04-18T04:52:00',
#              'latitude': -38.1665,
#              'longitude': 143.062,
#              'surface_temperature_celcius': 124},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 100,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:50',
#              'latitude': -36.343,
#              'longitude': 142.1986,
#              'surface_temperature_celcius': 123},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 121,
#  '_id': ObjectId('60a958a49343696505cf473c'),
#  'air_temperature_celcius': 14,
#  'date': '1/5/2018',
#  'hotspot': {'confidence': 100,
#              'date': '1/5/2018',
#              'datetime': '2018-05-01T04:14:20',
#              'latitude': -36.9318,
#              'longitude': 143.0907,
#              'surface_temperature_celcius': 122},
#  'max_wind_speed': 20.0,
#  'precip_flag': 'G',
#  'precipitation': 0.12,
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('60a958a49343696505cf4710'),
#  'air_temperature_celcius': 21,
#  'date': '18/3/2018',
#  'hotspot': {'confidence': 100,
#              'date': '18/3/2018',
#              'datetime': '2018-03-18T03:50:50',
#              'latitude': -37.017,
#              'longitude': 148.1297,
#              'surface_temperature_celcius': 121},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 100,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:40',
#              'latitude': -36.3521,
#              'longitude': 142.2008,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 81,
#  '_id': ObjectId('60a958a49343696505cf4748'),
#  'air_temperature_celcius': 9,
#  'date': '13/5/2018',
#  'hotspot': {'confidence': 100,
#              'date': '13/5/2018',
#              'datetime': '2018-05-13T04:40:20',
#              'latitude': -34.9938,
#              'longitude': 141.876,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 8.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60a958a49343696505cf472f'),
#  'air_temperature_celcius': 15,
#  'date': '18/4/2018',
#  'hotspot': {'confidence': 100,
#              'date': '18/4/2018',
#              'datetime': '2018-04-18T04:44:50',
#              'latitude': -37.8326,
#              'longitude': 143.4999,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 132,
#  '_id': ObjectId('60a958a49343696505cf472a'),
#  'air_temperature_celcius': 16,
#  'date': '13/4/2018',
#  'hotspot': {'confidence': 100,
#              'date': '13/4/2018',
#              'datetime': '2018-04-13T04:28:10',
#              'latitude': -37.0745,
#              'longitude': 141.0692,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 100,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:40:00',
#              'latitude': -36.1057,
#              'longitude': 141.7608,
#              'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('60a958a49343696505cf473f'),
#  'air_temperature_celcius': 10,
#  'date': '4/5/2018',
#  'hotspot': {'confidence': 100,
#              'date': '4/5/2018',
#              'datetime': '2018-05-04T04:44:50',
#              'latitude': -36.4057,
#              'longitude': 140.9806,
#              'surface_temperature_celcius': 119},
#  'max_wind_speed': 7.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %%
#f
"""
Find the number of fires each day. You are required to only display the total
number of fires and the date in the output
"""
pipeline = [
    {"$project": {"date":1,"hotspots":{"$size":"$hotspot"},"_id":0}},
]
#results = collection.aggregate([{"$group":{"$count":{"$hotspot":1}}}])

#cursor = collection.aggregate(pipeline)
#for document in cursor: 
#    pprint(document)
results = collection.aggregate(pipeline)
for document in results:
    pprint(document)
# Out:
# {'date': '31/12/2017', 'hotspots': 0}
# {'date': '2/1/2018', 'hotspots': 0}
# {'date': '3/1/2018', 'hotspots': 0}
# {'date': '4/1/2018', 'hotspots': 0}
# {'date': '5/1/2018', 'hotspots': 0}
# {'date': '6/1/2018', 'hotspots': 0}
# {'date': '7/1/2018', 'hotspots': 0}
# {'date': '8/1/2018', 'hotspots': 0}
# {'date': '9/1/2018', 'hotspots': 0}
# {'date': '10/1/2018', 'hotspots': 0}
# {'date': '11/1/2018', 'hotspots': 0}
# {'date': '12/1/2018', 'hotspots': 0}
# {'date': '13/1/2018', 'hotspots': 0}
# {'date': '14/1/2018', 'hotspots': 0}
# {'date': '15/1/2018', 'hotspots': 0}
# {'date': '16/1/2018', 'hotspots': 0}
# {'date': '17/1/2018', 'hotspots': 0}
# {'date': '18/1/2018', 'hotspots': 0}
# {'date': '19/1/2018', 'hotspots': 0}
# {'date': '20/1/2018', 'hotspots': 0}
# {'date': '21/1/2018', 'hotspots': 0}
# {'date': '22/1/2018', 'hotspots': 0}
# {'date': '23/1/2018', 'hotspots': 0}
# {'date': '24/1/2018', 'hotspots': 0}
# {'date': '25/1/2018', 'hotspots': 0}
# {'date': '26/1/2018', 'hotspots': 0}
# {'date': '27/1/2018', 'hotspots': 0}
# {'date': '28/1/2018', 'hotspots': 0}
# {'date': '29/1/2018', 'hotspots': 0}
# {'date': '30/1/2018', 'hotspots': 0}
# {'date': '31/1/2018', 'hotspots': 0}
# {'date': '1/2/2018', 'hotspots': 0}
# {'date': '2/2/2018', 'hotspots': 0}
# {'date': '3/2/2018', 'hotspots': 0}
# {'date': '4/2/2018', 'hotspots': 0}
# {'date': '5/2/2018', 'hotspots': 0}
# {'date': '6/2/2018', 'hotspots': 0}
# {'date': '7/2/2018', 'hotspots': 0}
# {'date': '8/2/2018', 'hotspots': 0}
# {'date': '9/2/2018', 'hotspots': 0}
# {'date': '10/2/2018', 'hotspots': 0}
# {'date': '11/2/2018', 'hotspots': 0}
# {'date': '12/2/2018', 'hotspots': 0}
# {'date': '13/2/2018', 'hotspots': 0}
# {'date': '14/2/2018', 'hotspots': 0}
# {'date': '15/2/2018', 'hotspots': 0}
# {'date': '16/2/2018', 'hotspots': 0}
# {'date': '17/2/2018', 'hotspots': 0}
# {'date': '18/2/2018', 'hotspots': 0}
# {'date': '19/2/2018', 'hotspots': 0}
# {'date': '20/2/2018', 'hotspots': 0}
# {'date': '21/2/2018', 'hotspots': 0}
# {'date': '22/2/2018', 'hotspots': 0}
# {'date': '23/2/2018', 'hotspots': 0}
# {'date': '24/2/2018', 'hotspots': 0}
# {'date': '25/2/2018', 'hotspots': 0}
# {'date': '26/2/2018', 'hotspots': 0}
# {'date': '27/2/2018', 'hotspots': 0}
# {'date': '28/2/2018', 'hotspots': 0}
# {'date': '1/3/2018', 'hotspots': 0}
# {'date': '2/3/2018', 'hotspots': 0}
# {'date': '3/3/2018', 'hotspots': 0}
# {'date': '4/3/2018', 'hotspots': 0}
# {'date': '5/3/2018', 'hotspots': 0}
# {'date': '6/3/2018', 'hotspots': 2}
# {'date': '7/3/2018', 'hotspots': 1}
# {'date': '8/3/2018', 'hotspots': 2}
# {'date': '9/3/2018', 'hotspots': 3}
# {'date': '10/3/2018', 'hotspots': 8}
# {'date': '11/3/2018', 'hotspots': 0}
# {'date': '12/3/2018', 'hotspots': 5}
# {'date': '13/3/2018', 'hotspots': 2}
# {'date': '14/3/2018', 'hotspots': 10}
# {'date': '15/3/2018', 'hotspots': 7}
# {'date': '16/3/2018', 'hotspots': 0}
# {'date': '17/3/2018', 'hotspots': 6}
# {'date': '18/3/2018', 'hotspots': 3}
# {'date': '19/3/2018', 'hotspots': 21}
# {'date': '20/3/2018', 'hotspots': 0}
# {'date': '21/3/2018', 'hotspots': 0}
# {'date': '22/3/2018', 'hotspots': 0}
# {'date': '23/3/2018', 'hotspots': 0}
# {'date': '24/3/2018', 'hotspots': 2}
# {'date': '25/3/2018', 'hotspots': 13}
# {'date': '26/3/2018', 'hotspots': 17}
# {'date': '27/3/2018', 'hotspots': 0}
# {'date': '28/3/2018', 'hotspots': 54}
# {'date': '29/3/2018', 'hotspots': 1}
# {'date': '30/3/2018', 'hotspots': 0}
# {'date': '31/3/2018', 'hotspots': 22}
# {'date': '1/4/2018', 'hotspots': 7}
# {'date': '2/4/2018', 'hotspots': 5}
# {'date': '3/4/2018', 'hotspots': 72}
# {'date': '4/4/2018', 'hotspots': 89}
# {'date': '5/4/2018', 'hotspots': 49}
# {'date': '6/4/2018', 'hotspots': 118}
# {'date': '7/4/2018', 'hotspots': 39}
# {'date': '8/4/2018', 'hotspots': 20}
# {'date': '9/4/2018', 'hotspots': 0}
# {'date': '10/4/2018', 'hotspots': 0}
# {'date': '11/4/2018', 'hotspots': 24}
# {'date': '12/4/2018', 'hotspots': 69}
# {'date': '13/4/2018', 'hotspots': 357}
# {'date': '14/4/2018', 'hotspots': 18}
# {'date': '15/4/2018', 'hotspots': 69}
# {'date': '16/4/2018', 'hotspots': 18}
# {'date': '17/4/2018', 'hotspots': 38}
# {'date': '18/4/2018', 'hotspots': 325}
# {'date': '19/4/2018', 'hotspots': 50}
# {'date': '20/4/2018', 'hotspots': 31}
# {'date': '21/4/2018', 'hotspots': 0}
# {'date': '22/4/2018', 'hotspots': 2}
# {'date': '23/4/2018', 'hotspots': 19}
# {'date': '24/4/2018', 'hotspots': 8}
# {'date': '25/4/2018', 'hotspots': 3}
# {'date': '26/4/2018', 'hotspots': 1}
# {'date': '27/4/2018', 'hotspots': 0}
# {'date': '28/4/2018', 'hotspots': 0}
# {'date': '29/4/2018', 'hotspots': 3}
# {'date': '30/4/2018', 'hotspots': 0}
# {'date': '1/5/2018', 'hotspots': 20}
# {'date': '2/5/2018', 'hotspots': 10}
# {'date': '3/5/2018', 'hotspots': 64}
# {'date': '4/5/2018', 'hotspots': 135}
# {'date': '5/5/2018', 'hotspots': 31}
# {'date': '6/5/2018', 'hotspots': 17}
# {'date': '7/5/2018', 'hotspots': 3}
# {'date': '8/5/2018', 'hotspots': 24}
# {'date': '9/5/2018', 'hotspots': 13}
# {'date': '10/5/2018', 'hotspots': 114}
# {'date': '11/5/2018', 'hotspots': 19}
# {'date': '12/5/2018', 'hotspots': 10}
# {'date': '13/5/2018', 'hotspots': 54}
# {'date': '14/5/2018', 'hotspots': 1}
# {'date': '15/5/2018', 'hotspots': 102}
# {'date': '16/5/2018', 'hotspots': 3}
# {'date': '17/5/2018', 'hotspots': 1}
# {'date': '18/5/2018', 'hotspots': 7}
# {'date': '19/5/2018', 'hotspots': 0}
# {'date': '20/5/2018', 'hotspots': 0}
# {'date': '21/5/2018', 'hotspots': 0}
# {'date': '22/5/2018', 'hotspots': 33}
# {'date': '23/5/2018', 'hotspots': 5}
# {'date': '24/5/2018', 'hotspots': 3}
# {'date': '25/5/2018', 'hotspots': 0}
# {'date': '26/5/2018', 'hotspots': 4}
# {'date': '27/5/2018', 'hotspots': 0}
# {'date': '28/5/2018', 'hotspots': 0}
# {'date': '29/5/2018', 'hotspots': 0}
# {'date': '30/5/2018', 'hotspots': 0}
# {'date': '31/5/2018', 'hotspots': 0}
# {'date': '1/6/2018', 'hotspots': 2}
# {'date': '2/6/2018', 'hotspots': 11}
# {'date': '3/6/2018', 'hotspots': 2}
# {'date': '4/6/2018', 'hotspots': 9}
# {'date': '5/6/2018', 'hotspots': 0}
# {'date': '6/6/2018', 'hotspots': 0}
# {'date': '7/6/2018', 'hotspots': 14}
# {'date': '8/6/2018', 'hotspots': 0}
# {'date': '9/6/2018', 'hotspots': 3}
# {'date': '10/6/2018', 'hotspots': 0}
# {'date': '11/6/2018', 'hotspots': 2}
# {'date': '12/6/2018', 'hotspots': 0}
# {'date': '13/6/2018', 'hotspots': 1}
# {'date': '14/6/2018', 'hotspots': 4}
# {'date': '15/6/2018', 'hotspots': 0}
# {'date': '16/6/2018', 'hotspots': 2}
# {'date': '17/6/2018', 'hotspots': 0}
# {'date': '18/6/2018', 'hotspots': 2}
# {'date': '19/6/2018', 'hotspots': 0}
# {'date': '20/6/2018', 'hotspots': 6}
# {'date': '21/6/2018', 'hotspots': 0}
# {'date': '22/6/2018', 'hotspots': 1}
# {'date': '23/6/2018', 'hotspots': 0}
# {'date': '24/6/2018', 'hotspots': 0}
# {'date': '25/6/2018', 'hotspots': 0}
# {'date': '26/6/2018', 'hotspots': 0}
# {'date': '27/6/2018', 'hotspots': 0}
# {'date': '28/6/2018', 'hotspots': 0}
# {'date': '29/6/2018', 'hotspots': 0}
# {'date': '30/6/2018', 'hotspots': 6}
# {'date': '1/7/2018', 'hotspots': 4}
# {'date': '2/7/2018', 'hotspots': 8}
# {'date': '3/7/2018', 'hotspots': 0}
# {'date': '4/7/2018', 'hotspots': 1}
# {'date': '5/7/2018', 'hotspots': 1}
# {'date': '6/7/2018', 'hotspots': 3}
# {'date': '7/7/2018', 'hotspots': 0}
# {'date': '8/7/2018', 'hotspots': 0}
# {'date': '9/7/2018', 'hotspots': 0}
# {'date': '10/7/2018', 'hotspots': 0}
# {'date': '11/7/2018', 'hotspots': 0}
# {'date': '12/7/2018', 'hotspots': 0}
# {'date': '13/7/2018', 'hotspots': 0}
# {'date': '14/7/2018', 'hotspots': 2}
# {'date': '15/7/2018', 'hotspots': 0}
# {'date': '16/7/2018', 'hotspots': 0}
# {'date': '17/7/2018', 'hotspots': 0}
# {'date': '18/7/2018', 'hotspots': 0}
# {'date': '19/7/2018', 'hotspots': 0}
# {'date': '20/7/2018', 'hotspots': 0}
# {'date': '21/7/2018', 'hotspots': 0}
# {'date': '22/7/2018', 'hotspots': 0}
# {'date': '23/7/2018', 'hotspots': 0}
# {'date': '24/7/2018', 'hotspots': 0}
# {'date': '25/7/2018', 'hotspots': 0}
# {'date': '26/7/2018', 'hotspots': 0}
# {'date': '27/7/2018', 'hotspots': 0}
# {'date': '28/7/2018', 'hotspots': 0}
# {'date': '29/7/2018', 'hotspots': 2}
# {'date': '30/7/2018', 'hotspots': 0}
# {'date': '31/7/2018', 'hotspots': 2}
# {'date': '1/8/2018', 'hotspots': 2}
# {'date': '2/8/2018', 'hotspots': 2}
# {'date': '3/8/2018', 'hotspots': 0}
# {'date': '4/8/2018', 'hotspots': 0}
# {'date': '5/8/2018', 'hotspots': 1}
# {'date': '6/8/2018', 'hotspots': 0}
# {'date': '7/8/2018', 'hotspots': 0}
# {'date': '8/8/2018', 'hotspots': 0}
# {'date': '9/8/2018', 'hotspots': 0}
# {'date': '10/8/2018', 'hotspots': 1}
# {'date': '11/8/2018', 'hotspots': 0}
# {'date': '12/8/2018', 'hotspots': 0}
# {'date': '13/8/2018', 'hotspots': 9}
# {'date': '14/8/2018', 'hotspots': 5}
# {'date': '15/8/2018', 'hotspots': 0}
# {'date': '16/8/2018', 'hotspots': 0}
# {'date': '17/8/2018', 'hotspots': 0}
# {'date': '18/8/2018', 'hotspots': 0}
# {'date': '19/8/2018', 'hotspots': 0}
# {'date': '20/8/2018', 'hotspots': 0}
# {'date': '21/8/2018', 'hotspots': 0}
# {'date': '22/8/2018', 'hotspots': 0}
# {'date': '23/8/2018', 'hotspots': 0}
# {'date': '24/8/2018', 'hotspots': 0}
# {'date': '25/8/2018', 'hotspots': 0}
# {'date': '26/8/2018', 'hotspots': 0}
# {'date': '27/8/2018', 'hotspots': 0}
# {'date': '28/8/2018', 'hotspots': 0}
# {'date': '29/8/2018', 'hotspots': 0}
# {'date': '30/8/2018', 'hotspots': 0}
# {'date': '31/8/2018', 'hotspots': 0}
# {'date': '1/9/2018', 'hotspots': 0}
# {'date': '2/9/2018', 'hotspots': 0}
# {'date': '3/9/2018', 'hotspots': 0}
# {'date': '4/9/2018', 'hotspots': 0}
# {'date': '5/9/2018', 'hotspots': 0}
# {'date': '6/9/2018', 'hotspots': 0}
# {'date': '7/9/2018', 'hotspots': 0}
# {'date': '8/9/2018', 'hotspots': 0}
# {'date': '9/9/2018', 'hotspots': 0}
# {'date': '10/9/2018', 'hotspots': 4}
# {'date': '11/9/2018', 'hotspots': 0}
# {'date': '12/9/2018', 'hotspots': 0}
# {'date': '13/9/2018', 'hotspots': 0}
# {'date': '14/9/2018', 'hotspots': 0}
# {'date': '15/9/2018', 'hotspots': 0}
# {'date': '16/9/2018', 'hotspots': 0}
# {'date': '17/9/2018', 'hotspots': 0}
# {'date': '18/9/2018', 'hotspots': 0}
# {'date': '19/9/2018', 'hotspots': 0}
# {'date': '20/9/2018', 'hotspots': 5}
# {'date': '21/9/2018', 'hotspots': 2}
# {'date': '22/9/2018', 'hotspots': 1}
# {'date': '23/9/2018', 'hotspots': 23}
# {'date': '24/9/2018', 'hotspots': 28}
# {'date': '25/9/2018', 'hotspots': 0}
# {'date': '26/9/2018', 'hotspots': 1}
# {'date': '27/9/2018', 'hotspots': 7}
# {'date': '28/9/2018', 'hotspots': 0}
# {'date': '29/9/2018', 'hotspots': 2}
# {'date': '30/9/2018', 'hotspots': 0}
# {'date': '1/10/2018', 'hotspots': 8}
# {'date': '2/10/2018', 'hotspots': 7}
# {'date': '3/10/2018', 'hotspots': 18}
# {'date': '4/10/2018', 'hotspots': 5}
# {'date': '5/10/2018', 'hotspots': 0}
# {'date': '6/10/2018', 'hotspots': 2}
# {'date': '7/10/2018', 'hotspots': 1}
# {'date': '8/10/2018', 'hotspots': 1}
# {'date': '9/10/2018', 'hotspots': 1}
# {'date': '10/10/2018', 'hotspots': 3}
# {'date': '11/10/2018', 'hotspots': 0}
# {'date': '12/10/2018', 'hotspots': 0}
# {'date': '13/10/2018', 'hotspots': 0}
# {'date': '14/10/2018', 'hotspots': 0}
# {'date': '15/10/2018', 'hotspots': 3}
# {'date': '16/10/2018', 'hotspots': 1}
# {'date': '17/10/2018', 'hotspots': 5}
# {'date': '18/10/2018', 'hotspots': 6}
# {'date': '19/10/2018', 'hotspots': 0}
# {'date': '20/10/2018', 'hotspots': 3}
# {'date': '21/10/2018', 'hotspots': 4}
# {'date': '22/10/2018', 'hotspots': 0}
# {'date': '23/10/2018', 'hotspots': 1}
# {'date': '24/10/2018', 'hotspots': 0}
# {'date': '25/10/2018', 'hotspots': 0}
# {'date': '26/10/2018', 'hotspots': 5}
# {'date': '27/10/2018', 'hotspots': 5}
# {'date': '28/10/2018', 'hotspots': 1}
# {'date': '29/10/2018', 'hotspots': 0}
# {'date': '30/10/2018', 'hotspots': 0}
# {'date': '31/10/2018', 'hotspots': 0}
# {'date': '1/11/2018', 'hotspots': 0}
# {'date': '2/11/2018', 'hotspots': 0}
# {'date': '3/11/2018', 'hotspots': 0}
# {'date': '4/11/2018', 'hotspots': 0}
# {'date': '5/11/2018', 'hotspots': 4}
# {'date': '6/11/2018', 'hotspots': 0}
# {'date': '7/11/2018', 'hotspots': 0}
# {'date': '8/11/2018', 'hotspots': 2}
# {'date': '9/11/2018', 'hotspots': 10}
# {'date': '10/11/2018', 'hotspots': 0}
# {'date': '11/11/2018', 'hotspots': 4}
# {'date': '12/11/2018', 'hotspots': 5}
# {'date': '13/11/2018', 'hotspots': 5}
# {'date': '14/11/2018', 'hotspots': 3}
# {'date': '15/11/2018', 'hotspots': 0}
# {'date': '16/11/2018', 'hotspots': 0}
# {'date': '17/11/2018', 'hotspots': 0}
# {'date': '18/11/2018', 'hotspots': 0}
# {'date': '19/11/2018', 'hotspots': 0}
# {'date': '20/11/2018', 'hotspots': 0}
# {'date': '21/11/2018', 'hotspots': 1}
# {'date': '22/11/2018', 'hotspots': 2}
# {'date': '23/11/2018', 'hotspots': 5}
# {'date': '24/11/2018', 'hotspots': 0}
# {'date': '25/11/2018', 'hotspots': 0}
# {'date': '26/11/2018', 'hotspots': 0}
# {'date': '27/11/2018', 'hotspots': 0}
# {'date': '28/11/2018', 'hotspots': 1}
# {'date': '29/11/2018', 'hotspots': 8}
# {'date': '30/11/2018', 'hotspots': 31}
# {'date': '1/12/2018', 'hotspots': 0}
# {'date': '2/12/2018', 'hotspots': 0}
# {'date': '3/12/2018', 'hotspots': 0}
# {'date': '4/12/2018', 'hotspots': 0}
# {'date': '5/12/2018', 'hotspots': 0}
# {'date': '6/12/2018', 'hotspots': 0}
# {'date': '7/12/2018', 'hotspots': 0}
# {'date': '8/12/2018', 'hotspots': 5}
# {'date': '9/12/2018', 'hotspots': 4}
# {'date': '10/12/2018', 'hotspots': 2}
# {'date': '11/12/2018', 'hotspots': 0}
# {'date': '12/12/2018', 'hotspots': 1}
# {'date': '13/12/2018', 'hotspots': 1}
# {'date': '14/12/2018', 'hotspots': 1}
# {'date': '15/12/2018', 'hotspots': 4}
# {'date': '16/12/2018', 'hotspots': 15}
# {'date': '17/12/2018', 'hotspots': 0}
# {'date': '18/12/2018', 'hotspots': 0}
# {'date': '19/12/2018', 'hotspots': 0}
# {'date': '20/12/2018', 'hotspots': 0}
# {'date': '21/12/2018', 'hotspots': 1}
# {'date': '22/12/2018', 'hotspots': 0}
# {'date': '23/12/2018', 'hotspots': 0}
# {'date': '24/12/2018', 'hotspots': 1}
# {'date': '25/12/2018', 'hotspots': 1}
# {'date': '26/12/2018', 'hotspots': 0}
# {'date': '27/12/2018', 'hotspots': 4}
# {'date': '28/12/2018', 'hotspots': 0}
# {'date': '29/12/2018', 'hotspots': 0}
# {'date': '30/12/2018', 'hotspots': 0}
# {'date': '31/12/2018', 'hotspots': 0}
# {'date': '1/1/2018', 'hotspots': 0}

# %%
#g
"""
Find the records of fires where the confidence is below 70.
"""
pipeline = [
    {"$unwind": "$hotspot"},
    {"$match": {"hotspot.confidence":{"$lt":70}}},
]

cursor = collection.aggregate(pipeline)
for document in cursor: 
    pprint(document)
# Out:
# {'GHI_w/m2': 177,
#  '_id': ObjectId('60a958a49343696505cf4706'),
#  'air_temperature_celcius': 21,
#  'date': '8/3/2018',
#  'hotspot': {'confidence': 68,
#              'date': '8/3/2018',
#              'datetime': '2018-03-08T04:51:00',
#              'latitude': -37.7885,
#              'longitude': 141.9352,
#              'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 192,
#  '_id': ObjectId('60a958a49343696505cf4707'),
#  'air_temperature_celcius': 23,
#  'date': '9/3/2018',
#  'hotspot': {'confidence': 54,
#              'date': '9/3/2018',
#              'datetime': '2018-03-09T03:57:00',
#              'latitude': -37.7171,
#              'longitude': 147.5866,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4708'),
#  'air_temperature_celcius': 19,
#  'date': '10/3/2018',
#  'hotspot': {'confidence': 54,
#              'date': '10/3/2018',
#              'datetime': '2018-03-10T04:42:30',
#              'latitude': -37.2197,
#              'longitude': 147.9621,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4708'),
#  'air_temperature_celcius': 19,
#  'date': '10/3/2018',
#  'hotspot': {'confidence': 55,
#              'date': '10/3/2018',
#              'datetime': '2018-03-10T04:43:00',
#              'latitude': -36.2544,
#              'longitude': 148.0353,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60a958a49343696505cf470b'),
#  'air_temperature_celcius': 20,
#  'date': '13/3/2018',
#  'hotspot': {'confidence': 52,
#              'date': '13/3/2018',
#              'datetime': '2018-03-13T12:57:00',
#              'latitude': -37.0316,
#              'longitude': 148.1519,
#              'surface_temperature_celcius': 35},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60a958a49343696505cf470b'),
#  'air_temperature_celcius': 20,
#  'date': '13/3/2018',
#  'hotspot': {'confidence': 56,
#              'date': '13/3/2018',
#              'datetime': '2018-03-13T23:58:50',
#              'latitude': -37.0286,
#              'longitude': 148.155,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60a958a49343696505cf470d'),
#  'air_temperature_celcius': 28,
#  'date': '15/3/2018',
#  'hotspot': {'confidence': 51,
#              'date': '15/3/2018',
#              'datetime': '2018-03-15T00:42:40',
#              'latitude': -37.002,
#              'longitude': 148.2055,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 18.1,
#  'precip_flag': 'G',
#  'precipitation': 0.04,
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60a958a49343696505cf470d'),
#  'air_temperature_celcius': 28,
#  'date': '15/3/2018',
#  'hotspot': {'confidence': 66,
#              'date': '15/3/2018',
#              'datetime': '2018-03-15T00:42:50',
#              'latitude': -37.0228,
#              'longitude': 148.1281,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 18.1,
#  'precip_flag': 'G',
#  'precipitation': 0.04,
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60a958a49343696505cf470d'),
#  'air_temperature_celcius': 28,
#  'date': '15/3/2018',
#  'hotspot': {'confidence': 52,
#              'date': '15/3/2018',
#              'datetime': '2018-03-15T00:42:50',
#              'latitude': -37.4075,
#              'longitude': 147.0233,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 18.1,
#  'precip_flag': 'G',
#  'precipitation': 0.04,
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('60a958a49343696505cf4710'),
#  'air_temperature_celcius': 21,
#  'date': '18/3/2018',
#  'hotspot': {'confidence': 64,
#              'date': '18/3/2018',
#              'datetime': '2018-03-18T13:16:50',
#              'latitude': -37.4313,
#              'longitude': 147.0343,
#              'surface_temperature_celcius': 37},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 60,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T00:12:50',
#              'latitude': -37.3942,
#              'longitude': 147.0455,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 66,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:32:50',
#              'latitude': -37.9277,
#              'longitude': 143.477,
#              'surface_temperature_celcius': 55},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 61,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:33:10',
#              'latitude': -37.3911,
#              'longitude': 147.037,
#              'surface_temperature_celcius': 50},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 53,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:33:30',
#              'latitude': -37.9184,
#              'longitude': 143.4745,
#              'surface_temperature_celcius': 55},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 61,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:33:30',
#              'latitude': -37.4003,
#              'longitude': 147.0448,
#              'surface_temperature_celcius': 55},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 60,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:33:50',
#              'latitude': -37.4336,
#              'longitude': 147.0534,
#              'surface_temperature_celcius': 51},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 59,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:35:00',
#              'latitude': -37.4023,
#              'longitude': 147.0394,
#              'surface_temperature_celcius': 56},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 64,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:36:00',
#              'latitude': -37.3982,
#              'longitude': 147.0001,
#              'surface_temperature_celcius': 58},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 63,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:39:20',
#              'latitude': -37.9257,
#              'longitude': 143.4891,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60a958a49343696505cf4711'),
#  'air_temperature_celcius': 24,
#  'date': '19/3/2018',
#  'hotspot': {'confidence': 58,
#              'date': '19/3/2018',
#              'datetime': '2018-03-19T04:39:20',
#              'latitude': -37.9164,
#              'longitude': 143.4866,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60a958a49343696505cf4716'),
#  'air_temperature_celcius': 20,
#  'date': '24/3/2018',
#  'hotspot': {'confidence': 55,
#              'date': '24/3/2018',
#              'datetime': '2018-03-24T04:56:10',
#              'latitude': -37.1684,
#              'longitude': 142.8183,
#              'surface_temperature_celcius': 48},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60a958a49343696505cf4716'),
#  'air_temperature_celcius': 20,
#  'date': '24/3/2018',
#  'hotspot': {'confidence': 65,
#              'date': '24/3/2018',
#              'datetime': '2018-03-24T04:58:00',
#              'latitude': -37.1603,
#              'longitude': 142.8088,
#              'surface_temperature_celcius': 50},
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'date': '25/3/2018',
#  'hotspot': {'confidence': 57,
#              'date': '25/3/2018',
#              'datetime': '2018-03-25T03:56:40',
#              'latitude': -37.9022,
#              'longitude': 143.4607,
#              'surface_temperature_celcius': 57},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('60a958a49343696505cf4717'),
#  'air_temperature_celcius': 23,
#  'date': '25/3/2018',
#  'hotspot': {'confidence': 62,
#              'date': '25/3/2018',
#              'datetime': '2018-03-25T04:03:10',
#              'latitude': -37.8992,
#              'longitude': 143.4534,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'date': '26/3/2018',
#  'hotspot': {'confidence': 67,
#              'date': '26/3/2018',
#              'datetime': '2018-03-26T04:39:10',
#              'latitude': -37.1956,
#              'longitude': 141.0252,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 26.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'date': '26/3/2018',
#  'hotspot': {'confidence': 60,
#              'date': '26/3/2018',
#              'datetime': '2018-03-26T04:39:10',
#              'latitude': -37.8469,
#              'longitude': 143.5343,
#              'surface_temperature_celcius': 50},
#  'max_wind_speed': 26.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('60a958a49343696505cf4718'),
#  'air_temperature_celcius': 23,
#  'date': '26/3/2018',
#  'hotspot': {'confidence': 68,
#              'date': '26/3/2018',
#              'datetime': '2018-03-26T04:41:10',
#              'latitude': -38.1131,
#              'longitude': 143.7173,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 26.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'date': '28/3/2018',
#  'hotspot': {'confidence': 55,
#              'date': '28/3/2018',
#              'datetime': '2018-03-28T04:26:50',
#              'latitude': -34.342,
#              'longitude': 141.6548,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'date': '28/3/2018',
#  'hotspot': {'confidence': 69,
#              'date': '28/3/2018',
#              'datetime': '2018-03-28T04:26:50',
#              'latitude': -36.4422,
#              'longitude': 141.4172,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'date': '28/3/2018',
#  'hotspot': {'confidence': 63,
#              'date': '28/3/2018',
#              'datetime': '2018-03-28T04:26:50',
#              'latitude': -37.6376,
#              'longitude': 143.4255,
#              'surface_temperature_celcius': 48},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60a958a49343696505cf471a'),
#  'air_temperature_celcius': 18,
#  'date': '28/3/2018',
#  'hotspot': {'confidence': 53,
#              'date': '28/3/2018',
#              'datetime': '2018-03-28T04:29:30',
#              'latitude': -37.6195,
#              'longitude': 143.4212,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('60a958a49343696505cf471b'),
#  'air_temperature_celcius': 17,
#  'date': '29/3/2018',
#  'hotspot': {'confidence': 69,
#              'date': '29/3/2018',
#              'datetime': '2018-03-29T00:48:40',
#              'latitude': -34.2648,
#              'longitude': 141.6325,
#              'surface_temperature_celcius': 51},
#  'max_wind_speed': 21.0,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'date': '31/3/2018',
#  'hotspot': {'confidence': 51,
#              'date': '31/3/2018',
#              'datetime': '2018-03-31T00:36:30',
#              'latitude': -34.2568,
#              'longitude': 141.64,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'date': '31/3/2018',
#  'hotspot': {'confidence': 56,
#              'date': '31/3/2018',
#              'datetime': '2018-03-31T04:57:10',
#              'latitude': -37.982,
#              'longitude': 143.6422,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'date': '31/3/2018',
#  'hotspot': {'confidence': 51,
#              'date': '31/3/2018',
#              'datetime': '2018-03-31T04:57:10',
#              'latitude': -37.561,
#              'longitude': 143.242,
#              'surface_temperature_celcius': 38},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'date': '31/3/2018',
#  'hotspot': {'confidence': 61,
#              'date': '31/3/2018',
#              'datetime': '2018-03-31T04:57:10',
#              'latitude': -36.7028,
#              'longitude': 145.2519,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'date': '31/3/2018',
#  'hotspot': {'confidence': 52,
#              'date': '31/3/2018',
#              'datetime': '2018-03-31T04:57:10',
#              'latitude': -36.7134,
#              'longitude': 145.2151,
#              'surface_temperature_celcius': 38},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'date': '31/3/2018',
#  'hotspot': {'confidence': 68,
#              'date': '31/3/2018',
#              'datetime': '2018-03-31T04:57:40',
#              'latitude': -36.0436,
#              'longitude': 145.7964,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471d'),
#  'air_temperature_celcius': 14,
#  'date': '31/3/2018',
#  'hotspot': {'confidence': 68,
#              'date': '31/3/2018',
#              'datetime': '2018-03-31T04:57:50',
#              'latitude': -36.1649,
#              'longitude': 145.9352,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471e'),
#  'air_temperature_celcius': 14,
#  'date': '1/4/2018',
#  'hotspot': {'confidence': 50,
#              'date': '1/4/2018',
#              'datetime': '2018-04-01T04:02:40',
#              'latitude': -36.1002,
#              'longitude': 147.6494,
#              'surface_temperature_celcius': 39},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471e'),
#  'air_temperature_celcius': 14,
#  'date': '1/4/2018',
#  'hotspot': {'confidence': 57,
#              'date': '1/4/2018',
#              'datetime': '2018-04-01T04:02:40',
#              'latitude': -36.5245,
#              'longitude': 143.1556,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60a958a49343696505cf471e'),
#  'air_temperature_celcius': 14,
#  'date': '1/4/2018',
#  'hotspot': {'confidence': 58,
#              'date': '1/4/2018',
#              'datetime': '2018-04-01T04:02:40',
#              'latitude': -36.2044,
#              'longitude': 145.7706,
#              'surface_temperature_celcius': 51},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60a958a49343696505cf471f'),
#  'air_temperature_celcius': 12,
#  'date': '2/4/2018',
#  'hotspot': {'confidence': 60,
#              'date': '2/4/2018',
#              'datetime': '2018-04-02T00:24:50',
#              'latitude': -37.324,
#              'longitude': 146.1647,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60a958a49343696505cf471f'),
#  'air_temperature_celcius': 12,
#  'date': '2/4/2018',
#  'hotspot': {'confidence': 63,
#              'date': '2/4/2018',
#              'datetime': '2018-04-02T04:45:10',
#              'latitude': -36.494,
#              'longitude': 145.4522,
#              'surface_temperature_celcius': 41},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60a958a49343696505cf471f'),
#  'air_temperature_celcius': 12,
#  'date': '2/4/2018',
#  'hotspot': {'confidence': 60,
#              'date': '2/4/2018',
#              'datetime': '2018-04-02T04:53:30',
#              'latitude': -36.3872,
#              'longitude': 145.3858,
#              'surface_temperature_celcius': 40},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 57,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T01:07:00',
#              'latitude': -34.2614,
#              'longitude': 141.6412,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 67,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T01:11:00',
#              'latitude': -34.2536,
#              'longitude': 141.6199,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 68,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:40',
#              'latitude': -36.911,
#              'longitude': 142.1445,
#              'surface_temperature_celcius': 47},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 52,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:40',
#              'latitude': -37.0484,
#              'longitude': 141.6245,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 69,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:40',
#              'latitude': -37.7836,
#              'longitude': 142.9437,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 62,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:40',
#              'latitude': -37.9009,
#              'longitude': 143.6217,
#              'surface_temperature_celcius': 45},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 56,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:40',
#              'latitude': -37.8089,
#              'longitude': 145.9555,
#              'surface_temperature_celcius': 41},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 56,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:50',
#              'latitude': -38.0226,
#              'longitude': 143.6739,
#              'surface_temperature_celcius': 39},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 52,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:50',
#              'latitude': -37.313,
#              'longitude': 146.1561,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:50',
#              'latitude': -37.2912,
#              'longitude': 143.543,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 67,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:50:50',
#              'latitude': -37.0241,
#              'longitude': 141.5163,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 67,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:51:10',
#              'latitude': -37.8011,
#              'longitude': 144.7343,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:52:10',
#              'latitude': -37.8717,
#              'longitude': 143.2566,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:53:30',
#              'latitude': -37.7885,
#              'longitude': 142.9509,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 68,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:53:40',
#              'latitude': -37.7602,
#              'longitude': 143.382,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4720'),
#  'air_temperature_celcius': 15,
#  'date': '3/4/2018',
#  'hotspot': {'confidence': 69,
#              'date': '3/4/2018',
#              'datetime': '2018-04-03T03:53:50',
#              'latitude': -37.8668,
#              'longitude': 143.0472,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 60,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:40',
#              'latitude': -38.1177,
#              'longitude': 143.6409,
#              'surface_temperature_celcius': 40},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 67,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:40',
#              'latitude': -36.6228,
#              'longitude': 142.428,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 64,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:40',
#              'latitude': -36.2889,
#              'longitude': 141.7692,
#              'surface_temperature_celcius': 51},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:40',
#              'latitude': -37.0081,
#              'longitude': 141.7654,
#              'surface_temperature_celcius': 62},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 53,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:40',
#              'latitude': -36.3539,
#              'longitude': 142.1894,
#              'surface_temperature_celcius': 53},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 55,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:40',
#              'latitude': -36.4611,
#              'longitude': 143.146,
#              'surface_temperature_celcius': 48},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 54,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:32:50',
#              'latitude': -36.7009,
#              'longitude': 141.541,
#              'surface_temperature_celcius': 49},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 53,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:33:10',
#              'latitude': -36.1439,
#              'longitude': 145.832,
#              'surface_temperature_celcius': 50},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:33:10',
#              'latitude': -36.6299,
#              'longitude': 142.4234,
#              'surface_temperature_celcius': 71},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 69,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:33:30',
#              'latitude': -36.4918,
#              'longitude': 142.2465,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 63,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:33:30',
#              'latitude': -37.1744,
#              'longitude': 143.9256,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 54,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:34:20',
#              'latitude': -38.4879,
#              'longitude': 143.9971,
#              'surface_temperature_celcius': 40},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 63,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:36:30',
#              'latitude': -38.0494,
#              'longitude': 143.9141,
#              'surface_temperature_celcius': 58},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 67,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:36:30',
#              'latitude': -37.6714,
#              'longitude': 144.2154,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 50,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:38:10',
#              'latitude': -36.6951,
#              'longitude': 145.424,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 61,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:39:40',
#              'latitude': -36.937,
#              'longitude': 142.1176,
#              'surface_temperature_celcius': 50},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 64,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T04:39:50',
#              'latitude': -36.6281,
#              'longitude': 142.4349,
#              'surface_temperature_celcius': 68},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4721'),
#  'air_temperature_celcius': 16,
#  'date': '4/4/2018',
#  'hotspot': {'confidence': 63,
#              'date': '4/4/2018',
#              'datetime': '2018-04-04T15:30:40',
#              'latitude': -36.0933,
#              'longitude': 141.7154,
#              'surface_temperature_celcius': 35},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 69,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:39:10',
#              'latitude': -37.6339,
#              'longitude': 143.4108,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 68,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:39:10',
#              'latitude': -36.9405,
#              'longitude': 142.8627,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 69,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:39:10',
#              'latitude': -36.9354,
#              'longitude': 142.5807,
#              'surface_temperature_celcius': 45},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 59,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:39:10',
#              'latitude': -38.0383,
#              'longitude': 144.4307,
#              'surface_temperature_celcius': 40},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 64,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:40:30',
#              'latitude': -36.934,
#              'longitude': 142.5759,
#              'surface_temperature_celcius': 47},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 50,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:40:30',
#              'latitude': -38.3553,
#              'longitude': 147.0231,
#              'surface_temperature_celcius': 38},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 65,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:44:30',
#              'latitude': -38.1756,
#              'longitude': 143.9829,
#              'surface_temperature_celcius': 53},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 68,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:44:40',
#              'latitude': -37.7767,
#              'longitude': 141.8127,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 65,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T03:45:10',
#              'latitude': -37.78,
#              'longitude': 141.8091,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T05:15:30',
#              'latitude': -36.9396,
#              'longitude': 141.9303,
#              'surface_temperature_celcius': 45},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T05:15:40',
#              'latitude': -37.7522,
#              'longitude': 142.3183,
#              'surface_temperature_celcius': 50},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 66,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T13:02:40',
#              'latitude': -37.6435,
#              'longitude': 146.1417,
#              'surface_temperature_celcius': 36},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60a958a49343696505cf4722'),
#  'air_temperature_celcius': 17,
#  'date': '5/4/2018',
#  'hotspot': {'confidence': 61,
#              'date': '5/4/2018',
#              'datetime': '2018-04-05T13:10:10',
#              'latitude': -38.3499,
#              'longitude': 147.033,
#              'surface_temperature_celcius': 35},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'date': '6/4/2018',
#  'hotspot': {'confidence': 52,
#              'date': '6/4/2018',
#              'datetime': '2018-04-06T00:01:40',
#              'latitude': -38.0942,
#              'longitude': 146.9603,
#              'surface_temperature_celcius': 39},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'date': '6/4/2018',
#  'hotspot': {'confidence': 67,
#              'date': '6/4/2018',
#              'datetime': '2018-04-06T00:03:50',
#              'latitude': -35.4625,
#              'longitude': 143.1486,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'date': '6/4/2018',
#  'hotspot': {'confidence': 64,
#              'date': '6/4/2018',
#              'datetime': '2018-04-06T04:20:40',
#              'latitude': -37.7496,
#              'longitude': 148.3898,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'date': '6/4/2018',
#  'hotspot': {'confidence': 63,
#              'date': '6/4/2018',
#              'datetime': '2018-04-06T04:20:40',
#              'latitude': -37.5914,
#              'longitude': 148.5807,
#              'surface_temperature_celcius': 61},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'date': '6/4/2018',
#  'hotspot': {'confidence': 68,
#              'date': '6/4/2018',
#              'datetime': '2018-04-06T04:20:40',
#              'latitude': -37.1992,
#              'longitude': 146.2301,
#              'surface_temperature_celcius': 60},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60a958a49343696505cf4723'),
#  'air_temperature_celcius': 19,
#  'date': '6/4/2018',
#  'hotspot': {'confidence': 59,
#              'date': '6/4/2018',
#              'datetime': '2018-04-06T04:20:40',
#              'latitude': -37.1929,
#              'longitude': 143.8132,
# ...
#              'longitude': 143.375,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 22.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 48.3,
#  'station': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('60a958a49343696505cf4801'),
#  'air_temperature_celcius': 28,
#  'date': '14/11/2018',
#  'hotspot': {'confidence': 64,
#              'date': '14/11/2018',
#              'datetime': '2018-11-14T00:21:26',
#              'latitude': -38.527,
#              'longitude': 143.493,
#              'surface_temperature_celcius': 45},
#  'max_wind_speed': 22.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 48.3,
#  'station': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('60a958a49343696505cf480a'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2018',
#  'hotspot': {'confidence': 63,
#              'date': '23/11/2018',
#              'datetime': '2018-11-23T00:14:47',
#              'latitude': -36.952,
#              'longitude': 144.972,
#              'surface_temperature_celcius': 60},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.8,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('60a958a49343696505cf480a'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2018',
#  'hotspot': {'confidence': 68,
#              'date': '23/11/2018',
#              'datetime': '2018-11-23T00:15:12',
#              'latitude': -38.141,
#              'longitude': 143.183,
#              'surface_temperature_celcius': 46},
#  'max_wind_speed': 9.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.8,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('60a958a49343696505cf480f'),
#  'air_temperature_celcius': 23,
#  'date': '28/11/2018',
#  'hotspot': {'confidence': 50,
#              'date': '28/11/2018',
#              'datetime': '2018-11-28T00:33:14',
#              'latitude': -37.749,
#              'longitude': 148.297,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 58.8,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2018',
#  'hotspot': {'confidence': 64,
#              'date': '29/11/2018',
#              'datetime': '2018-11-29T03:52:10',
#              'latitude': -37.605,
#              'longitude': 149.326,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 16.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2018',
#  'hotspot': {'confidence': 52,
#              'date': '29/11/2018',
#              'datetime': '2018-11-29T03:53:16',
#              'latitude': -34.282,
#              'longitude': 142.121,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 16.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2018',
#  'hotspot': {'confidence': 68,
#              'date': '29/11/2018',
#              'datetime': '2018-11-29T13:17:24',
#              'latitude': -37.605,
#              'longitude': 149.308,
#              'surface_temperature_celcius': 43},
#  'max_wind_speed': 16.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('60a958a49343696505cf4810'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2018',
#  'hotspot': {'confidence': 53,
#              'date': '29/11/2018',
#              'datetime': '2018-11-29T13:17:24',
#              'latitude': -37.611,
#              'longitude': 149.277,
#              'surface_temperature_celcius': 38},
#  'max_wind_speed': 16.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 64,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T00:20:49',
#              'latitude': -37.382,
#              'longitude': 149.341,
#              'surface_temperature_celcius': 41},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 69,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T00:20:53',
#              'latitude': -37.6,
#              'longitude': 149.297,
#              'surface_temperature_celcius': 50},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 60,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T00:21:00',
#              'latitude': -37.637,
#              'longitude': 146.288,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 69,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T04:34:57',
#              'latitude': -37.61,
#              'longitude': 149.279,
#              'surface_temperature_celcius': 48},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 64,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T12:22:15',
#              'latitude': -37.598,
#              'longitude': 149.29,
#              'surface_temperature_celcius': 32},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 62,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T12:22:15',
#              'latitude': -37.602,
#              'longitude': 149.295,
#              'surface_temperature_celcius': 33},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 61,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T15:38:32',
#              'latitude': -37.38,
#              'longitude': 149.334,
#              'surface_temperature_celcius': 31},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 69,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T15:38:35',
#              'latitude': -37.58,
#              'longitude': 149.331,
#              'surface_temperature_celcius': 35},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 64,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T15:38:36',
#              'latitude': -37.633,
#              'longitude': 149.264,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 51,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T15:38:36',
#              'latitude': -37.59,
#              'longitude': 149.31,
#              'surface_temperature_celcius': 42},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': {'confidence': 52,
#              'date': '30/11/2018',
#              'datetime': '2018-11-30T23:25:57',
#              'latitude': -37.635,
#              'longitude': 149.303,
#              'surface_temperature_celcius': 47},
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60a958a49343696505cf4819'),
#  'air_temperature_celcius': 15,
#  'date': '8/12/2018',
#  'hotspot': {'confidence': 56,
#              'date': '8/12/2018',
#              'datetime': '2018-12-08T13:11:43',
#              'latitude': -36.291,
#              'longitude': 146.159,
#              'surface_temperature_celcius': 40},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 48.1,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60a958a49343696505cf481b'),
#  'air_temperature_celcius': 17,
#  'date': '10/12/2018',
#  'hotspot': {'confidence': 67,
#              'date': '10/12/2018',
#              'datetime': '2018-12-10T00:56:57',
#              'latitude': -34.289,
#              'longitude': 141.712,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 14.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60a958a49343696505cf481b'),
#  'air_temperature_celcius': 17,
#  'date': '10/12/2018',
#  'hotspot': {'confidence': 50,
#              'date': '10/12/2018',
#              'datetime': '2018-12-10T00:57:59',
#              'latitude': -37.987,
#              'longitude': 144.005,
#              'surface_temperature_celcius': 38},
#  'max_wind_speed': 14.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60a958a49343696505cf481d'),
#  'air_temperature_celcius': 19,
#  'date': '12/12/2018',
#  'hotspot': {'confidence': 53,
#              'date': '12/12/2018',
#              'datetime': '2018-12-12T00:45:38',
#              'latitude': -37.903,
#              'longitude': 145.25,
#              'surface_temperature_celcius': 44},
#  'max_wind_speed': 12.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('60a958a49343696505cf4820'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2018',
#  'hotspot': {'confidence': 65,
#              'date': '15/12/2018',
#              'datetime': '2018-12-15T01:16:23',
#              'latitude': -38.038,
#              'longitude': 142.986,
#              'surface_temperature_celcius': 40},
#  'max_wind_speed': 14.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('60a958a49343696505cf4820'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2018',
#  'hotspot': {'confidence': 51,
#              'date': '15/12/2018',
#              'datetime': '2018-12-15T13:17:17',
#              'latitude': -37.623,
#              'longitude': 149.323,
#              'surface_temperature_celcius': 38},
#  'max_wind_speed': 14.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'hotspot': {'confidence': 53,
#              'date': '16/12/2018',
#              'datetime': '2018-12-16T00:20:53',
#              'latitude': -37.63,
#              'longitude': 149.335,
#              'surface_temperature_celcius': 57},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'hotspot': {'confidence': 60,
#              'date': '16/12/2018',
#              'datetime': '2018-12-16T00:21:11',
#              'latitude': -38.046,
#              'longitude': 144.201,
#              'surface_temperature_celcius': 48},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'hotspot': {'confidence': 59,
#              'date': '16/12/2018',
#              'datetime': '2018-12-16T04:34:57',
#              'latitude': -37.644,
#              'longitude': 149.346,
#              'surface_temperature_celcius': 55},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'hotspot': {'confidence': 62,
#              'date': '16/12/2018',
#              'datetime': '2018-12-16T04:35:15',
#              'latitude': -37.82,
#              'longitude': 142.323,
#              'surface_temperature_celcius': 54},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60a958a49343696505cf4821'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'hotspot': {'confidence': 69,
#              'date': '16/12/2018',
#              'datetime': '2018-12-16T15:38:39',
#              'latitude': -37.624,
#              'longitude': 149.332,
#              'surface_temperature_celcius': 33},
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60a958a49343696505cf4829'),
#  'air_temperature_celcius': 16,
#  'date': '24/12/2018',
#  'hotspot': {'confidence': 65,
#              'date': '24/12/2018',
#              'datetime': '2018-12-24T13:12:01',
#              'latitude': -35.646,
#              'longitude': 142.282,
#              'surface_temperature_celcius': 32},
#  'max_wind_speed': 16.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.0,
#  'station': 948702,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60a958a49343696505cf482c'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2018',
#  'hotspot': {'confidence': 67,
#              'date': '27/12/2018',
#              'datetime': '2018-12-27T00:02:15',
#              'latitude': -35.554,
#              'longitude': 143.307,
#              'surface_temperature_celcius': 53},
#  'max_wind_speed': 15.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %%
#h
"""
Find the average surface temperature (°C) for each day. You are required to
only display average surface temperature (°C) and the date in the output.
"""
pipeline = [
    {"$project": {"_id":0,"date":1,"avg_surfece_temp":{"$avg":"$hotspot.surface_temperature_celcius"}}}
]

cursor = collection.aggregate(pipeline)
for document in cursor: 
    pprint(document)
# Out:
# {'avg_surfece_temp': None, 'date': '31/12/2017'}
# {'avg_surfece_temp': None, 'date': '2/1/2018'}
# {'avg_surfece_temp': None, 'date': '3/1/2018'}
# {'avg_surfece_temp': None, 'date': '4/1/2018'}
# {'avg_surfece_temp': None, 'date': '5/1/2018'}
# {'avg_surfece_temp': None, 'date': '6/1/2018'}
# {'avg_surfece_temp': None, 'date': '7/1/2018'}
# {'avg_surfece_temp': None, 'date': '8/1/2018'}
# {'avg_surfece_temp': None, 'date': '9/1/2018'}
# {'avg_surfece_temp': None, 'date': '10/1/2018'}
# {'avg_surfece_temp': None, 'date': '11/1/2018'}
# {'avg_surfece_temp': None, 'date': '12/1/2018'}
# {'avg_surfece_temp': None, 'date': '13/1/2018'}
# {'avg_surfece_temp': None, 'date': '14/1/2018'}
# {'avg_surfece_temp': None, 'date': '15/1/2018'}
# {'avg_surfece_temp': None, 'date': '16/1/2018'}
# {'avg_surfece_temp': None, 'date': '17/1/2018'}
# {'avg_surfece_temp': None, 'date': '18/1/2018'}
# {'avg_surfece_temp': None, 'date': '19/1/2018'}
# {'avg_surfece_temp': None, 'date': '20/1/2018'}
# {'avg_surfece_temp': None, 'date': '21/1/2018'}
# {'avg_surfece_temp': None, 'date': '22/1/2018'}
# {'avg_surfece_temp': None, 'date': '23/1/2018'}
# {'avg_surfece_temp': None, 'date': '24/1/2018'}
# {'avg_surfece_temp': None, 'date': '25/1/2018'}
# {'avg_surfece_temp': None, 'date': '26/1/2018'}
# {'avg_surfece_temp': None, 'date': '27/1/2018'}
# {'avg_surfece_temp': None, 'date': '28/1/2018'}
# {'avg_surfece_temp': None, 'date': '29/1/2018'}
# {'avg_surfece_temp': None, 'date': '30/1/2018'}
# {'avg_surfece_temp': None, 'date': '31/1/2018'}
# {'avg_surfece_temp': None, 'date': '1/2/2018'}
# {'avg_surfece_temp': None, 'date': '2/2/2018'}
# {'avg_surfece_temp': None, 'date': '3/2/2018'}
# {'avg_surfece_temp': None, 'date': '4/2/2018'}
# {'avg_surfece_temp': None, 'date': '5/2/2018'}
# {'avg_surfece_temp': None, 'date': '6/2/2018'}
# {'avg_surfece_temp': None, 'date': '7/2/2018'}
# {'avg_surfece_temp': None, 'date': '8/2/2018'}
# {'avg_surfece_temp': None, 'date': '9/2/2018'}
# {'avg_surfece_temp': None, 'date': '10/2/2018'}
# {'avg_surfece_temp': None, 'date': '11/2/2018'}
# {'avg_surfece_temp': None, 'date': '12/2/2018'}
# {'avg_surfece_temp': None, 'date': '13/2/2018'}
# {'avg_surfece_temp': None, 'date': '14/2/2018'}
# {'avg_surfece_temp': None, 'date': '15/2/2018'}
# {'avg_surfece_temp': None, 'date': '16/2/2018'}
# {'avg_surfece_temp': None, 'date': '17/2/2018'}
# {'avg_surfece_temp': None, 'date': '18/2/2018'}
# {'avg_surfece_temp': None, 'date': '19/2/2018'}
# {'avg_surfece_temp': None, 'date': '20/2/2018'}
# {'avg_surfece_temp': None, 'date': '21/2/2018'}
# {'avg_surfece_temp': None, 'date': '22/2/2018'}
# {'avg_surfece_temp': None, 'date': '23/2/2018'}
# {'avg_surfece_temp': None, 'date': '24/2/2018'}
# {'avg_surfece_temp': None, 'date': '25/2/2018'}
# {'avg_surfece_temp': None, 'date': '26/2/2018'}
# {'avg_surfece_temp': None, 'date': '27/2/2018'}
# {'avg_surfece_temp': None, 'date': '28/2/2018'}
# {'avg_surfece_temp': None, 'date': '1/3/2018'}
# {'avg_surfece_temp': None, 'date': '2/3/2018'}
# {'avg_surfece_temp': None, 'date': '3/3/2018'}
# {'avg_surfece_temp': None, 'date': '4/3/2018'}
# {'avg_surfece_temp': None, 'date': '5/3/2018'}
# {'avg_surfece_temp': 60.5, 'date': '6/3/2018'}
# {'avg_surfece_temp': 64.0, 'date': '7/3/2018'}
# {'avg_surfece_temp': 51.5, 'date': '8/3/2018'}
# {'avg_surfece_temp': 46.666666666666664, 'date': '9/3/2018'}
# {'avg_surfece_temp': 69.375, 'date': '10/3/2018'}
# {'avg_surfece_temp': None, 'date': '11/3/2018'}
# {'avg_surfece_temp': 88.2, 'date': '12/3/2018'}
# {'avg_surfece_temp': 38.5, 'date': '13/3/2018'}
# {'avg_surfece_temp': 65.6, 'date': '14/3/2018'}
# {'avg_surfece_temp': 46.0, 'date': '15/3/2018'}
# {'avg_surfece_temp': None, 'date': '16/3/2018'}
# {'avg_surfece_temp': 59.5, 'date': '17/3/2018'}
# {'avg_surfece_temp': 79.33333333333333, 'date': '18/3/2018'}
# {'avg_surfece_temp': 65.57142857142857, 'date': '19/3/2018'}
# {'avg_surfece_temp': None, 'date': '20/3/2018'}
# {'avg_surfece_temp': None, 'date': '21/3/2018'}
# {'avg_surfece_temp': None, 'date': '22/3/2018'}
# {'avg_surfece_temp': None, 'date': '23/3/2018'}
# {'avg_surfece_temp': 49.0, 'date': '24/3/2018'}
# {'avg_surfece_temp': 66.0, 'date': '25/3/2018'}
# {'avg_surfece_temp': 56.88235294117647, 'date': '26/3/2018'}
# {'avg_surfece_temp': None, 'date': '27/3/2018'}
# {'avg_surfece_temp': 60.925925925925924, 'date': '28/3/2018'}
# {'avg_surfece_temp': 51.0, 'date': '29/3/2018'}
# {'avg_surfece_temp': None, 'date': '30/3/2018'}
# {'avg_surfece_temp': 48.72727272727273, 'date': '31/3/2018'}
# {'avg_surfece_temp': 46.714285714285715, 'date': '1/4/2018'}
# {'avg_surfece_temp': 45.2, 'date': '2/4/2018'}
# {'avg_surfece_temp': 58.44444444444444, 'date': '3/4/2018'}
# {'avg_surfece_temp': 62.57303370786517, 'date': '4/4/2018'}
# {'avg_surfece_temp': 53.142857142857146, 'date': '5/4/2018'}
# {'avg_surfece_temp': 61.71186440677966, 'date': '6/4/2018'}
# {'avg_surfece_temp': 50.69230769230769, 'date': '7/4/2018'}
# {'avg_surfece_temp': 60.75, 'date': '8/4/2018'}
# {'avg_surfece_temp': None, 'date': '9/4/2018'}
# {'avg_surfece_temp': None, 'date': '10/4/2018'}
# {'avg_surfece_temp': 46.291666666666664, 'date': '11/4/2018'}
# {'avg_surfece_temp': 52.69565217391305, 'date': '12/4/2018'}
# {'avg_surfece_temp': 58.57983193277311, 'date': '13/4/2018'}
# {'avg_surfece_temp': 61.94444444444444, 'date': '14/4/2018'}
# {'avg_surfece_temp': 59.57971014492754, 'date': '15/4/2018'}
# {'avg_surfece_temp': 48.72222222222222, 'date': '16/4/2018'}
# {'avg_surfece_temp': 50.921052631578945, 'date': '17/4/2018'}
# {'avg_surfece_temp': 53.36615384615384, 'date': '18/4/2018'}
# {'avg_surfece_temp': 54.16, 'date': '19/4/2018'}
# {'avg_surfece_temp': 56.58064516129032, 'date': '20/4/2018'}
# {'avg_surfece_temp': None, 'date': '21/4/2018'}
# {'avg_surfece_temp': 54.5, 'date': '22/4/2018'}
# {'avg_surfece_temp': 53.89473684210526, 'date': '23/4/2018'}
# {'avg_surfece_temp': 59.375, 'date': '24/4/2018'}
# {'avg_surfece_temp': 48.666666666666664, 'date': '25/4/2018'}
# {'avg_surfece_temp': 34.0, 'date': '26/4/2018'}
# {'avg_surfece_temp': None, 'date': '27/4/2018'}
# {'avg_surfece_temp': None, 'date': '28/4/2018'}
# {'avg_surfece_temp': 63.0, 'date': '29/4/2018'}
# {'avg_surfece_temp': None, 'date': '30/4/2018'}
# {'avg_surfece_temp': 68.4, 'date': '1/5/2018'}
# {'avg_surfece_temp': 55.6, 'date': '2/5/2018'}
# {'avg_surfece_temp': 56.796875, 'date': '3/5/2018'}
# {'avg_surfece_temp': 56.80740740740741, 'date': '4/5/2018'}
# {'avg_surfece_temp': 51.70967741935484, 'date': '5/5/2018'}
# {'avg_surfece_temp': 57.529411764705884, 'date': '6/5/2018'}
# {'avg_surfece_temp': 50.333333333333336, 'date': '7/5/2018'}
# {'avg_surfece_temp': 56.291666666666664, 'date': '8/5/2018'}
# {'avg_surfece_temp': 42.46153846153846, 'date': '9/5/2018'}
# {'avg_surfece_temp': 52.86842105263158, 'date': '10/5/2018'}
# {'avg_surfece_temp': 59.36842105263158, 'date': '11/5/2018'}
# {'avg_surfece_temp': 51.5, 'date': '12/5/2018'}
# {'avg_surfece_temp': 58.611111111111114, 'date': '13/5/2018'}
# {'avg_surfece_temp': 49.0, 'date': '14/5/2018'}
# {'avg_surfece_temp': 53.950980392156865, 'date': '15/5/2018'}
# {'avg_surfece_temp': 39.666666666666664, 'date': '16/5/2018'}
# {'avg_surfece_temp': 52.0, 'date': '17/5/2018'}
# {'avg_surfece_temp': 44.142857142857146, 'date': '18/5/2018'}
# {'avg_surfece_temp': None, 'date': '19/5/2018'}
# {'avg_surfece_temp': None, 'date': '20/5/2018'}
# {'avg_surfece_temp': None, 'date': '21/5/2018'}
# {'avg_surfece_temp': 54.484848484848484, 'date': '22/5/2018'}
# {'avg_surfece_temp': 51.2, 'date': '23/5/2018'}
# {'avg_surfece_temp': 40.333333333333336, 'date': '24/5/2018'}
# {'avg_surfece_temp': None, 'date': '25/5/2018'}
# {'avg_surfece_temp': 49.5, 'date': '26/5/2018'}
# {'avg_surfece_temp': None, 'date': '27/5/2018'}
# {'avg_surfece_temp': None, 'date': '28/5/2018'}
# {'avg_surfece_temp': None, 'date': '29/5/2018'}
# {'avg_surfece_temp': None, 'date': '30/5/2018'}
# {'avg_surfece_temp': None, 'date': '31/5/2018'}
# {'avg_surfece_temp': 54.0, 'date': '1/6/2018'}
# {'avg_surfece_temp': 47.72727272727273, 'date': '2/6/2018'}
# {'avg_surfece_temp': 47.0, 'date': '3/6/2018'}
# {'avg_surfece_temp': 52.22222222222222, 'date': '4/6/2018'}
# {'avg_surfece_temp': None, 'date': '5/6/2018'}
# {'avg_surfece_temp': None, 'date': '6/6/2018'}
# {'avg_surfece_temp': 51.857142857142854, 'date': '7/6/2018'}
# {'avg_surfece_temp': None, 'date': '8/6/2018'}
# {'avg_surfece_temp': 49.0, 'date': '9/6/2018'}
# {'avg_surfece_temp': None, 'date': '10/6/2018'}
# {'avg_surfece_temp': 41.5, 'date': '11/6/2018'}
# {'avg_surfece_temp': None, 'date': '12/6/2018'}
# {'avg_surfece_temp': 41.0, 'date': '13/6/2018'}
# {'avg_surfece_temp': 53.25, 'date': '14/6/2018'}
# {'avg_surfece_temp': None, 'date': '15/6/2018'}
# {'avg_surfece_temp': 42.5, 'date': '16/6/2018'}
# {'avg_surfece_temp': None, 'date': '17/6/2018'}
# {'avg_surfece_temp': 42.0, 'date': '18/6/2018'}
# {'avg_surfece_temp': None, 'date': '19/6/2018'}
# {'avg_surfece_temp': 71.16666666666667, 'date': '20/6/2018'}
# {'avg_surfece_temp': None, 'date': '21/6/2018'}
# {'avg_surfece_temp': 46.0, 'date': '22/6/2018'}
# {'avg_surfece_temp': None, 'date': '23/6/2018'}
# {'avg_surfece_temp': None, 'date': '24/6/2018'}
# {'avg_surfece_temp': None, 'date': '25/6/2018'}
# {'avg_surfece_temp': None, 'date': '26/6/2018'}
# {'avg_surfece_temp': None, 'date': '27/6/2018'}
# {'avg_surfece_temp': None, 'date': '28/6/2018'}
# {'avg_surfece_temp': None, 'date': '29/6/2018'}
# {'avg_surfece_temp': 44.333333333333336, 'date': '30/6/2018'}
# {'avg_surfece_temp': 30.5, 'date': '1/7/2018'}
# {'avg_surfece_temp': 43.5, 'date': '2/7/2018'}
# {'avg_surfece_temp': None, 'date': '3/7/2018'}
# {'avg_surfece_temp': 40.0, 'date': '4/7/2018'}
# {'avg_surfece_temp': 45.0, 'date': '5/7/2018'}
# {'avg_surfece_temp': 56.0, 'date': '6/7/2018'}
# {'avg_surfece_temp': None, 'date': '7/7/2018'}
# {'avg_surfece_temp': None, 'date': '8/7/2018'}
# {'avg_surfece_temp': None, 'date': '9/7/2018'}
# {'avg_surfece_temp': None, 'date': '10/7/2018'}
# {'avg_surfece_temp': None, 'date': '11/7/2018'}
# {'avg_surfece_temp': None, 'date': '12/7/2018'}
# {'avg_surfece_temp': None, 'date': '13/7/2018'}
# {'avg_surfece_temp': 41.5, 'date': '14/7/2018'}
# {'avg_surfece_temp': None, 'date': '15/7/2018'}
# {'avg_surfece_temp': None, 'date': '16/7/2018'}
# {'avg_surfece_temp': None, 'date': '17/7/2018'}
# {'avg_surfece_temp': None, 'date': '18/7/2018'}
# {'avg_surfece_temp': None, 'date': '19/7/2018'}
# {'avg_surfece_temp': None, 'date': '20/7/2018'}
# {'avg_surfece_temp': None, 'date': '21/7/2018'}
# {'avg_surfece_temp': None, 'date': '22/7/2018'}
# {'avg_surfece_temp': None, 'date': '23/7/2018'}
# {'avg_surfece_temp': None, 'date': '24/7/2018'}
# {'avg_surfece_temp': None, 'date': '25/7/2018'}
# {'avg_surfece_temp': None, 'date': '26/7/2018'}
# {'avg_surfece_temp': None, 'date': '27/7/2018'}
# {'avg_surfece_temp': None, 'date': '28/7/2018'}
# {'avg_surfece_temp': 48.0, 'date': '29/7/2018'}
# {'avg_surfece_temp': None, 'date': '30/7/2018'}
# {'avg_surfece_temp': 47.0, 'date': '31/7/2018'}
# {'avg_surfece_temp': 58.0, 'date': '1/8/2018'}
# {'avg_surfece_temp': 63.5, 'date': '2/8/2018'}
# {'avg_surfece_temp': None, 'date': '3/8/2018'}
# {'avg_surfece_temp': None, 'date': '4/8/2018'}
# {'avg_surfece_temp': 40.0, 'date': '5/8/2018'}
# {'avg_surfece_temp': None, 'date': '6/8/2018'}
# {'avg_surfece_temp': None, 'date': '7/8/2018'}
# {'avg_surfece_temp': None, 'date': '8/8/2018'}
# {'avg_surfece_temp': None, 'date': '9/8/2018'}
# {'avg_surfece_temp': 63.0, 'date': '10/8/2018'}
# {'avg_surfece_temp': None, 'date': '11/8/2018'}
# {'avg_surfece_temp': None, 'date': '12/8/2018'}
# {'avg_surfece_temp': 49.0, 'date': '13/8/2018'}
# {'avg_surfece_temp': 40.8, 'date': '14/8/2018'}
# {'avg_surfece_temp': None, 'date': '15/8/2018'}
# {'avg_surfece_temp': None, 'date': '16/8/2018'}
# {'avg_surfece_temp': None, 'date': '17/8/2018'}
# {'avg_surfece_temp': None, 'date': '18/8/2018'}
# {'avg_surfece_temp': None, 'date': '19/8/2018'}
# {'avg_surfece_temp': None, 'date': '20/8/2018'}
# {'avg_surfece_temp': None, 'date': '21/8/2018'}
# {'avg_surfece_temp': None, 'date': '22/8/2018'}
# {'avg_surfece_temp': None, 'date': '23/8/2018'}
# {'avg_surfece_temp': None, 'date': '24/8/2018'}
# {'avg_surfece_temp': None, 'date': '25/8/2018'}
# {'avg_surfece_temp': None, 'date': '26/8/2018'}
# {'avg_surfece_temp': None, 'date': '27/8/2018'}
# {'avg_surfece_temp': None, 'date': '28/8/2018'}
# {'avg_surfece_temp': None, 'date': '29/8/2018'}
# {'avg_surfece_temp': None, 'date': '30/8/2018'}
# {'avg_surfece_temp': None, 'date': '31/8/2018'}
# {'avg_surfece_temp': None, 'date': '1/9/2018'}
# {'avg_surfece_temp': None, 'date': '2/9/2018'}
# {'avg_surfece_temp': None, 'date': '3/9/2018'}
# {'avg_surfece_temp': None, 'date': '4/9/2018'}
# {'avg_surfece_temp': None, 'date': '5/9/2018'}
# {'avg_surfece_temp': None, 'date': '6/9/2018'}
# {'avg_surfece_temp': None, 'date': '7/9/2018'}
# {'avg_surfece_temp': None, 'date': '8/9/2018'}
# {'avg_surfece_temp': None, 'date': '9/9/2018'}
# {'avg_surfece_temp': 56.5, 'date': '10/9/2018'}
# {'avg_surfece_temp': None, 'date': '11/9/2018'}
# {'avg_surfece_temp': None, 'date': '12/9/2018'}
# {'avg_surfece_temp': None, 'date': '13/9/2018'}
# {'avg_surfece_temp': None, 'date': '14/9/2018'}
# {'avg_surfece_temp': None, 'date': '15/9/2018'}
# {'avg_surfece_temp': None, 'date': '16/9/2018'}
# {'avg_surfece_temp': None, 'date': '17/9/2018'}
# {'avg_surfece_temp': None, 'date': '18/9/2018'}
# {'avg_surfece_temp': None, 'date': '19/9/2018'}
# {'avg_surfece_temp': 63.6, 'date': '20/9/2018'}
# {'avg_surfece_temp': 40.5, 'date': '21/9/2018'}
# {'avg_surfece_temp': 45.0, 'date': '22/9/2018'}
# {'avg_surfece_temp': 52.73913043478261, 'date': '23/9/2018'}
# {'avg_surfece_temp': 53.57142857142857, 'date': '24/9/2018'}
# {'avg_surfece_temp': None, 'date': '25/9/2018'}
# {'avg_surfece_temp': 33.0, 'date': '26/9/2018'}
# {'avg_surfece_temp': 49.714285714285715, 'date': '27/9/2018'}
# {'avg_surfece_temp': None, 'date': '28/9/2018'}
# {'avg_surfece_temp': 43.0, 'date': '29/9/2018'}
# {'avg_surfece_temp': None, 'date': '30/9/2018'}
# {'avg_surfece_temp': 48.25, 'date': '1/10/2018'}
# {'avg_surfece_temp': 43.57142857142857, 'date': '2/10/2018'}
# {'avg_surfece_temp': 50.0, 'date': '3/10/2018'}
# {'avg_surfece_temp': 49.0, 'date': '4/10/2018'}
# {'avg_surfece_temp': None, 'date': '5/10/2018'}
# {'avg_surfece_temp': 44.0, 'date': '6/10/2018'}
# {'avg_surfece_temp': 42.0, 'date': '7/10/2018'}
# {'avg_surfece_temp': 41.0, 'date': '8/10/2018'}
# {'avg_surfece_temp': 44.0, 'date': '9/10/2018'}
# {'avg_surfece_temp': 53.333333333333336, 'date': '10/10/2018'}
# {'avg_surfece_temp': None, 'date': '11/10/2018'}
# {'avg_surfece_temp': None, 'date': '12/10/2018'}
# {'avg_surfece_temp': None, 'date': '13/10/2018'}
# {'avg_surfece_temp': None, 'date': '14/10/2018'}
# {'avg_surfece_temp': 72.66666666666667, 'date': '15/10/2018'}
# {'avg_surfece_temp': 36.0, 'date': '16/10/2018'}
# {'avg_surfece_temp': 51.6, 'date': '17/10/2018'}
# {'avg_surfece_temp': 52.166666666666664, 'date': '18/10/2018'}
# {'avg_surfece_temp': None, 'date': '19/10/2018'}
# {'avg_surfece_temp': 50.0, 'date': '20/10/2018'}
# {'avg_surfece_temp': 51.25, 'date': '21/10/2018'}
# {'avg_surfece_temp': None, 'date': '22/10/2018'}
# {'avg_surfece_temp': 38.0, 'date': '23/10/2018'}
# {'avg_surfece_temp': None, 'date': '24/10/2018'}
# {'avg_surfece_temp': None, 'date': '25/10/2018'}
# {'avg_surfece_temp': 44.6, 'date': '26/10/2018'}
# {'avg_surfece_temp': 50.4, 'date': '27/10/2018'}
# {'avg_surfece_temp': 56.0, 'date': '28/10/2018'}
# {'avg_surfece_temp': None, 'date': '29/10/2018'}
# {'avg_surfece_temp': None, 'date': '30/10/2018'}
# {'avg_surfece_temp': None, 'date': '31/10/2018'}
# {'avg_surfece_temp': None, 'date': '1/11/2018'}
# {'avg_surfece_temp': None, 'date': '2/11/2018'}
# {'avg_surfece_temp': None, 'date': '3/11/2018'}
# {'avg_surfece_temp': None, 'date': '4/11/2018'}
# {'avg_surfece_temp': 58.5, 'date': '5/11/2018'}
# {'avg_surfece_temp': None, 'date': '6/11/2018'}
# {'avg_surfece_temp': None, 'date': '7/11/2018'}
# {'avg_surfece_temp': 45.5, 'date': '8/11/2018'}
# {'avg_surfece_temp': 61.3, 'date': '9/11/2018'}
# {'avg_surfece_temp': None, 'date': '10/11/2018'}
# {'avg_surfece_temp': 46.25, 'date': '11/11/2018'}
# {'avg_surfece_temp': 53.0, 'date': '12/11/2018'}
# {'avg_surfece_temp': 47.0, 'date': '13/11/2018'}
# {'avg_surfece_temp': 52.0, 'date': '14/11/2018'}
# {'avg_surfece_temp': None, 'date': '15/11/2018'}
# {'avg_surfece_temp': None, 'date': '16/11/2018'}
# {'avg_surfece_temp': None, 'date': '17/11/2018'}
# {'avg_surfece_temp': None, 'date': '18/11/2018'}
# {'avg_surfece_temp': None, 'date': '19/11/2018'}
# {'avg_surfece_temp': None, 'date': '20/11/2018'}
# {'avg_surfece_temp': 59.0, 'date': '21/11/2018'}
# {'avg_surfece_temp': 61.5, 'date': '22/11/2018'}
# {'avg_surfece_temp': 58.8, 'date': '23/11/2018'}
# {'avg_surfece_temp': None, 'date': '24/11/2018'}
# {'avg_surfece_temp': None, 'date': '25/11/2018'}
# {'avg_surfece_temp': None, 'date': '26/11/2018'}
# {'avg_surfece_temp': None, 'date': '27/11/2018'}
# {'avg_surfece_temp': 42.0, 'date': '28/11/2018'}
# {'avg_surfece_temp': 60.625, 'date': '29/11/2018'}
# {'avg_surfece_temp': 52.41935483870968, 'date': '30/11/2018'}
# {'avg_surfece_temp': None, 'date': '1/12/2018'}
# {'avg_surfece_temp': None, 'date': '2/12/2018'}
# {'avg_surfece_temp': None, 'date': '3/12/2018'}
# {'avg_surfece_temp': None, 'date': '4/12/2018'}
# {'avg_surfece_temp': None, 'date': '5/12/2018'}
# {'avg_surfece_temp': None, 'date': '6/12/2018'}
# {'avg_surfece_temp': None, 'date': '7/12/2018'}
# {'avg_surfece_temp': 50.6, 'date': '8/12/2018'}
# {'avg_surfece_temp': 58.25, 'date': '9/12/2018'}
# {'avg_surfece_temp': 46.0, 'date': '10/12/2018'}
# {'avg_surfece_temp': None, 'date': '11/12/2018'}
# {'avg_surfece_temp': 44.0, 'date': '12/12/2018'}
# {'avg_surfece_temp': 60.0, 'date': '13/12/2018'}
# {'avg_surfece_temp': 70.0, 'date': '14/12/2018'}
# {'avg_surfece_temp': 39.0, 'date': '15/12/2018'}
# {'avg_surfece_temp': 57.8, 'date': '16/12/2018'}
# {'avg_surfece_temp': None, 'date': '17/12/2018'}
# {'avg_surfece_temp': None, 'date': '18/12/2018'}
# {'avg_surfece_temp': None, 'date': '19/12/2018'}
# {'avg_surfece_temp': None, 'date': '20/12/2018'}
# {'avg_surfece_temp': 46.0, 'date': '21/12/2018'}
# {'avg_surfece_temp': None, 'date': '22/12/2018'}
# {'avg_surfece_temp': None, 'date': '23/12/2018'}
# {'avg_surfece_temp': 32.0, 'date': '24/12/2018'}
# {'avg_surfece_temp': 54.0, 'date': '25/12/2018'}
# {'avg_surfece_temp': None, 'date': '26/12/2018'}
# {'avg_surfece_temp': 62.75, 'date': '27/12/2018'}
# {'avg_surfece_temp': None, 'date': '28/12/2018'}
# {'avg_surfece_temp': None, 'date': '29/12/2018'}
# {'avg_surfece_temp': None, 'date': '30/12/2018'}
# {'avg_surfece_temp': None, 'date': '31/12/2018'}
# {'avg_surfece_temp': None, 'date': '1/1/2018'}

# %%
#i
"""
Find the top 10 records with the lowest GHI
"""
results = collection.find().sort([("GHI_w/m2", pymongo.ASCENDING)]).limit(10)
for result in results:
    pprint(result)
# Out:
# {'GHI_w/m2': 47,
#  '_id': ObjectId('60a958a49343696505cf4799'),
#  'air_temperature_celcius': 5,
#  'date': '2/8/2018',
#  'hotspot': [{'confidence': 54,
#               'date': '2/8/2018',
#               'datetime': '2018-08-02T03:45:00',
#               'latitude': -37.491,
#               'longitude': 141.936,
#               'surface_temperature_celcius': 40},
#              {'confidence': 94,
#               'date': '2/8/2018',
#               'datetime': '2018-08-02T03:45:40',
#               'latitude': -37.4796,
#               'longitude': 141.9403,
#               'surface_temperature_celcius': 87}],
#  'max_wind_speed': 5.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 48,
#  '_id': ObjectId('60a958a49343696505cf4778'),
#  'air_temperature_celcius': 5,
#  'date': '30/6/2018',
#  'hotspot': [{'confidence': 81,
#               'date': '30/6/2018',
#               'datetime': '2018-06-30T00:27:19',
#               'latitude': -37.858,
#               'longitude': 143.428,
#               'surface_temperature_celcius': 48},
#              {'confidence': 75,
#               'date': '30/6/2018',
#               'datetime': '2018-06-30T00:27:19',
#               'latitude': -37.856,
#               'longitude': 143.416,
#               'surface_temperature_celcius': 41},
#              {'confidence': 75,
#               'date': '30/6/2018',
#               'datetime': '2018-06-30T00:27:19',
#               'latitude': -37.856,
#               'longitude': 143.416,
#               'surface_temperature_celcius': 41},
#              {'confidence': 81,
#               'date': '30/6/2018',
#               'datetime': '2018-06-30T00:27:19',
#               'latitude': -37.858,
#               'longitude': 143.428,
#               'surface_temperature_celcius': 48},
#              {'confidence': 78,
#               'date': '30/6/2018',
#               'datetime': '2018-06-30T04:41:25',
#               'latitude': -36.834,
#               'longitude': 142.524,
#               'surface_temperature_celcius': 44},
#              {'confidence': 78,
#               'date': '30/6/2018',
#               'datetime': '2018-06-30T04:41:25',
#               'latitude': -36.834,
#               'longitude': 142.524,
#               'surface_temperature_celcius': 44}],
#  'max_wind_speed': 11.1,
#  'precip_flag': 'A',
#  'precipitation': 0.0,
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  '_id': ObjectId('60a958a49343696505cf4779'),
#  'air_temperature_celcius': 5,
#  'date': '1/7/2018',
#  'hotspot': [{'confidence': 61,
#               'date': '1/7/2018',
#               'datetime': '2018-07-01T03:46:08',
#               'latitude': -36.779,
#               'longitude': 146.108,
#               'surface_temperature_celcius': 32},
#              {'confidence': 61,
#               'date': '1/7/2018',
#               'datetime': '2018-07-01T03:46:08',
#               'latitude': -36.779,
#               'longitude': 146.108,
#               'surface_temperature_celcius': 32},
#              {'confidence': 53,
#               'date': '1/7/2018',
#               'datetime': '2018-07-01T13:11:41',
#               'latitude': -37.062,
#               'longitude': 141.373,
#               'surface_temperature_celcius': 29},
#              {'confidence': 53,
#               'date': '1/7/2018',
#               'datetime': '2018-07-01T13:11:41',
#               'latitude': -37.062,
#               'longitude': 141.373,
#               'surface_temperature_celcius': 29}],
#  'max_wind_speed': 14.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 56,
#  '_id': ObjectId('60a958a49343696505cf4783'),
#  'air_temperature_celcius': 6,
#  'date': '11/7/2018',
#  'hotspot': [],
#  'max_wind_speed': 5.1,
#  'precip_flag': 'G',
#  'precipitation': 0.01,
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 57,
#  '_id': ObjectId('60a958a49343696505cf4787'),
#  'air_temperature_celcius': 6,
#  'date': '15/7/2018',
#  'hotspot': [],
#  'max_wind_speed': 9.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  '_id': ObjectId('60a958a49343696505cf477a'),
#  'air_temperature_celcius': 6,
#  'date': '2/7/2018',
#  'hotspot': [{'confidence': 50,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:28:42',
#               'latitude': -37.886,
#               'longitude': 147.207,
#               'surface_temperature_celcius': 28},
#              {'confidence': 50,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:28:42',
#               'latitude': -37.886,
#               'longitude': 147.207,
#               'surface_temperature_celcius': 28},
#              {'confidence': 88,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:29:00',
#               'latitude': -37.333,
#               'longitude': 143.534,
#               'surface_temperature_celcius': 58},
#              {'confidence': 88,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:29:00',
#               'latitude': -37.333,
#               'longitude': 143.534,
#               'surface_temperature_celcius': 58},
#              {'confidence': 69,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:29:10',
#               'latitude': -37.067,
#               'longitude': 141.379,
#               'surface_temperature_celcius': 36},
#              {'confidence': 69,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:29:10',
#               'latitude': -37.067,
#               'longitude': 141.379,
#               'surface_temperature_celcius': 36},
#              {'confidence': 84,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:29:18',
#               'latitude': -36.397,
#               'longitude': 142.254,
#               'surface_temperature_celcius': 52},
#              {'confidence': 84,
#               'date': '2/7/2018',
#               'datetime': '2018-07-02T04:29:18',
#               'latitude': -36.397,
#               'longitude': 142.254,
#               'surface_temperature_celcius': 52}],
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60a958a49343696505cf478c'),
#  'air_temperature_celcius': 7,
#  'date': '20/7/2018',
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.12,
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60a958a49343696505cf4797'),
#  'air_temperature_celcius': 7,
#  'date': '31/7/2018',
#  'hotspot': [{'confidence': 92,
#               'date': '31/7/2018',
#               'datetime': '2018-07-31T13:21:00',
#               'latitude': -37.8658,
#               'longitude': 143.4162,
#               'surface_temperature_celcius': 43},
#              {'confidence': 100,
#               'date': '31/7/2018',
#               'datetime': '2018-07-31T13:21:00',
#               'latitude': -37.8641,
#               'longitude': 143.4276,
#               'surface_temperature_celcius': 51}],
#  'max_wind_speed': 8.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60a958a49343696505cf4798'),
#  'air_temperature_celcius': 7,
#  'date': '1/8/2018',
#  'hotspot': [{'confidence': 78,
#               'date': '1/8/2018',
#               'datetime': '2018-08-01T00:19:30',
#               'latitude': -38.3982,
#               'longitude': 147.0509,
#               'surface_temperature_celcius': 51},
#              {'confidence': 89,
#               'date': '1/8/2018',
#               'datetime': '2018-08-01T00:20:30',
#               'latitude': -38.3998,
#               'longitude': 147.064,
#               'surface_temperature_celcius': 65}],
#  'max_wind_speed': 7.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 66,
#  '_id': ObjectId('60a958a49343696505cf47aa'),
#  'air_temperature_celcius': 7,
#  'date': '19/8/2018',
#  'hotspot': [],
#  'max_wind_speed': 9.9,
#  'precip_flag': 'G',
#  'precipitation': 0.04,
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %%
#j
"""
Find the records with a 24-hour precipitation recorded between 0.20 to 0.35
"""
results = collection.find({"$and":[{"precip_flag":{"$eq":"G"}},{"precipitation":{"$gte":0.2,"$lte":0.35}}]})
for result in results:
    pprint(result)
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('60a958a49343696505cf46d0'),
#  'air_temperature_celcius': 19,
#  'date': '13/1/2018',
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precip_flag': 'G',
#  'precipitation': 0.31,
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('60a958a49343696505cf471b'),
#  'air_temperature_celcius': 17,
#  'date': '29/3/2018',
#  'hotspot': [{'confidence': 69,
#               'date': '29/3/2018',
#               'datetime': '2018-03-29T00:48:40',
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51}],
#  'max_wind_speed': 21.0,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('60a958a49343696505cf4731'),
#  'air_temperature_celcius': 20,
#  'date': '20/4/2018',
#  'hotspot': [{'confidence': 76,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:12:50',
#               'latitude': -37.2212,
#               'longitude': 148.8262,
#               'surface_temperature_celcius': 49},
#              {'confidence': 54,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:13:00',
#               'latitude': -36.6363,
#               'longitude': 144.3033,
#               'surface_temperature_celcius': 40},
#              {'confidence': 63,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:13:00',
#               'latitude': -36.1569,
#               'longitude': 145.6554,
#               'surface_temperature_celcius': 41},
#              {'confidence': 76,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:13:10',
#               'latitude': -36.6407,
#               'longitude': 144.2957,
#               'surface_temperature_celcius': 50},
#              {'confidence': 61,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:13:30',
#               'latitude': -37.932,
#               'longitude': 146.1845,
#               'surface_temperature_celcius': 50},
#              {'confidence': 89,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:13:40',
#               'latitude': -37.6997,
#               'longitude': 145.5519,
#               'surface_temperature_celcius': 64},
#              {'confidence': 96,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:14:10',
#               'latitude': -36.5847,
#               'longitude': 145.1968,
#               'surface_temperature_celcius': 78},
#              {'confidence': 77,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:14:20',
#               'latitude': -37.2197,
#               'longitude': 148.8134,
#               'surface_temperature_celcius': 50},
#              {'confidence': 78,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:15:30',
#               'latitude': -36.5956,
#               'longitude': 145.206,
#               'surface_temperature_celcius': 51},
#              {'confidence': 74,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:16:50',
#               'latitude': -37.8672,
#               'longitude': 143.8194,
#               'surface_temperature_celcius': 48},
#              {'confidence': 99,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:17:10',
#               'latitude': -36.1586,
#               'longitude': 145.6666,
#               'surface_temperature_celcius': 85},
#              {'confidence': 73,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:17:10',
#               'latitude': -36.8702,
#               'longitude': 144.0381,
#               'surface_temperature_celcius': 47},
#              {'confidence': 100,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:18:20',
#               'latitude': -36.5865,
#               'longitude': 145.2081,
#               'surface_temperature_celcius': 111},
#              {'confidence': 69,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:18:20',
#               'latitude': -37.7087,
#               'longitude': 145.5499,
#               'surface_temperature_celcius': 45},
#              {'confidence': 88,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:18:40',
#               'latitude': -38.1301,
#               'longitude': 143.9398,
#               'surface_temperature_celcius': 63},
#              {'confidence': 64,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T00:19:00',
#               'latitude': -36.085,
#               'longitude': 145.9096,
#               'surface_temperature_celcius': 42},
#              {'confidence': 87,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:30',
#               'latitude': -36.9246,
#               'longitude': 147.5559,
#               'surface_temperature_celcius': 62},
#              {'confidence': 98,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:30',
#               'latitude': -36.1345,
#               'longitude': 146.351,
#               'surface_temperature_celcius': 84},
#              {'confidence': 63,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:30',
#               'latitude': -36.9189,
#               'longitude': 147.5603,
#               'surface_temperature_celcius': 52},
#              {'confidence': 80,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:30',
#               'latitude': -37.2341,
#               'longitude': 149.1736,
#               'surface_temperature_celcius': 53},
#              {'confidence': 79,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:30',
#               'latitude': -36.8846,
#               'longitude': 145.1679,
#               'surface_temperature_celcius': 52},
#              {'confidence': 85,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:30',
#               'latitude': -37.7783,
#               'longitude': 147.9284,
#               'surface_temperature_celcius': 60},
#              {'confidence': 63,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:30',
#               'latitude': -36.8079,
#               'longitude': 145.1409,
#               'surface_temperature_celcius': 42},
#              {'confidence': 67,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:50',
#               'latitude': -37.7615,
#               'longitude': 147.9169,
#               'surface_temperature_celcius': 45},
#              {'confidence': 90,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:32:50',
#               'latitude': -36.1303,
#               'longitude': 146.3606,
#               'surface_temperature_celcius': 67},
#              {'confidence': 88,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:33:20',
#               'latitude': -36.0829,
#               'longitude': 146.0621,
#               'surface_temperature_celcius': 63},
#              {'confidence': 77,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:33:40',
#               'latitude': -36.0799,
#               'longitude': 146.0784,
#               'surface_temperature_celcius': 50},
#              {'confidence': 93,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:34:10',
#               'latitude': -37.769,
#               'longitude': 147.94,
#               'surface_temperature_celcius': 72},
#              {'confidence': 60,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:34:10',
#               'latitude': -36.8922,
#               'longitude': 145.1252,
#               'surface_temperature_celcius': 40},
#              {'confidence': 59,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:36:00',
#               'latitude': -38.4685,
#               'longitude': 146.673,
#               'surface_temperature_celcius': 40},
#              {'confidence': 84,
#               'date': '20/4/2018',
#               'datetime': '2018-04-20T04:44:20',
#               'latitude': -36.8871,
#               'longitude': 145.1536,
#               'surface_temperature_celcius': 58}],
#  'max_wind_speed': 15.9,
#  'precip_flag': 'G',
#  'precipitation': 0.31,
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60a958a49343696505cf4737'),
#  'air_temperature_celcius': 11,
#  'date': '26/4/2018',
#  'hotspot': [{'confidence': 56,
#               'date': '26/4/2018',
#               'datetime': '2018-04-26T13:26:10',
#               'latitude': -36.5511,
#               'longitude': 146.7819,
#               'surface_temperature_celcius': 34}],
#  'max_wind_speed': 20.0,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60a958a49343696505cf4756'),
#  'air_temperature_celcius': 14,
#  'date': '27/5/2018',
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precip_flag': 'G',
#  'precipitation': 0.35,
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60a958a49343696505cf4759'),
#  'air_temperature_celcius': 8,
#  'date': '30/5/2018',
#  'hotspot': [],
#  'max_wind_speed': 15.9,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('60a958a49343696505cf477b'),
#  'air_temperature_celcius': 11,
#  'date': '3/7/2018',
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('60a958a49343696505cf4793'),
#  'air_temperature_celcius': 11,
#  'date': '27/7/2018',
#  'hotspot': [],
#  'max_wind_speed': 21.0,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60a958a49343696505cf479d'),
#  'air_temperature_celcius': 9,
#  'date': '6/8/2018',
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60a958a49343696505cf47b1'),
#  'air_temperature_celcius': 11,
#  'date': '26/8/2018',
#  'hotspot': [],
#  'max_wind_speed': 19.0,
#  'precip_flag': 'G',
#  'precipitation': 0.28,
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  '_id': ObjectId('60a958a49343696505cf47bb'),
#  'air_temperature_celcius': 8,
#  'date': '5/9/2018',
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precip_flag': 'G',
#  'precipitation': 0.31,
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('60a958a49343696505cf47bd'),
#  'air_temperature_celcius': 10,
#  'date': '7/9/2018',
#  'hotspot': [],
#  'max_wind_speed': 14.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('60a958a49343696505cf47c5'),
#  'air_temperature_celcius': 11,
#  'date': '15/9/2018',
#  'hotspot': [],
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.28,
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('60a958a49343696505cf47d9'),
#  'air_temperature_celcius': 12,
#  'date': '5/10/2018',
#  'hotspot': [],
#  'max_wind_speed': 18.1,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('60a958a49343696505cf47f1'),
#  'air_temperature_celcius': 17,
#  'date': '29/10/2018',
#  'hotspot': [],
#  'max_wind_speed': 27.0,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('60a958a49343696505cf47f2'),
#  'air_temperature_celcius': 11,
#  'date': '30/10/2018',
#  'hotspot': [],
#  'max_wind_speed': 14.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60a958a49343696505cf4803'),
#  'air_temperature_celcius': 18,
#  'date': '16/11/2018',
#  'hotspot': [],
#  'max_wind_speed': 11.1,
#  'precip_flag': 'G',
#  'precipitation': 0.28,
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('60a958a49343696505cf4804'),
#  'air_temperature_celcius': 19,
#  'date': '17/11/2018',
#  'hotspot': [],
#  'max_wind_speed': 12.0,
#  'precip_flag': 'G',
#  'precipitation': 0.28,
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60a958a49343696505cf4811'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'hotspot': [{'confidence': 64,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:49',
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41},
#              {'confidence': 69,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:53',
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50},
#              {'confidence': 81,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:53',
#               'latitude': -37.602,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 55},
#              {'confidence': 73,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:53',
#               'latitude': -37.603,
#               'longitude': 149.324,
#               'surface_temperature_celcius': 51},
#              {'confidence': 81,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:53',
#               'latitude': -37.61,
#               'longitude': 149.296,
#               'surface_temperature_celcius': 56},
#              {'confidence': 95,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:53',
#               'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76},
#              {'confidence': 87,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:53',
#               'latitude': -37.62,
#               'longitude': 149.294,
#               'surface_temperature_celcius': 63},
#              {'confidence': 83,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:20:53',
#               'latitude': -37.608,
#               'longitude': 149.282,
#               'surface_temperature_celcius': 58},
#              {'confidence': 60,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T00:21:00',
#               'latitude': -37.637,
#               'longitude': 146.288,
#               'surface_temperature_celcius': 42},
#              {'confidence': 69,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T04:34:57',
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48},
#              {'confidence': 99,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T04:34:57',
#               'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86},
#              {'confidence': 84,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T04:34:57',
#               'latitude': -37.623,
#               'longitude': 149.284,
#               'surface_temperature_celcius': 61},
#              {'confidence': 81,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T04:34:57',
#               'latitude': -37.627,
#               'longitude': 149.261,
#               'surface_temperature_celcius': 57},
#              {'confidence': 98,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T04:34:57',
#               'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83},
#              {'confidence': 73,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T04:35:00',
#               'latitude': -37.389,
#               'longitude': 149.311,
#               'surface_temperature_celcius': 50},
#              {'confidence': 84,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T04:35:00',
#               'latitude': -37.384,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 59},
#              {'confidence': 100,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T12:22:14',
#               'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71},
#              {'confidence': 100,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T12:22:15',
#               'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65},
#              {'confidence': 100,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T12:22:15',
#               'latitude': -37.644,
#               'longitude': 149.233,
#               'surface_temperature_celcius': 55},
#              {'confidence': 81,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T12:22:15',
#               'latitude': -37.63,
#               'longitude': 149.232,
#               'surface_temperature_celcius': 42},
#              {'confidence': 84,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T12:22:15',
#               'latitude': -37.596,
#               'longitude': 149.319,
#               'surface_temperature_celcius': 38},
#              {'confidence': 64,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T12:22:15',
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32},
#              {'confidence': 62,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T12:22:15',
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33},
#              {'confidence': 61,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T15:38:32',
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31},
#              {'confidence': 100,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T15:38:35',
#               'latitude': -37.583,
#               'longitude': 149.316,
#               'surface_temperature_celcius': 49},
#              {'confidence': 69,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T15:38:35',
#               'latitude': -37.58,
#               'longitude': 149.331,
#               'surface_temperature_celcius': 35},
#              {'confidence': 100,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T15:38:35',
#               'latitude': -37.585,
#               'longitude': 149.336,
#               'surface_temperature_celcius': 54},
#              {'confidence': 64,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T15:38:36',
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42},
#              {'confidence': 51,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T15:38:36',
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42},
#              {'confidence': 100,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T15:38:36',
#               'latitude': -37.591,
#               'longitude': 149.33,
#               'surface_temperature_celcius': 53},
#              {'confidence': 52,
#               'date': '30/11/2018',
#               'datetime': '2018-11-30T23:25:57',
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47}],
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}

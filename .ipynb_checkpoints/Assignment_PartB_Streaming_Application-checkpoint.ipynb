# %% [markdown]
# Name : Tan Sook Mun
#
# ID   : 30695759
#
# Email: stan0111@student.monash.edu

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.3.0 pyspark-shell'

import sys
import time
import json
from pymongo import MongoClient
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils
import pygeohash as pgh

def sendDataToDB(iter):    
    #Store the message into local variable
    aqua_records=[]
    terra_records=[]
    climate={}
    for record in iter:
        key=record[0]
        if key == "producer1":
            #rstore the climate
            climate = json.loads(record[1])
        elif key == "producer2":
            #if is from aqua store in aqua_records
            aqua_records.append(json.loads(record[1]))
        else:
            #if is from aqua store in terra_records
            terra_records.append(json.loads(record[1]))

    if climate!={}: #if no climate data dont store anything in database
        # Data processing
        hotspot=[]
        fire_event=[]
        cli_long=climate.get('longitude')
        cli_lat=climate.get('latitude')
        #look at aqua hotspots
        for aqua in aqua_records:
            long=aqua.get('longitude')
            lat=aqua.get('latitude')
            #checking if the area is close to each other in precission 3
            hash_a=pgh.encode(long,lat,precision=3)
            hash_b=pgh.encode(cli_long,cli_lat,precision=3)
            if hash_a!=hash_b: #if is not close
                aqua_records.remove(aqua) #remove hotspots that are far
            else: #if is close
                aqua["date"]=climate.get('date')#add the date 
                hotspot.append(aqua)#append into the list of hotspots
                
        #look at aqua hotspots
        for terra in terra_records:
            long=terra.get('longitude')
            lat=terra.get('latitude')
            hash_a=pgh.encode(long,lat,precision=3)
            hash_b=pgh.encode(cli_long,cli_lat,precision=3)
            if hash_a!=hash_b:
                terra_records.remove(terra)#remove hotspots that are far                 
            else: #if is close
                terra["date"]=climate.get('date')#add the date 
                hotspot.append(terra)#append into the list of hotspots

        climate["hotspots"]=hotspot
        if (len(aqua_records)>0 and len(terra_records)>0): #ensure there is aqua and terra data to compare 
            for aqua in aqua_records: #for each aqau check if it matches with terra
                aqua_long=aqua.get('longitude')
                aqua_lat=aqua.get('latitude')
                for terra in terra_records:
                    terra_long=aqua.get('longitude')
                    terra_lat=aqua.get('latitude')
                    hash_a=pgh.encode(aqua_long,aqua_lat,precision=5)
                    hash_b=pgh.encode(terra_long,terra_lat,precision=5)
                    if hash_a==hash_b: #if in the same location
                        fire={} #create a fire object
                        #get the avg values
                        fire["avg_surface_temp"]=(aqua["surface_temperature_celcius"]+
                                                  terra["surface_temperature_celcius"])/2
                        fire["confidence"]=(aqua["confidence"]+terra["confidence"])/2
                        #determine if the fire is natural or others
                        if climate.get("air_temperature_celcius")>20 and climate.get("GHI_w/m2")>180:
                            fire["cause"]="natural"
                        else:
                            fire["cause"]="others"
                        #setting the new key hour for the data visualition
                        fire["hour"]=int(terra.get("time")[0:2])
                        fire_event.append(fire)#append the collection of fire events
                        
        climate["fire_events"]=fire_event #add it an array of fire even into the key "fire_events"

    #Storing data into DB
    print("STORING PART")
    client = MongoClient()
    db = client.fit3182_assignment_db
    partB = db.partB
    if climate !={}: #if not climate dont store anything
        try:
            partB.insert(climate) #insert climate data
            print("inserted",climate)
        except Exception as ex:
            print("Exception Occured. Message: {0}".format(str(ex)))
    client.close()

    
##-------------------------------------------------------------------------------
n_secs = 10
topic = "partB"

conf = SparkConf().setAppName("KafkaStreamProcessor").setMaster("local[2]")
sc = SparkContext.getOrCreate()
sc.setLogLevel("WARN")
ssc = StreamingContext(sc, n_secs)
    
kafkaStream = KafkaUtils.createDirectStream(ssc, [topic], {
                        'bootstrap.servers':'127.0.0.1:9092', 
                        'group.id':'week11-group', 
                        'fetch.message.max.bytes':'15728640',
                        'auto.offset.reset':'largest'})
                        # Group ID is completely arbitrary

lines = kafkaStream.foreachRDD(lambda rdd: rdd.foreachPartition(sendDataToDB))

ssc.start()
time.sleep(600) # Run stream for 10 minutes just in case no detection of producer
# ssc.awaitTermination()
ssc.stop(stopSparkContext=True,stopGraceFully=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5eb8d8db7e18> in <module>()
#     121
#     122 ssc.start()
# --> 123 time.sleep(600) # Run stream for 10 minutes just in case no detection of producer
#     124 # ssc.awaitTermination()
#     125 ssc.stop(stopSparkContext=True,stopGraceFully=True)
#
# ~/.local/lib/python3.5/site-packages/pyspark/context.py in signal_handler(signal, frame)
#     232         def signal_handler(signal, frame):
#     233             self.cancelAllJobs()
# --> 234             raise KeyboardInterrupt()
#     235
#     236         # see http://stackoverflow.com/questions/23206787/
#
# KeyboardInterrupt:

# %%
#to check the records that has been added into the collection partB
from pymongo import MongoClient
from pprint import pprint

client = MongoClient()
db = client.fit3182_assignment_db
partB = db.partB
m=partB.find()
count=0
for a in m:
    pprint(a)
    count+=1
print(count)
# Out:
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60aa08ce9343690ee21a8da0'),
#  'air_temperature_celcius': 18,
#  'date': '2019-01-05',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 60.0,
#                   'cause': 'others',
#                   'confidence': 82.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 68.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 82.0,
#                   'cause': 'others',
#                   'confidence': 97.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 67.0,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 67.0,
#                   'cause': 'others',
#                   'confidence': 85.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 64.0,
#                   'cause': 'others',
#                   'confidence': 86.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 72.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 74.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 60.0,
#                   'cause': 'others',
#                   'confidence': 82.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 68.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 65,
#                'date': '2019-01-05',
#                'latitude': -36.0902,
#                'longitude': 143.8394,
#                'surface_temperature_celcius': 42,
#                'time': '22:35:43'},
#               {'confidence': 51,
#                'date': '2019-01-05',
#                'latitude': -36.4466,
#                'longitude': 141.2471,
#                'surface_temperature_celcius': 40,
#                'time': '08:11:46'},
#               {'confidence': 74,
#                'date': '2019-01-05',
#                'latitude': -36.2417,
#                'longitude': 143.6232,
#                'surface_temperature_celcius': 48,
#                'time': '17:47:46'}],
#  'latitude': -37.63,
#  'longitude': 149.232,
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 57.0,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60aa08d89343690ee21a8da2'),
#  'air_temperature_celcius': 12,
#  'date': '2019-01-06',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 46.5,
#                   'cause': 'others',
#                   'confidence': 70.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 45.5,
#                   'cause': 'others',
#                   'confidence': 69.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 68.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 52.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 72.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 50.5,
#                   'cause': 'others',
#                   'confidence': 72.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 65.0,
#                   'cause': 'others',
#                   'confidence': 87.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 64.0,
#                   'cause': 'others',
#                   'confidence': 85.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 63.5,
#                   'cause': 'others',
#                   'confidence': 85.0,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 76,
#                'date': '2019-01-06',
#                'latitude': -36.3374,
#                'longitude': 141.041,
#                'surface_temperature_celcius': 49,
#                'time': '17:47:43'},
#               {'confidence': 78,
#                'date': '2019-01-06',
#                'latitude': -35.9326,
#                'longitude': 141.958,
#                'surface_temperature_celcius': 66,
#                'time': '03:23:43'},
#               {'confidence': 70,
#                'date': '2019-01-06',
#                'latitude': -36.4604,
#                'longitude': 142.1623,
#                'surface_temperature_celcius': 48,
#                'time': '08:11:46'},
#               {'confidence': 81,
#                'date': '2019-01-06',
#                'latitude': -36.285,
#                'longitude': 146.151,
#                'surface_temperature_celcius': 54,
#                'time': '22:35:46'}],
#  'latitude': -37.9072,
#  'longitude': 141.9183,
#  'max_wind_speed': 11.1,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 43.3,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 126,
#  '_id': ObjectId('60aa08e29343690ee21a8da4'),
#  'air_temperature_celcius': 14,
#  'date': '2019-01-07',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 44.0,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 44.0,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 62.0,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 62.0,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 41.5,
#                   'cause': 'others',
#                   'confidence': 62.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 41.5,
#                   'cause': 'others',
#                   'confidence': 62.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 84,
#                'date': '2019-01-07',
#                'latitude': -36.2933,
#                'longitude': 141.6923,
#                'surface_temperature_celcius': 58,
#                'time': '08:11:43'},
#               {'confidence': 66,
#                'date': '2019-01-07',
#                'latitude': -36.4844,
#                'longitude': 143.9663,
#                'surface_temperature_celcius': 43,
#                'time': '08:11:46'},
#               {'confidence': 78,
#                'date': '2019-01-07',
#                'latitude': -36.1411,
#                'longitude': 143.5727,
#                'surface_temperature_celcius': 51,
#                'time': '17:47:46'},
#               {'confidence': 84,
#                'date': '2019-01-07',
#                'latitude': -36.277,
#                'longitude': 146.165,
#                'surface_temperature_celcius': 58,
#                'time': '03:23:46'}],
#  'latitude': -37.434,
#  'longitude': 148.123,
#  'max_wind_speed': 27.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 43.7,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('60aa08ec9343690ee21a8da6'),
#  'air_temperature_celcius': 15,
#  'date': '2019-01-08',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 47.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 42.5,
#                   'cause': 'others',
#                   'confidence': 79.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 47.0,
#                   'cause': 'others',
#                   'confidence': 71.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 55.0,
#                   'cause': 'others',
#                   'confidence': 84.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 50.5,
#                   'cause': 'others',
#                   'confidence': 89.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 55.0,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 55.5,
#                   'cause': 'others',
#                   'confidence': 85.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 90.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 55.5,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 59,
#                'date': '2019-01-08',
#                'latitude': -37.5077,
#                'longitude': 143.2495,
#                'surface_temperature_celcius': 40,
#                'time': '17:47:43'},
#               {'confidence': 98,
#                'date': '2019-01-08',
#                'latitude': -36.9329,
#                'longitude': 143.7796,
#                'surface_temperature_celcius': 82,
#                'time': '08:11:43'},
#               {'confidence': 65,
#                'date': '2019-01-08',
#                'latitude': -37.441,
#                'longitude': 142.9966,
#                'surface_temperature_celcius': 42,
#                'time': '12:59:46'},
#               {'confidence': 67,
#                'date': '2019-01-08',
#                'latitude': -36.7314,
#                'longitude': 141.8698,
#                'surface_temperature_celcius': 44,
#                'time': '22:35:46'}],
#  'latitude': -36.3674,
#  'longitude': 143.7295,
#  'max_wind_speed': 20.0,
#  'precip_flag': 'G',
#  'precipitation': 0.01,
#  'relative_humidity': 48.7,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 93,
#  '_id': ObjectId('60aa08f69343690ee21a8da8'),
#  'air_temperature_celcius': 10,
#  'date': '2019-01-09',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 51.5,
#                   'cause': 'others',
#                   'confidence': 72.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 52.5,
#                   'cause': 'others',
#                   'confidence': 77.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 51.5,
#                   'cause': 'others',
#                   'confidence': 73.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 55.5,
#                   'cause': 'others',
#                   'confidence': 80.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 46.0,
#                   'cause': 'others',
#                   'confidence': 67.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 47.0,
#                   'cause': 'others',
#                   'confidence': 72.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 46.0,
#                   'cause': 'others',
#                   'confidence': 68.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 50.0,
#                   'cause': 'others',
#                   'confidence': 75.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 69.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 48.5,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 51.5,
#                   'cause': 'others',
#                   'confidence': 77.0,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 75,
#                'date': '2019-01-09',
#                'latitude': -36.241,
#                'longitude': 143.1229,
#                'surface_temperature_celcius': 53,
#                'time': '17:47:43'},
#               {'confidence': 65,
#                'date': '2019-01-09',
#                'latitude': -36.3115,
#                'longitude': 143.3581,
#                'surface_temperature_celcius': 42,
#                'time': '03:23:43'},
#               {'confidence': 100,
#                'date': '2019-01-09',
#                'latitude': -38.2003,
#                'longitude': 146.8378,
#                'surface_temperature_celcius': 58,
#                'time': '03:23:46'}],
#  'latitude': -36.984,
#  'longitude': 148.25,
#  'max_wind_speed': 16.9,
#  'precip_flag': 'G',
#  'precipitation': 0.08,
#  'relative_humidity': 39.9,
#  'windspeed_knots': 12.6}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60aa09009343690ee21a8daa'),
#  'air_temperature_celcius': 14,
#  'date': '2019-01-10',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 86.5,
#                   'cause': 'others',
#                   'confidence': 93.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 101.0,
#                   'cause': 'others',
#                   'confidence': 97.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 71.5,
#                   'cause': 'others',
#                   'confidence': 77.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 74.5,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 56.5,
#                   'cause': 'others',
#                   'confidence': 79.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 71.0,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 41.5,
#                   'cause': 'others',
#                   'confidence': 63.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 44.5,
#                   'cause': 'others',
#                   'confidence': 69.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 73.5,
#                   'cause': 'others',
#                   'confidence': 93.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 88.0,
#                   'cause': 'others',
#                   'confidence': 97.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 58.5,
#                   'cause': 'others',
#                   'confidence': 77.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 61.5,
#                   'cause': 'others',
#                   'confidence': 83.5,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 98,
#                'date': '2019-01-10',
#                'latitude': -34.3526,
#                'longitude': 141.6458,
#                'surface_temperature_celcius': 82,
#                'time': '17:47:43'},
#               {'confidence': 87,
#                'date': '2019-01-10',
#                'latitude': -34.3795,
#                'longitude': 141.6331,
#                'surface_temperature_celcius': 62,
#                'time': '08:11:43'},
#               {'confidence': 99,
#                'date': '2019-01-10',
#                'latitude': -34.351,
#                'longitude': 141.6567,
#                'surface_temperature_celcius': 86,
#                'time': '22:35:46'}],
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'max_wind_speed': 30.9,
#  'precip_flag': 'G',
#  'precipitation': 0.01,
#  'relative_humidity': 39.3,
#  'windspeed_knots': 17.7}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('60aa090a9343690ee21a8dac'),
#  'air_temperature_celcius': 10,
#  'date': '2019-01-11',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 73.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 73.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 44.0,
#                   'cause': 'others',
#                   'confidence': 68.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 75.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 75.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 45.5,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 59.0,
#                   'cause': 'others',
#                   'confidence': 84.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 59.0,
#                   'cause': 'others',
#                   'confidence': 84.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 55.5,
#                   'cause': 'others',
#                   'confidence': 78.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 78.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 78.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 72.5,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 84,
#                'date': '2019-01-11',
#                'latitude': -37.978,
#                'longitude': 145.623,
#                'surface_temperature_celcius': 59,
#                'time': '12:59:43'},
#               {'confidence': 82,
#                'date': '2019-01-11',
#                'latitude': -36.0994,
#                'longitude': 143.4156,
#                'surface_temperature_celcius': 62,
#                'time': '08:11:46'},
#               {'confidence': 68,
#                'date': '2019-01-11',
#                'latitude': -36.3891,
#                'longitude': 141.0253,
#                'surface_temperature_celcius': 44,
#                'time': '22:35:46'}],
#  'latitude': -37.448,
#  'longitude': 148.114,
#  'max_wind_speed': 11.1,
#  'precip_flag': 'G',
#  'precipitation': 0.12,
#  'relative_humidity': 44.4,
#  'windspeed_knots': 5.6}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60aa09149343690ee21a8dae'),
#  'air_temperature_celcius': 19,
#  'date': '2019-01-12',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 59.5,
#                   'cause': 'others',
#                   'confidence': 84.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 60.5,
#                   'cause': 'others',
#                   'confidence': 85.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 50.5,
#                   'cause': 'others',
#                   'confidence': 76.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 60.0,
#                   'cause': 'others',
#                   'confidence': 80.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 61.0,
#                   'cause': 'others',
#                   'confidence': 80.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 72.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 58.0,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 59.0,
#                   'cause': 'others',
#                   'confidence': 83.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 75.0,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 72,
#                'date': '2019-01-12',
#                'latitude': -36.0313,
#                'longitude': 143.6296,
#                'surface_temperature_celcius': 47,
#                'time': '17:47:43'},
#               {'confidence': 67,
#                'date': '2019-01-12',
#                'latitude': -36.1751,
#                'longitude': 142.7831,
#                'surface_temperature_celcius': 43,
#                'time': '03:23:43'},
#               {'confidence': 76,
#                'date': '2019-01-12',
#                'latitude': -36.4315,
#                'longitude': 141.1987,
#                'surface_temperature_celcius': 49,
#                'time': '08:11:46'},
#               {'confidence': 75,
#                'date': '2019-01-12',
#                'latitude': -36.309,
#                'longitude': 141.4964,
#                'surface_temperature_celcius': 48,
#                'time': '17:47:46'}],
#  'latitude': -37.586,
#  'longitude': 141.271,
#  'max_wind_speed': 11.1,
#  'precip_flag': 'G',
#  'precipitation': 0.83,
#  'relative_humidity': 60.5,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('60aa091e9343690ee21a8db0'),
#  'air_temperature_celcius': 10,
#  'date': '2019-01-13',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 44.0,
#                   'cause': 'others',
#                   'confidence': 58.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 72.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 46.5,
#                   'cause': 'others',
#                   'confidence': 68.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 45.5,
#                   'cause': 'others',
#                   'confidence': 64.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 50.5,
#                   'cause': 'others',
#                   'confidence': 77.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 48.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 95,
#                'date': '2019-01-13',
#                'latitude': -36.8009,
#                'longitude': 142.7259,
#                'surface_temperature_celcius': 76,
#                'time': '17:47:43'},
#               {'confidence': 82,
#                'date': '2019-01-13',
#                'latitude': -36.9887,
#                'longitude': 142.6515,
#                'surface_temperature_celcius': 55,
#                'time': '03:23:43'},
#               {'confidence': 93,
#                'date': '2019-01-13',
#                'latitude': -38.057,
#                'longitude': 144.211,
#                'surface_temperature_celcius': 73,
#                'time': '08:11:46'},
#               {'confidence': 64,
#                'date': '2019-01-13',
#                'latitude': -36.934,
#                'longitude': 142.5759,
#                'surface_temperature_celcius': 47,
#                'time': '03:23:46'}],
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'max_wind_speed': 14.0,
#  'precip_flag': 'G',
#  'precipitation': 0.2,
#  'relative_humidity': 43.6,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60aa09289343690ee21a8db2'),
#  'air_temperature_celcius': 18,
#  'date': '2019-01-14',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 60.5,
#                   'cause': 'others',
#                   'confidence': 84.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 55.5,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 62.0,
#                   'cause': 'others',
#                   'confidence': 85.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 50.0,
#                   'cause': 'others',
#                   'confidence': 74.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 67.5,
#                   'cause': 'others',
#                   'confidence': 87.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 82.5,
#                   'cause': 'others',
#                   'confidence': 96.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 77.5,
#                   'cause': 'others',
#                   'confidence': 93.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 84.0,
#                   'cause': 'others',
#                   'confidence': 97.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 72.0,
#                   'cause': 'others',
#                   'confidence': 86.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 89.5,
#                   'cause': 'others',
#                   'confidence': 99.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 58.0,
#                   'cause': 'others',
#                   'confidence': 80.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 53.0,
#                   'cause': 'others',
#                   'confidence': 77.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 59.5,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 70.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 65.0,
#                   'cause': 'others',
#                   'confidence': 83.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 58.0,
#                   'cause': 'others',
#                   'confidence': 81.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 53.0,
#                   'cause': 'others',
#                   'confidence': 78.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 59.5,
#                   'cause': 'others',
#                   'confidence': 82.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 71.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 65.0,
#                   'cause': 'others',
#                   'confidence': 84.0,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 87,
#                'date': '2019-01-14',
#                'latitude': -36.0757,
#                'longitude': 142.3606,
#                'surface_temperature_celcius': 62,
#                'time': '22:35:43'}],
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.5,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('60aa09329343690ee21a8db4'),
#  'air_temperature_celcius': 24,
#  'date': '2019-01-15',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 61.5,
#                   'cause': 'natural',
#                   'confidence': 86.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 52.5,
#                   'cause': 'natural',
#                   'confidence': 79.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 79.0,
#                   'cause': 'natural',
#                   'confidence': 87.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 67.0,
#                   'cause': 'natural',
#                   'confidence': 90.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 58.0,
#                   'cause': 'natural',
#                   'confidence': 83.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 84.5,
#                   'cause': 'natural',
#                   'confidence': 91.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 61.0,
#                   'cause': 'natural',
#                   'confidence': 75.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 52.0,
#                   'cause': 'natural',
#                   'confidence': 69.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 78.5,
#                   'cause': 'natural',
#                   'confidence': 77.0,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 76,
#                'date': '2019-01-15',
#                'latitude': -36.99,
#                'longitude': 142.9147,
#                'surface_temperature_celcius': 49,
#                'time': '17:47:43'},
#               {'confidence': 100,
#                'date': '2019-01-15',
#                'latitude': -37.9047,
#                'longitude': 141.0945,
#                'surface_temperature_celcius': 90,
#                'time': '03:23:43'},
#               {'confidence': 76,
#                'date': '2019-01-15',
#                'latitude': -37.4551,
#                'longitude': 143.7902,
#                'surface_temperature_celcius': 49,
#                'time': '12:59:46'},
#               {'confidence': 97,
#                'date': '2019-01-15',
#                'latitude': -37.0669,
#                'longitude': 141.0556,
#                'surface_temperature_celcius': 80,
#                'time': '22:35:46'}],
#  'latitude': -36.2111,
#  'longitude': 141.505,
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 55.5,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60aa093c9343690ee21a8db6'),
#  'air_temperature_celcius': 15,
#  'date': '2019-01-16',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 55.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 52.5,
#                   'cause': 'others',
#                   'confidence': 70.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 51.5,
#                   'cause': 'others',
#                   'confidence': 77.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 73.5,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 62,
#                'date': '2019-01-16',
#                'latitude': -36.758,
#                'longitude': 145.19,
#                'surface_temperature_celcius': 51,
#                'time': '12:59:43'},
#               {'confidence': 56,
#                'date': '2019-01-16',
#                'latitude': -36.8241,
#                'longitude': 145.1274,
#                'surface_temperature_celcius': 39,
#                'time': '22:35:43'},
#               {'confidence': 61,
#                'date': '2019-01-16',
#                'latitude': -37.347,
#                'longitude': 148.019,
#                'surface_temperature_celcius': 36,
#                'time': '08:11:43'},
#               {'confidence': 64,
#                'date': '2019-01-16',
#                'latitude': -37.633,
#                'longitude': 149.264,
#                'surface_temperature_celcius': 42,
#                'time': '08:11:46'},
#               {'confidence': 78,
#                'date': '2019-01-16',
#                'latitude': -37.966,
#                'longitude': 145.051,
#                'surface_temperature_celcius': 68,
#                'time': '17:47:46'},
#               {'confidence': 68,
#                'date': '2019-01-16',
#                'latitude': -37.136,
#                'longitude': 141.7239,
#                'surface_temperature_celcius': 44,
#                'time': '03:23:46'}],
#  'latitude': -36.543,
#  'longitude': 141.138,
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 47.7,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 120,
#  '_id': ObjectId('60aa09469343690ee21a8db8'),
#  'air_temperature_celcius': 14,
#  'date': '2019-01-17',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 68.5,
#                   'cause': 'others',
#                   'confidence': 77.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 57.5,
#                   'cause': 'others',
#                   'confidence': 70.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 57.5,
#                   'cause': 'others',
#                   'confidence': 70.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 68.5,
#                   'cause': 'others',
#                   'confidence': 90.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 57.5,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 57.5,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 62.0,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 76.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 76.0,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 100,
#                'date': '2019-01-17',
#                'latitude': -38.1665,
#                'longitude': 143.062,
#                'surface_temperature_celcius': 124,
#                'time': '17:47:43'},
#               {'confidence': 81,
#                'date': '2019-01-17',
#                'latitude': -34.2782,
#                'longitude': 142.2253,
#                'surface_temperature_celcius': 54,
#                'time': '03:23:43'},
#               {'confidence': 89,
#                'date': '2019-01-17',
#                'latitude': -38.4792,
#                'longitude': 146.3081,
#                'surface_temperature_celcius': 65,
#                'time': '12:59:46'},
#               {'confidence': 100,
#                'date': '2019-01-17',
#                'latitude': -38.0795,
#                'longitude': 143.2449,
#                'surface_temperature_celcius': 91,
#                'time': '03:23:46'}],
#  'latitude': -36.752,
#  'longitude': 144.15,
#  'max_wind_speed': 20.0,
#  'precip_flag': 'G',
#  'precipitation': 0.01,
#  'relative_humidity': 50.4,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60aa09509343690ee21a8dba'),
#  'air_temperature_celcius': 8,
#  'date': '2019-01-18',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 75.5,
#                   'cause': 'others',
#                   'confidence': 85.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 76.5,
#                   'cause': 'others',
#                   'confidence': 82.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 43.5,
#                   'cause': 'others',
#                   'confidence': 73.0,
#                   'hour': 3},
#                  {'avg_surface_temp': 77.5,
#                   'cause': 'others',
#                   'confidence': 86.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 78.5,
#                   'cause': 'others',
#                   'confidence': 83.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 45.5,
#                   'cause': 'others',
#                   'confidence': 74.5,
#                   'hour': 3},
#                  {'avg_surface_temp': 83.0,
#                   'cause': 'others',
#                   'confidence': 92.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 84.0,
#                   'cause': 'others',
#                   'confidence': 89.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 80.5,
#                   'hour': 3}],
#  'hotspots': [{'confidence': 81,
#                'date': '2019-01-18',
#                'latitude': -36.2205,
#                'longitude': 141.7933,
#                'surface_temperature_celcius': 54,
#                'time': '22:35:43'},
#               {'confidence': 68,
#                'date': '2019-01-18',
#                'latitude': -38.2481,
#                'longitude': 142.8381,
#                'surface_temperature_celcius': 44,
#                'time': '08:11:43'},
#               {'confidence': 74,
#                'date': '2019-01-18',
#                'latitude': -36.2417,
#                'longitude': 143.6232,
#                'surface_temperature_celcius': 48,
#                'time': '12:59:46'},
#               {'confidence': 74,
#                'date': '2019-01-18',
#                'latitude': -35.4591,
#                'longitude': 142.062,
#                'surface_temperature_celcius': 48,
#                'time': '22:35:46'}],
#  'latitude': -37.238,
#  'longitude': 141.145,
#  'max_wind_speed': 15.9,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 41.6,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('60aa095a9343690ee21a8dbc'),
#  'air_temperature_celcius': 18,
#  'date': '2019-01-19',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 46.5,
#                   'cause': 'others',
#                   'confidence': 71.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 54.0,
#                   'cause': 'others',
#                   'confidence': 80.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 47.0,
#                   'cause': 'others',
#                   'confidence': 72.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 52.5,
#                   'cause': 'others',
#                   'confidence': 64.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 60.0,
#                   'cause': 'others',
#                   'confidence': 73.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 53.0,
#                   'cause': 'others',
#                   'confidence': 65.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 68.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 52.5,
#                   'cause': 'others',
#                   'confidence': 78.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 45.5,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 41.0,
#                   'cause': 'others',
#                   'confidence': 61.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 48.5,
#                   'cause': 'others',
#                   'confidence': 71.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 41.5,
#                   'cause': 'others',
#                   'confidence': 63.0,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 73,
#                'date': '2019-01-19',
#                'latitude': -35.4509,
#                'longitude': 143.1522,
#                'surface_temperature_celcius': 47,
#                'time': '08:11:43'},
#               {'confidence': 54,
#                'date': '2019-01-19',
#                'latitude': -35.7608,
#                'longitude': 143.3545,
#                'surface_temperature_celcius': 47,
#                'time': '08:11:46'},
#               {'confidence': 90,
#                'date': '2019-01-19',
#                'latitude': -36.4325,
#                'longitude': 144.3142,
#                'surface_temperature_celcius': 67,
#                'time': '03:23:46'}],
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 49.4,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60aa09649343690ee21a8dbe'),
#  'air_temperature_celcius': 9,
#  'date': '2019-01-20',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 36.0,
#                   'cause': 'others',
#                   'confidence': 58.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 44.5,
#                   'cause': 'others',
#                   'confidence': 69.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 52.0,
#                   'cause': 'others',
#                   'confidence': 83.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 55.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 63.5,
#                   'cause': 'others',
#                   'confidence': 84.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 71.0,
#                   'cause': 'others',
#                   'confidence': 98.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 38.0,
#                   'cause': 'others',
#                   'confidence': 56.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 46.5,
#                   'cause': 'others',
#                   'confidence': 67.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 54.0,
#                   'cause': 'others',
#                   'confidence': 81.0,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 84,
#                'date': '2019-01-20',
#                'latitude': -36.3295,
#                'longitude': 142.3494,
#                'surface_temperature_celcius': 58,
#                'time': '12:59:43'},
#               {'confidence': 62,
#                'date': '2019-01-20',
#                'latitude': -36.3557,
#                'longitude': 141.3268,
#                'surface_temperature_celcius': 52,
#                'time': '08:11:43'},
#               {'confidence': 81,
#                'date': '2019-01-20',
#                'latitude': -38.0652,
#                'longitude': 142.9781,
#                'surface_temperature_celcius': 54,
#                'time': '08:11:46'},
#               {'confidence': 100,
#                'date': '2019-01-20',
#                'latitude': -35.6374,
#                'longitude': 142.3787,
#                'surface_temperature_celcius': 95,
#                'time': '03:23:46'}],
#  'latitude': -37.559,
#  'longitude': 148.037,
#  'max_wind_speed': 19.0,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 41.1,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 216,
#  '_id': ObjectId('60aa096e9343690ee21a8dc0'),
#  'air_temperature_celcius': 26,
#  'date': '2019-01-21',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 42.5,
#                   'cause': 'natural',
#                   'confidence': 77.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 44.5,
#                   'cause': 'natural',
#                   'confidence': 62.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 46.0,
#                   'cause': 'natural',
#                   'confidence': 77.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 36.5,
#                   'cause': 'natural',
#                   'confidence': 68.0,
#                   'hour': 8},
#                  {'avg_surface_temp': 38.5,
#                   'cause': 'natural',
#                   'confidence': 53.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 40.0,
#                   'cause': 'natural',
#                   'confidence': 68.0,
#                   'hour': 22},
#                  {'avg_surface_temp': 47.0,
#                   'cause': 'natural',
#                   'confidence': 80.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'natural',
#                   'confidence': 65.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 50.5,
#                   'cause': 'natural',
#                   'confidence': 80.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 40.0,
#                   'cause': 'natural',
#                   'confidence': 68.5,
#                   'hour': 8},
#                  {'avg_surface_temp': 42.0,
#                   'cause': 'natural',
#                   'confidence': 53.5,
#                   'hour': 17},
#                  {'avg_surface_temp': 43.5,
#                   'cause': 'natural',
#                   'confidence': 68.5,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 71,
#                'date': '2019-01-21',
#                'latitude': -36.3638,
#                'longitude': 143.9086,
#                'surface_temperature_celcius': 46,
#                'time': '17:47:43'},
#               {'confidence': 67,
#                'date': '2019-01-21',
#                'latitude': -36.2282,
#                'longitude': 145.9074,
#                'surface_temperature_celcius': 43,
#                'time': '12:59:46'},
#               {'confidence': 100,
#                'date': '2019-01-21',
#                'latitude': -36.5454,
#                'longitude': 144.7402,
#                'surface_temperature_celcius': 96,
#                'time': '03:23:46'}],
#  'latitude': -37.627,
#  'longitude': 149.261,
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.7,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 170,
#  '_id': ObjectId('60aa09789343690ee21a8dc2'),
#  'air_temperature_celcius': 22,
#  'date': '2019-01-22',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 56.0,
#                   'cause': 'others',
#                   'confidence': 74.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 61.0,
#                   'cause': 'others',
#                   'confidence': 84.5,
#                   'hour': 22},
#                  {'avg_surface_temp': 41.0,
#                   'cause': 'others',
#                   'confidence': 61.0,
#                   'hour': 12},
#                  {'avg_surface_temp': 46.0,
#                   'cause': 'others',
#                   'confidence': 71.0,
#                   'hour': 22}],
#  'hotspots': [{'confidence': 64,
#                'date': '2019-01-22',
#                'latitude': -36.6026,
#                'longitude': 144.48,
#                'surface_temperature_celcius': 42,
#                'time': '12:59:43'},
#               {'confidence': 72,
#                'date': '2019-01-22',
#                'latitude': -37.467,
#                'longitude': 143.351,
#                'surface_temperature_celcius': 47,
#                'time': '22:35:43'},
#               {'confidence': 57,
#                'date': '2019-01-22',
#                'latitude': -36.9142,
#                'longitude': 141.3013,
#                'surface_temperature_celcius': 40,
#                'time': '08:11:43'},
#               {'confidence': 90,
#                'date': '2019-01-22',
#                'latitude': -35.7657,
#                'longitude': 142.0906,
#                'surface_temperature_celcius': 66,
#                'time': '08:11:46'},
#               {'confidence': 71,
#                'date': '2019-01-22',
#                'latitude': -36.7056,
#                'longitude': 145.2481,
#                'surface_temperature_celcius': 45,
#                'time': '17:47:46'},
#               {'confidence': 74,
#                'date': '2019-01-22',
#                'latitude': -36.907,
#                'longitude': 143.508,
#                'surface_temperature_celcius': 48,
#                'time': '03:23:46'}],
#  'latitude': -37.976,
#  'longitude': 145.649,
#  'max_wind_speed': 11.1,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 62.0,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('60aa09829343690ee21a8dc4'),
#  'air_temperature_celcius': 21,
#  'date': '2019-01-23',
#  'date:': '',
#  'fire_events': [{'avg_surface_temp': 49.0,
#                   'cause': 'natural',
#                   'confidence': 74.5,
#                   'hour': 12},
#                  {'avg_surface_temp': 48.5,
#                   'cause': 'natural',
#                   'confidence': 74.0,
#                   'hour': 17},
#                  {'avg_surface_temp': 55.0,
#                   'cause': 'natural',
#                   'confidence': 78.5,
#                   'hour': 3},
# ...
#                   'cause': 'others',
#                   'confidence': 64.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 46.5,
#                   'cause': 'others',
#                   'confidence': 71.5,
#                   'hour': 14},
#                  {'avg_surface_temp': 49.5,
#                   'cause': 'others',
#                   'confidence': 75.5,
#                   'hour': 19}],
#  'hotspots': [{'confidence': 68,
#                'date': '2019-02-05',
#                'latitude': -37.3344,
#                'longitude': 149.3933,
#                'surface_temperature_celcius': 47,
#                'time': '14:12:57'},
#               {'confidence': 75,
#                'date': '2019-02-05',
#                'latitude': -37.0704,
#                'longitude': 145.3684,
#                'surface_temperature_celcius': 49,
#                'time': '19:00:57'},
#               {'confidence': 79,
#                'date': '2019-02-05',
#                'latitude': -36.9221,
#                'longitude': 141.9429,
#                'surface_temperature_celcius': 52,
#                'time': '23:49:00'},
#               {'confidence': 53,
#                'date': '2019-02-05',
#                'latitude': -37.2549,
#                'longitude': 142.7719,
#                'surface_temperature_celcius': 38,
#                'time': '04:37:00'},
#               {'confidence': 76,
#                'date': '2019-02-05',
#                'latitude': -37.5402,
#                'longitude': 143.2559,
#                'surface_temperature_celcius': 50,
#                'time': '19:01:00'}],
#  'latitude': -37.479,
#  'longitude': 143.358,
#  'max_wind_speed': 26.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 60.6,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60aa1b349343690daa71f76c'),
#  'air_temperature_celcius': 17,
#  'date': '2019-02-06',
#  'fire_events': [{'avg_surface_temp': 51.0,
#                   'cause': 'others',
#                   'confidence': 67.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 54.0,
#                   'cause': 'others',
#                   'confidence': 70.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 56.5,
#                   'cause': 'others',
#                   'confidence': 82.5,
#                   'hour': 14},
#                  {'avg_surface_temp': 52.5,
#                   'cause': 'others',
#                   'confidence': 68.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 55.5,
#                   'cause': 'others',
#                   'confidence': 71.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 58.0,
#                   'cause': 'others',
#                   'confidence': 83.5,
#                   'hour': 14}],
#  'hotspots': [{'confidence': 55,
#                'date': '2019-02-06',
#                'latitude': -36.4611,
#                'longitude': 143.146,
#                'surface_temperature_celcius': 48,
#                'time': '09:25:00'},
#               {'confidence': 80,
#                'date': '2019-02-06',
#                'latitude': -36.357,
#                'longitude': 141.2363,
#                'surface_temperature_celcius': 53,
#                'time': '14:13:00'}],
#  'latitude': -36.251,
#  'longitude': 142.5651,
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 53.6,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('60aa1b3e9343690daa71f76e'),
#  'air_temperature_celcius': 22,
#  'date': '2019-02-07',
#  'fire_events': [{'avg_surface_temp': 50.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 63.5,
#                   'cause': 'others',
#                   'confidence': 87.5,
#                   'hour': 14},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 68.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 58.5,
#                   'cause': 'others',
#                   'confidence': 82.0,
#                   'hour': 14},
#                  {'avg_surface_temp': 45.0,
#                   'cause': 'others',
#                   'confidence': 69.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 58.5,
#                   'cause': 'others',
#                   'confidence': 82.5,
#                   'hour': 14}],
#  'hotspots': [{'confidence': 73,
#                'date': '2019-02-07',
#                'latitude': -36.2936,
#                'longitude': 145.1053,
#                'surface_temperature_celcius': 47,
#                'time': '23:48:57'}],
#  'latitude': -36.0966,
#  'longitude': 142.3635,
#  'max_wind_speed': 15.0,
#  'precip_flag': 'G',
#  'precipitation': 0.0,
#  'relative_humidity': 57.0,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('60aa1b489343690daa71f770'),
#  'air_temperature_celcius': 14,
#  'date': '2019-02-08',
#  'fire_events': [{'avg_surface_temp': 62.0,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 23},
#                  {'avg_surface_temp': 68.0,
#                   'cause': 'others',
#                   'confidence': 90.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 78.5,
#                   'cause': 'others',
#                   'confidence': 90.5,
#                   'hour': 14},
#                  {'avg_surface_temp': 80.5,
#                   'cause': 'others',
#                   'confidence': 97.5,
#                   'hour': 19},
#                  {'avg_surface_temp': 49.0,
#                   'cause': 'others',
#                   'confidence': 70.5,
#                   'hour': 23},
#                  {'avg_surface_temp': 55.0,
#                   'cause': 'others',
#                   'confidence': 79.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 65.5,
#                   'cause': 'others',
#                   'confidence': 79.5,
#                   'hour': 14},
#                  {'avg_surface_temp': 67.5,
#                   'cause': 'others',
#                   'confidence': 86.5,
#                   'hour': 19},
#                  {'avg_surface_temp': 46.0,
#                   'cause': 'others',
#                   'confidence': 66.5,
#                   'hour': 23},
#                  {'avg_surface_temp': 52.0,
#                   'cause': 'others',
#                   'confidence': 75.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 62.5,
#                   'cause': 'others',
#                   'confidence': 75.5,
#                   'hour': 14},
#                  {'avg_surface_temp': 64.5,
#                   'cause': 'others',
#                   'confidence': 82.5,
#                   'hour': 19},
#                  {'avg_surface_temp': 41.5,
#                   'cause': 'others',
#                   'confidence': 58.0,
#                   'hour': 23},
#                  {'avg_surface_temp': 47.5,
#                   'cause': 'others',
#                   'confidence': 66.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 58.0,
#                   'cause': 'others',
#                   'confidence': 67.0,
#                   'hour': 14},
#                  {'avg_surface_temp': 60.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 19}],
#  'hotspots': [{'confidence': 75,
#                'date': '2019-02-08',
#                'latitude': -37.3632,
#                'longitude': 145.8356,
#                'surface_temperature_celcius': 53,
#                'time': '14:12:57'},
#               {'confidence': 67,
#                'date': '2019-02-08',
#                'latitude': -36.8254,
#                'longitude': 143.5602,
#                'surface_temperature_celcius': 47,
#                'time': '19:00:57'},
#               {'confidence': 50,
#                'date': '2019-02-08',
#                'latitude': -36.7194,
#                'longitude': 143.5593,
#                'surface_temperature_celcius': 38,
#                'time': '23:48:57'},
#               {'confidence': 66,
#                'date': '2019-02-08',
#                'latitude': -36.86,
#                'longitude': 142.8137,
#                'surface_temperature_celcius': 45,
#                'time': '23:49:00'},
#               {'confidence': 83,
#                'date': '2019-02-08',
#                'latitude': -36.7313,
#                'longitude': 141.7398,
#                'surface_temperature_celcius': 57,
#                'time': '04:37:00'},
#               {'confidence': 98,
#                'date': '2019-02-08',
#                'latitude': -36.5921,
#                'longitude': 144.4905,
#                'surface_temperature_celcius': 82,
#                'time': '19:01:00'}],
#  'latitude': -37.38,
#  'longitude': 148.053,
#  'max_wind_speed': 15.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 51.0,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60aa1b529343690daa71f772'),
#  'air_temperature_celcius': 8,
#  'date': '2019-02-09',
#  'fire_events': [{'avg_surface_temp': 53.0,
#                   'cause': 'others',
#                   'confidence': 69.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 54.5,
#                   'cause': 'others',
#                   'confidence': 82.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 65.5,
#                   'cause': 'others',
#                   'confidence': 87.0,
#                   'hour': 19},
#                  {'avg_surface_temp': 76.5,
#                   'cause': 'others',
#                   'confidence': 81.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 78.0,
#                   'cause': 'others',
#                   'confidence': 94.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 89.0,
#                   'cause': 'others',
#                   'confidence': 99.0,
#                   'hour': 19},
#                  {'avg_surface_temp': 58.0,
#                   'cause': 'others',
#                   'confidence': 74.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 59.5,
#                   'cause': 'others',
#                   'confidence': 86.5,
#                   'hour': 9},
#                  {'avg_surface_temp': 70.5,
#                   'cause': 'others',
#                   'confidence': 91.5,
#                   'hour': 19},
#                  {'avg_surface_temp': 57.0,
#                   'cause': 'others',
#                   'confidence': 73.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 58.5,
#                   'cause': 'others',
#                   'confidence': 86.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 69.5,
#                   'cause': 'others',
#                   'confidence': 91.0,
#                   'hour': 19}],
#  'hotspots': [{'confidence': 76,
#                'date': '2019-02-09',
#                'latitude': -37.6177,
#                'longitude': 141.2662,
#                'surface_temperature_celcius': 49,
#                'time': '04:36:57'},
#               {'confidence': 85,
#                'date': '2019-02-09',
#                'latitude': -37.6261,
#                'longitude': 142.9447,
#                'surface_temperature_celcius': 59,
#                'time': '19:00:57'},
#               {'confidence': 84,
#                'date': '2019-02-09',
#                'latitude': -36.8272,
#                'longitude': 142.2097,
#                'surface_temperature_celcius': 57,
#                'time': '23:48:57'},
#               {'confidence': 88,
#                'date': '2019-02-09',
#                'latitude': -37.335,
#                'longitude': 148.064,
#                'surface_temperature_celcius': 60,
#                'time': '09:25:00'}],
#  'latitude': -37.238,
#  'longitude': 141.145,
#  'max_wind_speed': 15.9,
#  'precip_flag': 'G',
#  'precipitation': 0.24,
#  'relative_humidity': 41.6,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('60aa1b5c9343690daa71f774'),
#  'air_temperature_celcius': 14,
#  'date': '2019-02-10',
#  'fire_events': [{'avg_surface_temp': 49.5,
#                   'cause': 'others',
#                   'confidence': 77.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 42.0,
#                   'cause': 'others',
#                   'confidence': 58.0,
#                   'hour': 14},
#                  {'avg_surface_temp': 50.5,
#                   'cause': 'others',
#                   'confidence': 86.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 43.0,
#                   'cause': 'others',
#                   'confidence': 67.5,
#                   'hour': 14}],
#  'hotspots': [],
#  'latitude': -36.3769,
#  'longitude': 144.7505,
#  'max_wind_speed': 13.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 50.9,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 195,
#  '_id': ObjectId('60aa1b669343690daa71f776'),
#  'air_temperature_celcius': 25,
#  'date': '2019-02-11',
#  'fire_events': [{'avg_surface_temp': 48.5,
#                   'cause': 'natural',
#                   'confidence': 72.0,
#                   'hour': 23},
#                  {'avg_surface_temp': 46.0,
#                   'cause': 'natural',
#                   'confidence': 80.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 39.5,
#                   'cause': 'natural',
#                   'confidence': 58.5,
#                   'hour': 19},
#                  {'avg_surface_temp': 53.0,
#                   'cause': 'natural',
#                   'confidence': 80.0,
#                   'hour': 23},
#                  {'avg_surface_temp': 50.5,
#                   'cause': 'natural',
#                   'confidence': 88.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 44.0,
#                   'cause': 'natural',
#                   'confidence': 66.5,
#                   'hour': 19},
#                  {'avg_surface_temp': 66.0,
#                   'cause': 'natural',
#                   'confidence': 89.0,
#                   'hour': 23},
#                  {'avg_surface_temp': 63.5,
#                   'cause': 'natural',
#                   'confidence': 97.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 57.0,
#                   'cause': 'natural',
#                   'confidence': 75.5,
#                   'hour': 19}],
#  'hotspots': [{'confidence': 76,
#                'date': '2019-02-11',
#                'latitude': -36.2207,
#                'longitude': 142.8519,
#                'surface_temperature_celcius': 49,
#                'time': '14:12:57'},
#               {'confidence': 84,
#                'date': '2019-02-11',
#                'latitude': -36.0574,
#                'longitude': 141.5856,
#                'surface_temperature_celcius': 57,
#                'time': '23:49:00'}],
#  'latitude': -36.404,
#  'longitude': 142.5467,
#  'max_wind_speed': 8.9,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 60.9,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('60aa1b709343690daa71f778'),
#  'air_temperature_celcius': 28,
#  'date': '2019-02-12',
#  'fire_events': [{'avg_surface_temp': 42.0,
#                   'cause': 'natural',
#                   'confidence': 57.5,
#                   'hour': 4},
#                  {'avg_surface_temp': 76.0,
#                   'cause': 'natural',
#                   'confidence': 78.0,
#                   'hour': 9},
#                  {'avg_surface_temp': 48.5,
#                   'cause': 'natural',
#                   'confidence': 70.0,
#                   'hour': 4},
#                  {'avg_surface_temp': 82.5,
#                   'cause': 'natural',
#                   'confidence': 90.5,
#                   'hour': 9}],
#  'hotspots': [{'confidence': 100,
#                'date': '2019-02-12',
#                'latitude': -36.2648,
#                'longitude': 141.1012,
#                'surface_temperature_celcius': 111,
#                'time': '09:25:00'}],
#  'latitude': -36.009,
#  'longitude': 143.185,
#  'max_wind_speed': 22.0,
#  'precip_flag': 'I',
#  'precipitation': 0.0,
#  'relative_humidity': 48.3,
#  'windspeed_knots': 11.9}
# 80
